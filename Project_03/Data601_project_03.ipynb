# %% [markdown]
# <a href="https://colab.research.google.com/github/ajitjadhav10/DATA601/blob/main/Project_03/Data601_project_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import plotly.express as px
import plotly.io as pio

# %%
# skill migration dataset

df_1=pd.read_csv('https://raw.githubusercontent.com/ajitjadhav10/DATA601/main/Project_03/skill_migration_public%20(2).csv')
df_2=pd.read_csv('https://raw.githubusercontent.com/ajitjadhav10/DATA601/main/Project_03/industry_migration_public.csv')
df_3=pd.read_csv('https://raw.githubusercontent.com/ajitjadhav10/DATA601/main/Project_03/country_migration_public.csv')
df_1.head(5)
# Out:
#   country_code country_name   wb_income  ... Unnamed: 26  Unnamed: 27 Unnamed: 28
# 0           af  Afghanistan  Low income  ...         NaN          NaN         NaN
# 1           af  Afghanistan  Low income  ...         NaN          NaN         NaN
# 2           af  Afghanistan  Low income  ...         NaN          NaN         NaN
# 3           af  Afghanistan  Low income  ...         NaN          NaN         NaN
# 4           af  Afghanistan  Low income  ...         NaN          NaN         NaN
#
# [5 rows x 29 columns]

# %%
df_1.shape
# Out:
# (20647, 29)

# %%
df_1.isnull().sum()
# Out:
# country_code             3030
# country_name             3030
# wb_income                3030
# wb_region                3030
# skill_group_id           3030
# skill_group_category     3030
# skill_group_name         3030
# net_per_10K_2015         3030
# net_per_10K_2016         3030
# net_per_10K_2017         3030
# net_per_10K_2018         3030
# net_per_10K_2019         3030
# Unnamed: 12             20647
# Unnamed: 13             20647
# Unnamed: 14             20647
# Unnamed: 15             20647
# Unnamed: 16             20647
# Unnamed: 17             20647
# Unnamed: 18             20647
# Unnamed: 19             20647
# Unnamed: 20             20647
# Unnamed: 21             20647
# Unnamed: 22             20647
# Unnamed: 23             20647
# Unnamed: 24             20647
# Unnamed: 25             20647
# Unnamed: 26             20647
# Unnamed: 27             20647
# Unnamed: 28             20647
# dtype: int64

# %%
df_1_1=df_1.drop(columns=['Unnamed: 12','Unnamed: 13','Unnamed: 14','Unnamed: 15','Unnamed: 16','Unnamed: 17','Unnamed: 18','Unnamed: 19','Unnamed: 20','Unnamed: 21','Unnamed: 22','Unnamed: 23','Unnamed: 24','Unnamed: 25','Unnamed: 26','Unnamed: 27','Unnamed: 28'])
df_1_1.head(5)
# Out:
#   country_code country_name  ... net_per_10K_2018 net_per_10K_2019
# 0           af  Afghanistan  ...          -680.92         -1208.79
# 1           af  Afghanistan  ...          -532.22          -790.09
# 2           af  Afghanistan  ...          -600.44          -767.64
# 3           af  Afghanistan  ...          -406.50          -739.51
# 4           af  Afghanistan  ...          -581.71          -718.64
#
# [5 rows x 12 columns]

# %%
#Renaming the columns

df_1_2= df_1_1.rename({'net_per_10K_2015': '2015', 'net_per_10K_2016': '2016', 'net_per_10K_2017': '2017', 'net_per_10K_2018': '2018', 'net_per_10K_2019': '2019'}, axis=1)
df_1_2.head()
# Out:
#   country_code country_name   wb_income  ...    2017    2018     2019
# 0           af  Afghanistan  Low income  ... -550.04 -680.92 -1208.79
# 1           af  Afghanistan  Low income  ... -776.06 -532.22  -790.09
# 2           af  Afghanistan  Low income  ... -756.59 -600.44  -767.64
# 3           af  Afghanistan  Low income  ... -964.73 -406.50  -739.51
# 4           af  Afghanistan  Low income  ... -842.32 -581.71  -718.64
#
# [5 rows x 12 columns]

# %%
df_1_tidy=pd.melt(df_1_2,
             id_vars=['country_code','country_name','wb_income','wb_region','skill_group_id','skill_group_category','skill_group_name'],
             var_name='Year',
             value_name='value' #giving the column name as 'value' because I need to combine all 4 datasets at the end
                  )
df_1_tidy.head(5)
# Out:
#   country_code country_name   wb_income  ...        skill_group_name  Year    value
# 0           af  Afghanistan  Low income  ...  Information Management  2015  -791.59
# 1           af  Afghanistan  Low income  ...  Operational Efficiency  2015 -1610.25
# 2           af  Afghanistan  Low income  ...       National Security  2015 -1731.45
# 3           af  Afghanistan  Low income  ...        Software Testing  2015  -957.50
# 4           af  Afghanistan  Low income  ...                    Navy  2015 -1510.71
#
# [5 rows x 9 columns]

# %%
df_1_3=df_1_tidy.dropna()
df_1_3.head()
# Out:
#   country_code country_name   wb_income  ...        skill_group_name  Year    value
# 0           af  Afghanistan  Low income  ...  Information Management  2015  -791.59
# 1           af  Afghanistan  Low income  ...  Operational Efficiency  2015 -1610.25
# 2           af  Afghanistan  Low income  ...       National Security  2015 -1731.45
# 3           af  Afghanistan  Low income  ...        Software Testing  2015  -957.50
# 4           af  Afghanistan  Low income  ...                    Navy  2015 -1510.71
#
# [5 rows x 9 columns]

# %%
df_1_3.isnull().sum()
# Out:
# country_code            0
# country_name            0
# wb_income               0
# wb_region               0
# skill_group_id          0
# skill_group_category    0
# skill_group_name        0
# Year                    0
# value                   0
# dtype: int64

# %%
df_1_3.shape
# Out:
# (88085, 9)

# %%
df_1_5=df_1_3.sort_values(by='value',ascending=False).reset_index()
df_1_5.head()
# Out:
#    index country_code country_name  ...     skill_group_name  Year    value
# 0   9570           ml         Mali  ...                 Army  2015  2824.97
# 1  50864           ml         Mali  ...                 Army  2017  1906.14
# 2  87851           ge      Georgia  ...  Customer Experience  2019  1901.99
# 3   9239           lu   Luxembourg  ...      Time Management  2015  1799.39
# 4  29889           lu   Luxembourg  ...             Teamwork  2016  1796.89
#
# [5 rows x 10 columns]

# %%
fig_4 = px.bar(df_1_5.query('Year=="2015"').head(20), 
                x="skill_group_name", 
                y="value",
                title="'Percentage of women enrolled in higher-level education'vs Percentage of women in labour-force",
                labels={"skill_group_name":"Skill group","value":"Net migration per 10k"},
                color="country_name",
                hover_data=['Year','country_name'],
                height=400,
                # size_max=7,
                #size="value"
               ).update_xaxes(categoryorder="total descending")
#fig_4.update_traces(marker_size=40)
fig_4.show()

fig_5 = px.bar(df_1_5.query('Year=="2016"').head(20), 
                x="skill_group_name", 
                y="value",
                title="'Percentage of women enrolled in higher-level education'vs Percentage of women in labour-force",
                labels={"skill_group_name":"Skill group","value":"Net migration per 10k"},
                color="country_name",
                hover_data=['Year','country_name'],
                height=400,
                # size_max=7,
                #size="value"
               ).update_xaxes(categoryorder="total descending")
fig_5.show()

fig_6 = px.bar(df_1_5.query('Year=="2017"').head(20), 
                x="skill_group_name", 
                y="value",
                title="'Percentage of women enrolled in higher-level education'vs Percentage of women in labour-force",
                labels={"skill_group_name":"Skill group","value":"Net migration per 10k"},
                color="country_name",
                hover_data=['Year','country_name'],
                height=400,
                # size_max=7,
                #size="value"
               ).update_xaxes(categoryorder="total descending")
fig_6.show()

fig_7 = px.bar(df_1_5.query('Year=="2018"').head(20), 
                x="skill_group_name", 
                y="value",
                title="'Percentage of women enrolled in higher-level education'vs Percentage of women in labour-force",
                labels={"skill_group_name":"Skill group","value":"Net migration per 10k"},
                color="country_name",
                hover_data=['Year','country_name'],
                height=400,
                # size_max=7,
                #size="value"
               ).update_xaxes(categoryorder="total descending")
fig_7.show()

fig_8 = px.bar(df_1_5.query('Year=="2019"').head(20), 
                x="skill_group_name", 
                y="value",
                title="'Percentage of women enrolled in higher-level education'vs Percentage of women in labour-force",
                labels={"skill_group_name":"Skill group","value":"Net migration per 10k"},
                color="country_name",
                hover_data=['Year','country_name'],
                height=400,
                # size_max=7,
                #size="value"
               ).update_xaxes(categoryorder="total descending")
fig_8.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="a1176c32-bd9d-44be-8376-28d9033e8194" class="plotly-graph-div" style="height:400px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a1176c32-bd9d-44be-8376-28d9033e8194")) {
#                     Plotly.newPlot(
#                         'a1176c32-bd9d-44be-8376-28d9033e8194',
#                         [{"alignmentgroup": "True", "customdata": [["2015", "Mali"], ["2015", "Mali"], ["2015", "Mali"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>Skill group=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=Mali", "marker": {"color": "#636efa"}, "name": "country_name=Mali", "offsetgroup": "country_name=Mali", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Army", "People Management", "Inventory Management"], "xaxis": "x", "y": [2824.97, 1496.1, 1290.32], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [["2015", "Luxembourg"], ["2015", "Luxembourg"], ["2015", "Luxembourg"], ["2015", "Luxembourg"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>Skill group=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=Luxembourg", "marker": {"color": "#EF553B"}, "name": "country_name=Luxembourg", "offsetgroup": "country_name=Luxembourg", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Time Management", "Teamwork", "Ground Transportation", "Digital Literacy"], "xaxis": "x", "y": [1799.39, 1657.96, 1297.47, 1273.93], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [["2015", "Congo, Dem. Rep."], ["2015", "Congo, Dem. Rep."]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>Skill group=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=Congo, Dem. Rep.", "marker": {"color": "#00cc96"}, "name": "country_name=Congo, Dem. Rep.", "offsetgroup": "country_name=Congo, Dem. Rep.", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Employee Learning & Development", "Graphic Design"], "xaxis": "x", "y": [1536.42, 1381.07], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [["2015", "Myanmar"], ["2015", "Myanmar"], ["2015", "Myanmar"], ["2015", "Myanmar"], ["2015", "Myanmar"], ["2015", "Myanmar"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>Skill group=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=Myanmar", "marker": {"color": "#ab63fa"}, "name": "country_name=Myanmar", "offsetgroup": "country_name=Myanmar", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Environmental Consulting", "Higher Education", "Economics", "Investment Banking", "Educational Administration", "Commercial Banking"], "xaxis": "x", "y": [1289.63, 1278.91, 1256.28, 1216.92, 1194.27, 1185.36], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [["2015", "Qatar"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>Skill group=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=Qatar", "marker": {"color": "#FFA15A"}, "name": "country_name=Qatar", "offsetgroup": "country_name=Qatar", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Scientific Computing"], "xaxis": "x", "y": [1254.57], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [["2015", "United Arab Emirates"], ["2015", "United Arab Emirates"], ["2015", "United Arab Emirates"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>Skill group=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=United Arab Emirates", "marker": {"color": "#19d3f3"}, "name": "country_name=United Arab Emirates", "offsetgroup": "country_name=United Arab Emirates", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Scientific Computing", "Physiology", "Artificial Intelligence (AI)"], "xaxis": "x", "y": [1246.71, 1176.02, 1171.89], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [["2015", "Panama"]], "hoverlabel": {"nameleng ...
#                         {"barmode": "relative", "height": 400, "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.111111111111
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="bb15abc4-4191-4a6a-85f2-56d1ac0761d6" class="plotly-graph-div" style="height:400px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("bb15abc4-4191-4a6a-85f2-56d1ac0761d6")) {
#                     Plotly.newPlot(
#                         'bb15abc4-4191-4a6a-85f2-56d1ac0761d6',
#                         [{"alignmentgroup": "True", "customdata": [["2016", "Luxembourg"], ["2016", "Luxembourg"], ["2016", "Luxembourg"], ["2016", "Luxembourg"], ["2016", "Luxembourg"], ["2016", "Luxembourg"], ["2016", "Luxembourg"], ["2016", "Luxembourg"], ["2016", "Luxembourg"], ["2016", "Luxembourg"], ["2016", "Luxembourg"], ["2016", "Luxembourg"], ["2016", "Luxembourg"], ["2016", "Luxembourg"], ["2016", "Luxembourg"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>Skill group=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=Luxembourg", "marker": {"color": "#636efa"}, "name": "country_name=Luxembourg", "offsetgroup": "country_name=Luxembourg", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Teamwork", "Scientific Computing", "Analytical Reasoning", "Mathematics", "Physics", "Time Management", "Problem Solving", "Social Perceptiveness", "Sales Leads", "Artificial Intelligence (AI)", "Machining", "Bookkeeping", "Digital Literacy", "Communication", "Data Science"], "xaxis": "x", "y": [1796.89, 1672.25, 1646.73, 1605.8, 1512.06, 1381.01, 1295.96, 1267.37, 1191.49, 1161.23, 1129.51, 1121.05, 1081.06, 1061.74, 1036.65], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [["2016", "Myanmar"], ["2016", "Myanmar"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>Skill group=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=Myanmar", "marker": {"color": "#EF553B"}, "name": "country_name=Myanmar", "offsetgroup": "country_name=Myanmar", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Law", "Environmental Science"], "xaxis": "x", "y": [1187.17, 1125.46], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [["2016", "Kuwait"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>Skill group=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=Kuwait", "marker": {"color": "#00cc96"}, "name": "country_name=Kuwait", "offsetgroup": "country_name=Kuwait", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Machining"], "xaxis": "x", "y": [1153.11], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [["2016", "Congo, Dem. Rep."]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>Skill group=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=Congo, Dem. Rep.", "marker": {"color": "#ab63fa"}, "name": "country_name=Congo, Dem. Rep.", "offsetgroup": "country_name=Congo, Dem. Rep.", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Social Media"], "xaxis": "x", "y": [1133.72], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [["2016", "Panama"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>Skill group=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=Panama", "marker": {"color": "#FFA15A"}, "name": "country_name=Panama", "offsetgroup": "country_name=Panama", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Machining"], "xaxis": "x", "y": [1046.28], "yaxis": "y"}],
#                         {"barmode": "relative", "height": 400, "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="d9fcba3d-fb4f-4094-a9af-e4a474526ee8" class="plotly-graph-div" style="height:400px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d9fcba3d-fb4f-4094-a9af-e4a474526ee8")) {
#                     Plotly.newPlot(
#                         'd9fcba3d-fb4f-4094-a9af-e4a474526ee8',
#                         [{"alignmentgroup": "True", "customdata": [["2017", "Mali"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>Skill group=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=Mali", "marker": {"color": "#636efa"}, "name": "country_name=Mali", "offsetgroup": "country_name=Mali", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Army"], "xaxis": "x", "y": [1906.14], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [["2017", "Luxembourg"], ["2017", "Luxembourg"], ["2017", "Luxembourg"], ["2017", "Luxembourg"], ["2017", "Luxembourg"], ["2017", "Luxembourg"], ["2017", "Luxembourg"], ["2017", "Luxembourg"], ["2017", "Luxembourg"], ["2017", "Luxembourg"], ["2017", "Luxembourg"], ["2017", "Luxembourg"], ["2017", "Luxembourg"], ["2017", "Luxembourg"], ["2017", "Luxembourg"], ["2017", "Luxembourg"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>Skill group=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=Luxembourg", "marker": {"color": "#EF553B"}, "name": "country_name=Luxembourg", "offsetgroup": "country_name=Luxembourg", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Teamwork", "Time Management", "Artificial Intelligence (AI)", "Scientific Computing", "Industrial Design", "Machining", "Mathematics", "Data Science", "Problem Solving", "Product Testing", "Analytical Reasoning", "Game Development", "Sales Leads", "Communication", "Physics", "Organic Chemistry"], "xaxis": "x", "y": [1572.35, 1527.26, 1478.56, 1336.78, 1271.49, 1192.59, 1180.89, 1119.18, 1114.96, 1104.69, 1069.69, 1051.03, 1048.2, 1026.83, 1011.02, 966.61], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [["2017", "Kuwait"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>Skill group=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=Kuwait", "marker": {"color": "#00cc96"}, "name": "country_name=Kuwait", "offsetgroup": "country_name=Kuwait", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Fluid Mechanics"], "xaxis": "x", "y": [1381.04], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [["2017", "Cyprus"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>Skill group=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=Cyprus", "marker": {"color": "#ab63fa"}, "name": "country_name=Cyprus", "offsetgroup": "country_name=Cyprus", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Game Development"], "xaxis": "x", "y": [1112.89], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [["2017", "Chile"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>Skill group=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=Chile", "marker": {"color": "#FFA15A"}, "name": "country_name=Chile", "offsetgroup": "country_name=Chile", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Oil & Gas"], "xaxis": "x", "y": [1010.59], "yaxis": "y"}],
#                         {"barmode": "relative", "height": 400, "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"ma
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="b64f7bf2-f9c4-4320-8024-1c08e7b0ae1d" class="plotly-graph-div" style="height:400px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b64f7bf2-f9c4-4320-8024-1c08e7b0ae1d")) {
#                     Plotly.newPlot(
#                         'b64f7bf2-f9c4-4320-8024-1c08e7b0ae1d',
#                         [{"alignmentgroup": "True", "customdata": [["2018", "Luxembourg"], ["2018", "Luxembourg"], ["2018", "Luxembourg"], ["2018", "Luxembourg"], ["2018", "Luxembourg"], ["2018", "Luxembourg"], ["2018", "Luxembourg"], ["2018", "Luxembourg"], ["2018", "Luxembourg"], ["2018", "Luxembourg"], ["2018", "Luxembourg"], ["2018", "Luxembourg"], ["2018", "Luxembourg"], ["2018", "Luxembourg"], ["2018", "Luxembourg"], ["2018", "Luxembourg"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>Skill group=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=Luxembourg", "marker": {"color": "#636efa"}, "name": "country_name=Luxembourg", "offsetgroup": "country_name=Luxembourg", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Analytical Reasoning", "Teamwork", "Time Management", "Oil & Gas", "Artificial Intelligence (AI)", "Problem Solving", "Computer Hardware", "Scientific Computing", "Communication", "Mobile Application Development", "Game Development", "Machining", "Data Science", "Organic Chemistry", "Development Tools", "Web Development"], "xaxis": "x", "y": [1515.79, 1433.05, 1426.15, 1338.68, 1274.61, 1217.96, 1135.52, 1108.91, 1102.09, 1068.58, 1059.94, 1058.2, 1054.65, 1053.54, 1008.86, 985.5], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [["2018", "Cyprus"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>Skill group=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=Cyprus", "marker": {"color": "#EF553B"}, "name": "country_name=Cyprus", "offsetgroup": "country_name=Cyprus", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Game Development"], "xaxis": "x", "y": [1136.36], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [["2018", "United Arab Emirates"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>Skill group=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=United Arab Emirates", "marker": {"color": "#00cc96"}, "name": "country_name=United Arab Emirates", "offsetgroup": "country_name=United Arab Emirates", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Artificial Intelligence (AI)"], "xaxis": "x", "y": [1068.14], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [["2018", "Kuwait"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>Skill group=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=Kuwait", "marker": {"color": "#ab63fa"}, "name": "country_name=Kuwait", "offsetgroup": "country_name=Kuwait", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Chemical Processing"], "xaxis": "x", "y": [1054.92], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [["2018", "Chile"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>Skill group=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=Chile", "marker": {"color": "#FFA15A"}, "name": "country_name=Chile", "offsetgroup": "country_name=Chile", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Oil & Gas"], "xaxis": "x", "y": [985.56], "yaxis": "y"}],
#                         {"barmode": "relative", "height": 400, "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="362bb5aa-7f7e-4989-ba2b-40714cd6413b" class="plotly-graph-div" style="height:400px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("362bb5aa-7f7e-4989-ba2b-40714cd6413b")) {
#                     Plotly.newPlot(
#                         '362bb5aa-7f7e-4989-ba2b-40714cd6413b',
#                         [{"alignmentgroup": "True", "customdata": [["2019", "Georgia"], ["2019", "Georgia"], ["2019", "Georgia"], ["2019", "Georgia"], ["2019", "Georgia"], ["2019", "Georgia"], ["2019", "Georgia"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>Skill group=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=Georgia", "marker": {"color": "#636efa"}, "name": "country_name=Georgia", "offsetgroup": "country_name=Georgia", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Customer Experience", "Administrative Assistance", "Enterprise Software", "Physical Security", "Software Testing", "Inventory Management", "Time Management"], "xaxis": "x", "y": [1901.99, 1359.01, 1316.44, 1278.05, 1094.14, 1076.11, 1073.76], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [["2019", "Luxembourg"], ["2019", "Luxembourg"], ["2019", "Luxembourg"], ["2019", "Luxembourg"], ["2019", "Luxembourg"], ["2019", "Luxembourg"], ["2019", "Luxembourg"], ["2019", "Luxembourg"], ["2019", "Luxembourg"], ["2019", "Luxembourg"], ["2019", "Luxembourg"], ["2019", "Luxembourg"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>Skill group=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=Luxembourg", "marker": {"color": "#EF553B"}, "name": "country_name=Luxembourg", "offsetgroup": "country_name=Luxembourg", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Problem Solving", "Teamwork", "Scientific Computing", "Analytical Reasoning", "Time Management", "Mathematics", "Artificial Intelligence (AI)", "Physics", "Machining", "Mobile Application Development", "Data Science", "Operational Efficiency"], "xaxis": "x", "y": [1506.43, 1345.65, 1316.0, 1311.73, 1311.18, 1294.77, 1256.5, 1113.91, 1088.24, 1072.19, 1066.09, 1064.11], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [["2019", "Hong Kong SAR, China"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>Skill group=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=Hong Kong SAR, China", "marker": {"color": "#00cc96"}, "name": "country_name=Hong Kong SAR, China", "offsetgroup": "country_name=Hong Kong SAR, China", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Linguistics"], "xaxis": "x", "y": [1059.6], "yaxis": "y"}],
#                         {"barmode": "relative", "height": 400, "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "ty ...

# %%
fig_9 = px.bar(df_1_3.sort_values(by='value',ascending=True).query('Year=="2015"').head(20), 
                x="skill_group_name", 
                y="value",
                title="'Percentage of women enrolled in higher-level education'vs Percentage of women in labour-force",
                labels={"skill_group_name":"Skill group","value":"Net migration per 10k"},
                color="country_name",
                hover_data=['Year','country_name'],
                height=400,
                # size_max=7,
                #size="value"
               ).update_xaxes(categoryorder="total ascending")
#fig_4.update_traces(marker_size=40)
fig_9.show()

fig_10 = px.bar(df_1_3.sort_values(by='value',ascending=True).query('Year=="2016"').head(20), 
                x="skill_group_name", 
                y="value",
                title="'Percentage of women enrolled in higher-level education'vs Percentage of women in labour-force",
                labels={"skill_group_name":"Skill group","value":"Net migration per 10k"},
                color="country_name",
                hover_data=['Year','country_name'],
                height=400,
                # size_max=7,
                #size="value"
               ).update_xaxes(categoryorder="total ascending")
fig_10.show()

fig_11 = px.bar(df_1_3.sort_values(by='value',ascending=True).query('Year=="2017"').head(20), 
                x="skill_group_name", 
                y="value",
                title="'Percentage of women enrolled in higher-level education'vs Percentage of women in labour-force",
                labels={"skill_group_name":"Skill group","value":"Net migration per 10k"},
                color="country_name",
                hover_data=['Year','country_name'],
                height=400,
                # size_max=7,
                #size="value"
               ).update_xaxes(categoryorder="total ascending")
fig_11.show()

fig_12 = px.bar(df_1_3.sort_values(by='value',ascending=True).query('Year=="2018"').head(20), 
                x="skill_group_name", 
                y="value",
                title="'Percentage of women enrolled in higher-level education'vs Percentage of women in labour-force",
                labels={"skill_group_name":"Skill group","value":"Net migration per 10k"},
                color="country_name",
                hover_data=['Year','country_name'],
                height=400,
                # size_max=7,
                #size="value"
               ).update_xaxes(categoryorder="total ascending")
fig_12.show()

fig_13 = px.bar(df_1_3.sort_values(by='value',ascending=True).query('Year=="2019"').head(20), 
                x="skill_group_name", 
                y="value",
                title="'Percentage of women enrolled in higher-level education'vs Percentage of women in labour-force",
                labels={"skill_group_name":"Skill group","value":"Net migration per 10k"},
                color="country_name",
                hover_data=['Year','country_name'],
                height=400,
                # size_max=7,
                #size="value"
               ).update_xaxes(categoryorder="total ascending")
fig_13.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="2e46670a-75fc-4f1d-817e-cff6e752e3ad" class="plotly-graph-div" style="height:400px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2e46670a-75fc-4f1d-817e-cff6e752e3ad")) {
#                     Plotly.newPlot(
#                         '2e46670a-75fc-4f1d-817e-cff6e752e3ad',
#                         [{"alignmentgroup": "True", "customdata": [["2015", "Cuba"], ["2015", "Cuba"], ["2015", "Cuba"], ["2015", "Cuba"], ["2015", "Cuba"], ["2015", "Cuba"], ["2015", "Cuba"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>Skill group=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=Cuba", "marker": {"color": "#636efa"}, "name": "country_name=Cuba", "offsetgroup": "country_name=Cuba", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Mobile Application Development", "Human Computer Interaction", "Software Development Life Cycle (SDLC)", "Data Science", "Data Storage Technologies", "Scientific Computing", "Development Tools"], "xaxis": "x", "y": [-3037.38, -2386.58, -2190.15, -1885.79, -1734.81, -1713.31, -1601.0], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [["2015", "Iceland"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>Skill group=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=Iceland", "marker": {"color": "#EF553B"}, "name": "country_name=Iceland", "offsetgroup": "country_name=Iceland", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Employee Learning & Development"], "xaxis": "x", "y": [-2447.11], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [["2015", "Libya"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>Skill group=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=Libya", "marker": {"color": "#00cc96"}, "name": "country_name=Libya", "offsetgroup": "country_name=Libya", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Physical Security"], "xaxis": "x", "y": [-1925.5], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [["2015", "Afghanistan"], ["2015", "Afghanistan"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>Skill group=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=Afghanistan", "marker": {"color": "#ab63fa"}, "name": "country_name=Afghanistan", "offsetgroup": "country_name=Afghanistan", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["National Security", "Operational Efficiency"], "xaxis": "x", "y": [-1731.45, -1610.25], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [["2015", "Venezuela, RB"], ["2015", "Venezuela, RB"], ["2015", "Venezuela, RB"], ["2015", "Venezuela, RB"], ["2015", "Venezuela, RB"], ["2015", "Venezuela, RB"], ["2015", "Venezuela, RB"], ["2015", "Venezuela, RB"], ["2015", "Venezuela, RB"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>Skill group=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=Venezuela, RB", "marker": {"color": "#FFA15A"}, "name": "country_name=Venezuela, RB", "offsetgroup": "country_name=Venezuela, RB", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Software Testing", "Industrial Design", "Sales Leads", "Game Development", "Operational Efficiency", "Mobile Application Development", "Analytical Reasoning", "Problem Solving", "Software Development Life Cycle (SDLC)"], "xaxis": "x", "y": [-1717.64, -1679.15, -1675.34, -1674.14, -1647.7, -1631.38, -1581.51, -1572.24, -1568.18], "yaxis": "y"}],
#                         {"barmode": "relative", "height": 400, "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scatterge
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="b13a850e-9947-4d76-a089-a184a90bf786" class="plotly-graph-div" style="height:400px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b13a850e-9947-4d76-a089-a184a90bf786")) {
#                     Plotly.newPlot(
#                         'b13a850e-9947-4d76-a089-a184a90bf786',
#                         [{"alignmentgroup": "True", "customdata": [["2016", "Venezuela, RB"], ["2016", "Venezuela, RB"], ["2016", "Venezuela, RB"], ["2016", "Venezuela, RB"], ["2016", "Venezuela, RB"], ["2016", "Venezuela, RB"], ["2016", "Venezuela, RB"], ["2016", "Venezuela, RB"], ["2016", "Venezuela, RB"], ["2016", "Venezuela, RB"], ["2016", "Venezuela, RB"], ["2016", "Venezuela, RB"], ["2016", "Venezuela, RB"], ["2016", "Venezuela, RB"], ["2016", "Venezuela, RB"], ["2016", "Venezuela, RB"], ["2016", "Venezuela, RB"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>Skill group=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=Venezuela, RB", "marker": {"color": "#636efa"}, "name": "country_name=Venezuela, RB", "offsetgroup": "country_name=Venezuela, RB", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Flexible Approach", "Operational Efficiency", "Artificial Intelligence (AI)", "Structural Engineering", "Software Testing", "Time Management", "Problem Solving", "Structural Analysis", "Analytical Reasoning", "Human Computer Interaction", "Mobile Application Development", "Sales Leads", "Software Development Life Cycle (SDLC)", "Environmental Engineering", "Customer Experience", "Machining", "Scientific Computing"], "xaxis": "x", "y": [-2435.26, -2134.93, -2104.3, -2065.4, -2058.37, -2056.98, -2027.66, -2022.09, -1987.86, -1972.02, -1957.09, -1954.75, -1842.81, -1804.31, -1793.66, -1774.9, -1771.48], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [["2016", "Cuba"], ["2016", "Cuba"], ["2016", "Cuba"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>Skill group=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=Cuba", "marker": {"color": "#EF553B"}, "name": "country_name=Cuba", "offsetgroup": "country_name=Cuba", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Human Computer Interaction", "Mobile Application Development", "Software Development Life Cycle (SDLC)"], "xaxis": "x", "y": [-2052.55, -1968.18, -1928.25], "yaxis": "y"}],
#                         {"barmode": "relative", "height": 400, "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "ty ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="7b4d35ce-76cb-4d57-876d-124dc054140b" class="plotly-graph-div" style="height:400px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7b4d35ce-76cb-4d57-876d-124dc054140b")) {
#                     Plotly.newPlot(
#                         '7b4d35ce-76cb-4d57-876d-124dc054140b',
#                         [{"alignmentgroup": "True", "customdata": [["2017", "Algeria"], ["2017", "Algeria"], ["2017", "Algeria"], ["2017", "Algeria"], ["2017", "Algeria"], ["2017", "Algeria"], ["2017", "Algeria"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>Skill group=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=Algeria", "marker": {"color": "#636efa"}, "name": "country_name=Algeria", "offsetgroup": "country_name=Algeria", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Recruiting", "Enterprise Software", "Inventory Management", "Human Resources (HR)", "Data Storage Technologies", "Management Consulting", "Development Tools"], "xaxis": "x", "y": [-6604.67, -6060.98, -4858.51, -3471.35, -2960.83, -2955.29, -2158.62], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [["2017", "Venezuela, RB"], ["2017", "Venezuela, RB"], ["2017", "Venezuela, RB"], ["2017", "Venezuela, RB"], ["2017", "Venezuela, RB"], ["2017", "Venezuela, RB"], ["2017", "Venezuela, RB"], ["2017", "Venezuela, RB"], ["2017", "Venezuela, RB"], ["2017", "Venezuela, RB"], ["2017", "Venezuela, RB"], ["2017", "Venezuela, RB"], ["2017", "Venezuela, RB"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>Skill group=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=Venezuela, RB", "marker": {"color": "#EF553B"}, "name": "country_name=Venezuela, RB", "offsetgroup": "country_name=Venezuela, RB", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Sales Leads", "Human Computer Interaction", "Flexible Approach", "Software Testing", "Artificial Intelligence (AI)", "Structural Engineering", "Scientific Computing", "Operational Efficiency", "Industrial Design", "Problem Solving", "Mobile Application Development", "Machining", "Game Development"], "xaxis": "x", "y": [-3274.3, -2646.19, -2542.23, -2469.0, -2435.67, -2403.48, -2399.77, -2382.85, -2340.68, -2305.74, -2295.46, -2170.74, -2168.79], "yaxis": "y"}],
#                         {"barmode": "relative", "height": 400, "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "ty ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="da1ea0b2-410c-4f87-8646-c6145bc50dd1" class="plotly-graph-div" style="height:400px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("da1ea0b2-410c-4f87-8646-c6145bc50dd1")) {
#                     Plotly.newPlot(
#                         'da1ea0b2-410c-4f87-8646-c6145bc50dd1',
#                         [{"alignmentgroup": "True", "customdata": [["2018", "Venezuela, RB"], ["2018", "Venezuela, RB"], ["2018", "Venezuela, RB"], ["2018", "Venezuela, RB"], ["2018", "Venezuela, RB"], ["2018", "Venezuela, RB"], ["2018", "Venezuela, RB"], ["2018", "Venezuela, RB"], ["2018", "Venezuela, RB"], ["2018", "Venezuela, RB"], ["2018", "Venezuela, RB"], ["2018", "Venezuela, RB"], ["2018", "Venezuela, RB"], ["2018", "Venezuela, RB"], ["2018", "Venezuela, RB"], ["2018", "Venezuela, RB"], ["2018", "Venezuela, RB"], ["2018", "Venezuela, RB"], ["2018", "Venezuela, RB"], ["2018", "Venezuela, RB"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>Skill group=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=Venezuela, RB", "marker": {"color": "#636efa"}, "name": "country_name=Venezuela, RB", "offsetgroup": "country_name=Venezuela, RB", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Flexible Approach", "Human Computer Interaction", "Sales Leads", "Structural Engineering", "Machining", "Mobile Application Development", "Structural Analysis", "Software Testing", "Scientific Computing", "Social Perceptiveness", "Time Management", "Artificial Intelligence (AI)", "Industrial Design", "Problem Solving", "Customer Experience", "Electronic Control Systems", "Environmental Engineering", "Documentation", "Chemical Processing", "Analytical Reasoning"], "xaxis": "x", "y": [-3629.02, -3171.94, -3094.17, -3020.0, -2949.09, -2822.98, -2814.19, -2797.99, -2778.32, -2743.94, -2735.03, -2679.14, -2670.13, -2665.84, -2635.06, -2624.44, -2608.7, -2588.3, -2574.58, -2543.06], "yaxis": "y"}],
#                         {"barmode": "relative", "height": 400, "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "ty ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="d43cc282-49bb-429d-a865-a158fe158f80" class="plotly-graph-div" style="height:400px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d43cc282-49bb-429d-a865-a158fe158f80")) {
#                     Plotly.newPlot(
#                         'd43cc282-49bb-429d-a865-a158fe158f80',
#                         [{"alignmentgroup": "True", "customdata": [["2019", "Venezuela, RB"], ["2019", "Venezuela, RB"], ["2019", "Venezuela, RB"], ["2019", "Venezuela, RB"], ["2019", "Venezuela, RB"], ["2019", "Venezuela, RB"], ["2019", "Venezuela, RB"], ["2019", "Venezuela, RB"], ["2019", "Venezuela, RB"], ["2019", "Venezuela, RB"], ["2019", "Venezuela, RB"], ["2019", "Venezuela, RB"], ["2019", "Venezuela, RB"], ["2019", "Venezuela, RB"], ["2019", "Venezuela, RB"], ["2019", "Venezuela, RB"], ["2019", "Venezuela, RB"], ["2019", "Venezuela, RB"], ["2019", "Venezuela, RB"], ["2019", "Venezuela, RB"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>Skill group=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=Venezuela, RB", "marker": {"color": "#636efa"}, "name": "country_name=Venezuela, RB", "offsetgroup": "country_name=Venezuela, RB", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Flexible Approach", "Social Perceptiveness", "Analytical Reasoning", "Sales Leads", "Human Computer Interaction", "Problem Solving", "Structural Analysis", "Artificial Intelligence (AI)", "Customer Experience", "Chemical Processing", "Mobile Application Development", "Electronic Control Systems", "Information Management", "Nonprofit Management", "Time Management", "Environmental Engineering", "Operational Efficiency", "Structural Engineering", "Fluid Mechanics", "Dentistry"], "xaxis": "x", "y": [-4022.04, -3834.49, -2724.71, -2641.97, -2395.31, -2392.5, -2360.06, -2212.81, -2212.3, -2136.98, -2108.01, -2106.54, -2100.52, -2098.94, -2097.23, -2080.58, -2056.16, -2035.93, -2022.78, -1994.42], "yaxis": "y"}],
#                         {"barmode": "relative", "height": 400, "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "ty ...

# %%
# figure=px.choropleth(df_1_tidy,
#                      locations='country_name',
#                      locationmode='country names',
#                      color='value',
#                      animation_frame='Year',
#                      animation_group='country_name',
#                      title='GDP per capita, PPP (current international $) from 1990 to 2020',
#                      height=650,
#                      labels={'value':'GDP per capita, PPP (current international $)'}
#                      )
# figure.show()

# %%
#industry migration

df_2.head()
# Out:
#   country_code          country_name  ... Unnamed: 28 Unnamed: 29
# 0           ae  United Arab Emirates  ...         NaN         NaN
# 1           ae  United Arab Emirates  ...         NaN         NaN
# 2           ae  United Arab Emirates  ...         NaN         NaN
# 3           ae  United Arab Emirates  ...         NaN         NaN
# 4           ae  United Arab Emirates  ...         NaN         NaN
#
# [5 rows x 30 columns]

# %%
df_2.shape
# Out:
# (5295, 30)

# %%
df_2.isnull().sum()
# Out:
# country_code             0
# country_name             0
# wb_income                0
# wb_region                0
# isic_section_index       0
# isic_section_name        0
# industry_id              0
# industry_name            0
# net_per_10K_2015         0
# net_per_10K_2016         0
# net_per_10K_2017         0
# net_per_10K_2018         0
# net_per_10K_2019         0
# Unnamed: 13           5295
# Unnamed: 14           5295
# Unnamed: 15           5295
# Unnamed: 16           5295
# Unnamed: 17           5295
# Unnamed: 18           5295
# Unnamed: 19           5295
# Unnamed: 20           5295
# Unnamed: 21           5295
# Unnamed: 22           5295
# Unnamed: 23           5295
# Unnamed: 24           5295
# Unnamed: 25           5295
# Unnamed: 26           5295
# Unnamed: 27           5295
# Unnamed: 28           5295
# Unnamed: 29           5295
# dtype: int64

# %%
df_2_1=df_2.drop(columns=['Unnamed: 13','Unnamed: 14','Unnamed: 15','Unnamed: 16','Unnamed: 17','Unnamed: 18','Unnamed: 19','Unnamed: 20','Unnamed: 21','Unnamed: 22','Unnamed: 23','Unnamed: 24','Unnamed: 25','Unnamed: 26','Unnamed: 27','Unnamed: 28','Unnamed: 29'])
df_2_1.head(5)
# Out:
#   country_code          country_name  ... net_per_10K_2018 net_per_10K_2019
# 0           ae  United Arab Emirates  ...            68.51            49.55
# 1           ae  United Arab Emirates  ...           149.57           182.22
# 2           ae  United Arab Emirates  ...           409.18           407.41
# 3           ae  United Arab Emirates  ...           236.69           188.07
# 4           ae  United Arab Emirates  ...           852.39           519.40
#
# [5 rows x 13 columns]

# %%
#Renaming the columns

df_2_2= df_2_1.rename({'net_per_10K_2015': '2015', 'net_per_10K_2016': '2016', 'net_per_10K_2017': '2017', 'net_per_10K_2018': '2018', 'net_per_10K_2019': '2019'}, axis=1)
df_2_2.head()
# Out:
#   country_code          country_name    wb_income  ...    2017    2018    2019
# 0           ae  United Arab Emirates  High income  ...    8.20   68.51   49.55
# 1           ae  United Arab Emirates  High income  ...  112.98  149.57  182.22
# 2           ae  United Arab Emirates  High income  ...  596.48  409.18  407.41
# 3           ae  United Arab Emirates  High income  ...  163.99  236.69  188.07
# 4           ae  United Arab Emirates  High income  ...  877.71  852.39  519.40
#
# [5 rows x 13 columns]

# %%
df_2_tidy=pd.melt(df_2_2,
             id_vars=['country_code','country_name','wb_income','wb_region','isic_section_index','isic_section_name','industry_id','industry_name'],
             var_name='Year',
             value_name='value' #giving the column name as 'value' because I need to combine all 4 datasets at the end
                  )
df_2_tidy.head(5)
# Out:
#   country_code          country_name  ...  Year    value
# 0           ae  United Arab Emirates  ...  2015   378.74
# 1           ae  United Arab Emirates  ...  2015   100.97
# 2           ae  United Arab Emirates  ...  2015  1079.36
# 3           ae  United Arab Emirates  ...  2015   401.46
# 4           ae  United Arab Emirates  ...  2015  1840.33
#
# [5 rows x 10 columns]

# %%
fig_14 = px.bar(df_2_tidy.sort_values(by='value',ascending=False).query('Year=="2015"').head(20), 
                x="industry_name", 
                y="value",
                title="'Percentage of women enrolled in higher-level education'vs Percentage of women in labour-force",
                labels={"skill_group_name":"Skill group","value":"Net migration per 10k"},
                color="country_name",
                hover_data=['Year','country_name'],
                height=400,
                # size_max=7,
                #size="value"
               ).update_xaxes(categoryorder="total ascending")
#fig_4.update_traces(marker_size=40)
fig_14.show()

fig_15 = px.bar(df_2_tidy.sort_values(by='value',ascending=False).query('Year=="2016"').head(20), 
                x="industry_name", 
                y="value",
                title="'Percentage of women enrolled in higher-level education'vs Percentage of women in labour-force",
                labels={"skill_group_name":"Skill group","value":"Net migration per 10k"},
                color="country_name",
                hover_data=['Year','country_name'],
                height=400,
                # size_max=7,
                #size="value"
               ).update_xaxes(categoryorder="total ascending")
fig_15.show()

fig_16 = px.bar(df_2_tidy.sort_values(by='value',ascending=False).query('Year=="2017"').head(20), 
                x="industry_name", 
                y="value",
                title="'Percentage of women enrolled in higher-level education'vs Percentage of women in labour-force",
                labels={"skill_group_name":"Skill group","value":"Net migration per 10k"},
                color="country_name",
                hover_data=['Year','country_name'],
                height=400,
                # size_max=7,
                #size="value"
               ).update_xaxes(categoryorder="total ascending")
fig_16.show()

fig_17 = px.bar(df_2_tidy.sort_values(by='value',ascending=False).query('Year=="2018"').head(20), 
                x="industry_name",
                y="value",
                title="'Percentage of women enrolled in higher-level education'vs Percentage of women in labour-force",
                labels={"skill_group_name":"Skill group","value":"Net migration per 10k"},
                color="country_name",
                hover_data=['Year','country_name'],
                height=400,
                # size_max=7,
                #size="value"
               ).update_xaxes(categoryorder="total ascending")
fig_17.show()

fig_18 = px.bar(df_2_tidy.sort_values(by='value',ascending=False).query('Year=="2019"').head(20), 
                x="industry_name", 
                y="value",
                title="'Percentage of women enrolled in higher-level education'vs Percentage of women in labour-force",
                labels={"skill_group_name":"Skill group","value":"Net migration per 10k"},
                color="country_name",
                hover_data=['Year','country_name'],
                height=400,
                # size_max=7,
                #size="value"
               ).update_xaxes(categoryorder="total ascending")
fig_18.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="7eda4b57-b475-4b6b-9050-bb8b4bae66b9" class="plotly-graph-div" style="height:400px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7eda4b57-b475-4b6b-9050-bb8b4bae66b9")) {
#                     Plotly.newPlot(
#                         '7eda4b57-b475-4b6b-9050-bb8b4bae66b9',
#                         [{"alignmentgroup": "True", "customdata": [["2015", "United Arab Emirates"], ["2015", "United Arab Emirates"], ["2015", "United Arab Emirates"], ["2015", "United Arab Emirates"], ["2015", "United Arab Emirates"], ["2015", "United Arab Emirates"], ["2015", "United Arab Emirates"], ["2015", "United Arab Emirates"], ["2015", "United Arab Emirates"], ["2015", "United Arab Emirates"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>industry_name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=United Arab Emirates", "marker": {"color": "#636efa"}, "name": "country_name=United Arab Emirates", "offsetgroup": "country_name=United Arab Emirates", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["E-Learning", "Internet", "Computer Games", "Wine & Spirits", "International Affairs", "Tobacco", "Capital Markets", "Outsourcing/Offshoring", "Accounting", "Animation"], "xaxis": "x", "y": [2280.6, 1840.33, 1662.82, 1487.6, 1468.53, 1377.42, 1345.11, 1329.1, 1308.05, 1264.88], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [["2015", "Luxembourg"], ["2015", "Luxembourg"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>industry_name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=Luxembourg", "marker": {"color": "#EF553B"}, "name": "country_name=Luxembourg", "offsetgroup": "country_name=Luxembourg", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Food Production", "Internet"], "xaxis": "x", "y": [2054.79, 1537.7], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [["2015", "Cote d'Ivoire"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>industry_name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=Cote d'Ivoire", "marker": {"color": "#00cc96"}, "name": "country_name=Cote d'Ivoire", "offsetgroup": "country_name=Cote d'Ivoire", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["International Trade & Development"], "xaxis": "x", "y": [1839.48], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [["2015", "Qatar"], ["2015", "Qatar"], ["2015", "Qatar"], ["2015", "Qatar"], ["2015", "Qatar"], ["2015", "Qatar"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>industry_name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=Qatar", "marker": {"color": "#ab63fa"}, "name": "country_name=Qatar", "offsetgroup": "country_name=Qatar", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Transportation/Trucking/Railroad", "Food Production", "Renewables & Environment", "Health, Wellness & Fitness", "Consumer Services", "Outsourcing/Offshoring"], "xaxis": "x", "y": [1820.85, 1646.25, 1571.27, 1553.76, 1396.51, 1288.98], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [["2015", "Panama"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>industry_name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=Panama", "marker": {"color": "#FFA15A"}, "name": "country_name=Panama", "offsetgroup": "country_name=Panama", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Hospital & Health Care"], "xaxis": "x", "y": [1442.89], "yaxis": "y"}],
#                         {"barmode": "relative", "height": 400, "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "sca
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="a676ed76-fe4c-4d65-b6b9-896c1696e22f" class="plotly-graph-div" style="height:400px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a676ed76-fe4c-4d65-b6b9-896c1696e22f")) {
#                     Plotly.newPlot(
#                         'a676ed76-fe4c-4d65-b6b9-896c1696e22f',
#                         [{"alignmentgroup": "True", "customdata": [["2016", "Luxembourg"], ["2016", "Luxembourg"], ["2016", "Luxembourg"], ["2016", "Luxembourg"], ["2016", "Luxembourg"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>industry_name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=Luxembourg", "marker": {"color": "#636efa"}, "name": "country_name=Luxembourg", "offsetgroup": "country_name=Luxembourg", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Internet", "Consumer Goods", "Mechanical or Industrial Engineering", "Food Production", "Accounting"], "xaxis": "x", "y": [1787.58, 1388.95, 1279.68, 1256.23, 1206.24], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [["2016", "United Arab Emirates"], ["2016", "United Arab Emirates"], ["2016", "United Arab Emirates"], ["2016", "United Arab Emirates"], ["2016", "United Arab Emirates"], ["2016", "United Arab Emirates"], ["2016", "United Arab Emirates"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>industry_name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=United Arab Emirates", "marker": {"color": "#EF553B"}, "name": "country_name=United Arab Emirates", "offsetgroup": "country_name=United Arab Emirates", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Wine & Spirits", "E-Learning", "Internet", "Accounting", "Outsourcing/Offshoring", "Animation", "Computer Games"], "xaxis": "x", "y": [1616.52, 1492.85, 1368.42, 1261.62, 1207.32, 1159.13, 1153.85], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [["2016", "Qatar"], ["2016", "Qatar"], ["2016", "Qatar"], ["2016", "Qatar"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>industry_name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=Qatar", "marker": {"color": "#00cc96"}, "name": "country_name=Qatar", "offsetgroup": "country_name=Qatar", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Food Production", "Renewables & Environment", "Transportation/Trucking/Railroad", "Leisure, Travel & Tourism"], "xaxis": "x", "y": [1440.58, 1395.75, 1334.97, 1159.06], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [["2016", "Japan"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>industry_name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=Japan", "marker": {"color": "#ab63fa"}, "name": "country_name=Japan", "offsetgroup": "country_name=Japan", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Aviation & Aerospace"], "xaxis": "x", "y": [1327.59], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [["2016", "Cote d'Ivoire"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>industry_name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=Cote d'Ivoire", "marker": {"color": "#FFA15A"}, "name": "country_name=Cote d'Ivoire", "offsetgroup": "country_name=Cote d'Ivoire", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["International Trade & Development"], "xaxis": "x", "y": [1317.92], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [["2016", "Malta"], ["2016", "Malta"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>industry_name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=Malta", "marker": {"color": "#19d3f3"}, "name": "country_name=Malta", "offsetgroup": "country_name=Malta", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Marketing & Advertising", "Gambling & Casinos"], "xaxis": "x", "y": [1148.41, 1116.56], "y ...
#                         {"barmode": "relative", "height": 400, "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"c
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="8728d1f5-0a83-4722-a53a-189a2de6113f" class="plotly-graph-div" style="height:400px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8728d1f5-0a83-4722-a53a-189a2de6113f")) {
#                     Plotly.newPlot(
#                         '8728d1f5-0a83-4722-a53a-189a2de6113f',
#                         [{"alignmentgroup": "True", "customdata": [["2017", "Luxembourg"], ["2017", "Luxembourg"], ["2017", "Luxembourg"], ["2017", "Luxembourg"], ["2017", "Luxembourg"], ["2017", "Luxembourg"], ["2017", "Luxembourg"], ["2017", "Luxembourg"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>industry_name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=Luxembourg", "marker": {"color": "#636efa"}, "name": "country_name=Luxembourg", "offsetgroup": "country_name=Luxembourg", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Internet", "Consumer Goods", "Accounting", "Management Consulting", "Computer Software", "Higher Education", "Staffing & Recruiting", "Food Production"], "xaxis": "x", "y": [1981.38, 1216.73, 1050.4, 978.4, 968.91, 942.68, 879.12, 869.17], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [["2017", "United Arab Emirates"], ["2017", "United Arab Emirates"], ["2017", "United Arab Emirates"], ["2017", "United Arab Emirates"], ["2017", "United Arab Emirates"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>industry_name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=United Arab Emirates", "marker": {"color": "#EF553B"}, "name": "country_name=United Arab Emirates", "offsetgroup": "country_name=United Arab Emirates", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["E-Learning", "Accounting", "Wine & Spirits", "Internet", "Tobacco"], "xaxis": "x", "y": [1362.36, 1044.37, 912.0, 877.71, 870.1], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [["2017", "Japan"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>industry_name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=Japan", "marker": {"color": "#00cc96"}, "name": "country_name=Japan", "offsetgroup": "country_name=Japan", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Aviation & Aerospace"], "xaxis": "x", "y": [1031.67], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [["2017", "Cyprus"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>industry_name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=Cyprus", "marker": {"color": "#ab63fa"}, "name": "country_name=Cyprus", "offsetgroup": "country_name=Cyprus", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Marketing & Advertising"], "xaxis": "x", "y": [1006.93], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [["2017", "Switzerland"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>industry_name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=Switzerland", "marker": {"color": "#FFA15A"}, "name": "country_name=Switzerland", "offsetgroup": "country_name=Switzerland", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["E-Learning"], "xaxis": "x", "y": [968.91], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [["2017", "Ireland"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>industry_name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=Ireland", "marker": {"color": "#19d3f3"}, "name": "country_name=Ireland", "offsetgroup": "country_name=Ireland", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["International Affairs"], "xaxis": "x", "y": [924.37], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [["2017", "Malta"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>industry_name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", " ...
#                         {"barmode": "relative", "height": 400, "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="a7521352-74b0-4c3c-82f9-0a35022578c2" class="plotly-graph-div" style="height:400px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a7521352-74b0-4c3c-82f9-0a35022578c2")) {
#                     Plotly.newPlot(
#                         'a7521352-74b0-4c3c-82f9-0a35022578c2',
#                         [{"alignmentgroup": "True", "customdata": [["2018", "Luxembourg"], ["2018", "Luxembourg"], ["2018", "Luxembourg"], ["2018", "Luxembourg"], ["2018", "Luxembourg"], ["2018", "Luxembourg"], ["2018", "Luxembourg"], ["2018", "Luxembourg"], ["2018", "Luxembourg"], ["2018", "Luxembourg"], ["2018", "Luxembourg"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>industry_name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=Luxembourg", "marker": {"color": "#636efa"}, "name": "country_name=Luxembourg", "offsetgroup": "country_name=Luxembourg", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Accounting", "Food Production", "Computer Software", "Machinery", "Internet", "Staffing & Recruiting", "Management Consulting", "Consumer Goods", "Non-Profit Organization Management", "Research", "Financial Services"], "xaxis": "x", "y": [1500.0, 1287.36, 1184.13, 1169.95, 1168.6, 1012.57, 950.1, 916.54, 868.44, 856.21, 817.49], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [["2018", "United Arab Emirates"], ["2018", "United Arab Emirates"], ["2018", "United Arab Emirates"], ["2018", "United Arab Emirates"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>industry_name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=United Arab Emirates", "marker": {"color": "#EF553B"}, "name": "country_name=United Arab Emirates", "offsetgroup": "country_name=United Arab Emirates", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Accounting", "Computer Games", "E-Learning", "Internet"], "xaxis": "x", "y": [1187.61, 1127.47, 904.86, 852.39], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [["2018", "Cyprus"], ["2018", "Cyprus"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>industry_name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=Cyprus", "marker": {"color": "#00cc96"}, "name": "country_name=Cyprus", "offsetgroup": "country_name=Cyprus", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Internet", "Hospitality"], "xaxis": "x", "y": [1186.06, 840.94], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [["2018", "Qatar"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>industry_name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=Qatar", "marker": {"color": "#ab63fa"}, "name": "country_name=Qatar", "offsetgroup": "country_name=Qatar", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Food Production"], "xaxis": "x", "y": [1144.49], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [["2018", "Ireland"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>industry_name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=Ireland", "marker": {"color": "#FFA15A"}, "name": "country_name=Ireland", "offsetgroup": "country_name=Ireland", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Animation"], "xaxis": "x", "y": [917.1], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [["2018", "Canada"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>industry_name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=Canada", "marker": {"color": "#19d3f3"}, "name": "country_name=Canada", "offsetgroup": "country_name=Canada", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Outsourcing/Offshoring"], "xaxis": "x", "y": [856.55], "yaxis": "y"}],
#                         {"barmode": "relative", "height": 400, "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="8b0b4589-fcea-4b46-bdd3-a49ce357b376" class="plotly-graph-div" style="height:400px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8b0b4589-fcea-4b46-bdd3-a49ce357b376")) {
#                     Plotly.newPlot(
#                         '8b0b4589-fcea-4b46-bdd3-a49ce357b376',
#                         [{"alignmentgroup": "True", "customdata": [["2019", "Luxembourg"], ["2019", "Luxembourg"], ["2019", "Luxembourg"], ["2019", "Luxembourg"], ["2019", "Luxembourg"], ["2019", "Luxembourg"], ["2019", "Luxembourg"], ["2019", "Luxembourg"], ["2019", "Luxembourg"], ["2019", "Luxembourg"], ["2019", "Luxembourg"], ["2019", "Luxembourg"], ["2019", "Luxembourg"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>industry_name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=Luxembourg", "marker": {"color": "#636efa"}, "name": "country_name=Luxembourg", "offsetgroup": "country_name=Luxembourg", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Accounting", "Internet", "Consumer Goods", "Higher Education", "Staffing & Recruiting", "Logistics & Supply Chain", "Legal Services", "Information Technology & Services", "Financial Services", "Automotive", "Food Production", "Management Consulting", "Computer Software"], "xaxis": "x", "y": [1820.99, 1561.98, 916.87, 889.13, 861.03, 824.31, 800.65, 761.45, 756.89, 755.4, 738.21, 706.08, 670.05], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [["2019", "Georgia"], ["2019", "Georgia"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>industry_name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=Georgia", "marker": {"color": "#EF553B"}, "name": "country_name=Georgia", "offsetgroup": "country_name=Georgia", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Higher Education", "Information Technology & Services"], "xaxis": "x", "y": [1321.56, 669.04], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [["2019", "Qatar"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>industry_name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=Qatar", "marker": {"color": "#00cc96"}, "name": "country_name=Qatar", "offsetgroup": "country_name=Qatar", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Food Production"], "xaxis": "x", "y": [955.84], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [["2019", "Canada"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>industry_name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=Canada", "marker": {"color": "#ab63fa"}, "name": "country_name=Canada", "offsetgroup": "country_name=Canada", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Outsourcing/Offshoring"], "xaxis": "x", "y": [905.94], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [["2019", "Ireland"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>industry_name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=Ireland", "marker": {"color": "#FFA15A"}, "name": "country_name=Ireland", "offsetgroup": "country_name=Ireland", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["International Affairs"], "xaxis": "x", "y": [737.22], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [["2019", "Japan"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>industry_name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=Japan", "marker": {"color": "#19d3f3"}, "name": "country_name=Japan", "offsetgroup": "country_name=Japan", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Aviation & Aerospace"], "xaxis": "x", "y": [698.45], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [["2019", "United Arab Emirates"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>industr ...
#                         {"barmode": "relative", "height": 400, "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.22

# %%
fig_19 = px.bar(df_2_tidy.sort_values(by='value',ascending=True).query('Year=="2015"').head(20), 
                x="industry_name", 
                y="value",
                title="'Percentage of women enrolled in higher-level education'vs Percentage of women in labour-force",
                labels={"skill_group_name":"Skill group","value":"Net migration per 10k"},
                color="country_name",
                hover_data=['Year','country_name'],
                height=400,
                # size_max=7,
                #size="value"
               ).update_xaxes(categoryorder="total ascending")
#fig_4.update_traces(marker_size=40)
fig_19.show()

fig_20 = px.bar(df_2_tidy.sort_values(by='value',ascending=True).query('Year=="2016"').head(20), 
                x="industry_name", 
                y="value",
                title="'Percentage of women enrolled in higher-level education'vs Percentage of women in labour-force",
                labels={"skill_group_name":"Skill group","value":"Net migration per 10k"},
                color="country_name",
                hover_data=['Year','country_name'],
                height=400,
                # size_max=7,
                #size="value"
               ).update_xaxes(categoryorder="total ascending")
fig_20.show()

fig_21 = px.bar(df_2_tidy.sort_values(by='value',ascending=True).query('Year=="2017"').head(20), 
                x="industry_name", 
                y="value",
                title="'Percentage of women enrolled in higher-level education'vs Percentage of women in labour-force",
                labels={"skill_group_name":"Skill group","value":"Net migration per 10k"},
                color="country_name",
                hover_data=['Year','country_name'],
                height=400,
                # size_max=7,
                #size="value"
               ).update_xaxes(categoryorder="total ascending")
fig_21.show()

fig_22 = px.bar(df_2_tidy.sort_values(by='value',ascending=True).query('Year=="2018"').head(20), 
                x="industry_name",
                y="value",
                title="'Percentage of women enrolled in higher-level education'vs Percentage of women in labour-force",
                labels={"skill_group_name":"Skill group","value":"Net migration per 10k"},
                color="country_name",
                hover_data=['Year','country_name'],
                height=400,
                # size_max=7,
                #size="value"
               ).update_xaxes(categoryorder="total ascending")
fig_22.show()

fig_23 = px.bar(df_2_tidy.sort_values(by='value',ascending=True).query('Year=="2019"').head(20), 
                x="industry_name", 
                y="value",
                title="'Percentage of women enrolled in higher-level education'vs Percentage of women in labour-force",
                labels={"skill_group_name":"Skill group","value":"Net migration per 10k"},
                color="country_name",
                hover_data=['Year','country_name'],
                height=400,
                # size_max=7,
                #size="value"
               ).update_xaxes(categoryorder="total ascending")
fig_23.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="0a31dd3b-e8d7-4be3-929a-519d86497e17" class="plotly-graph-div" style="height:400px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0a31dd3b-e8d7-4be3-929a-519d86497e17")) {
#                     Plotly.newPlot(
#                         '0a31dd3b-e8d7-4be3-929a-519d86497e17',
#                         [{"alignmentgroup": "True", "customdata": [["2015", "Gabon"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>industry_name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=Gabon", "marker": {"color": "#636efa"}, "name": "country_name=Gabon", "offsetgroup": "country_name=Gabon", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Construction"], "xaxis": "x", "y": [-1185.25], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [["2015", "Afghanistan"], ["2015", "Afghanistan"], ["2015", "Afghanistan"], ["2015", "Afghanistan"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>industry_name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=Afghanistan", "marker": {"color": "#EF553B"}, "name": "country_name=Afghanistan", "offsetgroup": "country_name=Afghanistan", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Military", "Logistics & Supply Chain", "Defense & Space", "Oil & Energy"], "xaxis": "x", "y": [-1172.34, -917.05, -869.73, -688.49], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [["2015", "Venezuela, RB"], ["2015", "Venezuela, RB"], ["2015", "Venezuela, RB"], ["2015", "Venezuela, RB"], ["2015", "Venezuela, RB"], ["2015", "Venezuela, RB"], ["2015", "Venezuela, RB"], ["2015", "Venezuela, RB"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>industry_name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=Venezuela, RB", "marker": {"color": "#00cc96"}, "name": "country_name=Venezuela, RB", "offsetgroup": "country_name=Venezuela, RB", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Wine & Spirits", "Information Technology & Services", "Telecommunications", "Marketing & Advertising", "Consumer Goods", "Investment Management", "Accounting", "Pharmaceuticals"], "xaxis": "x", "y": [-1131.22, -794.13, -781.01, -778.24, -763.83, -741.64, -741.42, -703.04], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [["2015", "Korea, Rep."], ["2015", "Korea, Rep."]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>industry_name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=Korea, Rep.", "marker": {"color": "#ab63fa"}, "name": "country_name=Korea, Rep.", "offsetgroup": "country_name=Korea, Rep.", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Military", "Defense & Space"], "xaxis": "x", "y": [-1104.17, -800.0], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [["2015", "Cyprus"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>industry_name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=Cyprus", "marker": {"color": "#FFA15A"}, "name": "country_name=Cyprus", "offsetgroup": "country_name=Cyprus", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Military"], "xaxis": "x", "y": [-1052.63], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [["2015", "Bahrain"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>industry_name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=Bahrain", "marker": {"color": "#19d3f3"}, "name": "country_name=Bahrain", "offsetgroup": "country_name=Bahrain", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Military"], "xaxis": "x", "y": [-998.98], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [["2015", "Japan"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>industry_name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgr ...
#                         {"barmode": "relative", "height": 400, "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#4
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="04ec96ae-cac1-4ff0-acc6-e0f512411260" class="plotly-graph-div" style="height:400px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("04ec96ae-cac1-4ff0-acc6-e0f512411260")) {
#                     Plotly.newPlot(
#                         '04ec96ae-cac1-4ff0-acc6-e0f512411260',
#                         [{"alignmentgroup": "True", "customdata": [["2016", "Kuwait"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>industry_name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=Kuwait", "marker": {"color": "#636efa"}, "name": "country_name=Kuwait", "offsetgroup": "country_name=Kuwait", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Military"], "xaxis": "x", "y": [-1876.78], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [["2016", "Korea, Rep."]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>industry_name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=Korea, Rep.", "marker": {"color": "#EF553B"}, "name": "country_name=Korea, Rep.", "offsetgroup": "country_name=Korea, Rep.", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Military"], "xaxis": "x", "y": [-1630.7], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [["2016", "Venezuela, RB"], ["2016", "Venezuela, RB"], ["2016", "Venezuela, RB"], ["2016", "Venezuela, RB"], ["2016", "Venezuela, RB"], ["2016", "Venezuela, RB"], ["2016", "Venezuela, RB"], ["2016", "Venezuela, RB"], ["2016", "Venezuela, RB"], ["2016", "Venezuela, RB"], ["2016", "Venezuela, RB"], ["2016", "Venezuela, RB"], ["2016", "Venezuela, RB"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>industry_name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=Venezuela, RB", "marker": {"color": "#00cc96"}, "name": "country_name=Venezuela, RB", "offsetgroup": "country_name=Venezuela, RB", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Investment Management", "Pharmaceuticals", "Telecommunications", "Information Technology & Services", "Marketing & Advertising", "Consumer Goods", "Food & Beverages", "Wine & Spirits", "Computer Software", "Hospitality", "Cosmetics", "Accounting", "Entertainment"], "xaxis": "x", "y": [-1442.65, -1336.51, -1129.7, -1113.19, -1091.2, -1026.22, -1022.03, -980.76, -952.88, -927.38, -910.55, -908.77, -906.04], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [["2016", "Bahrain"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>industry_name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=Bahrain", "marker": {"color": "#ab63fa"}, "name": "country_name=Bahrain", "offsetgroup": "country_name=Bahrain", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Military"], "xaxis": "x", "y": [-1174.17], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [["2016", "Nigeria"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>industry_name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=Nigeria", "marker": {"color": "#FFA15A"}, "name": "country_name=Nigeria", "offsetgroup": "country_name=Nigeria", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Military"], "xaxis": "x", "y": [-1070.38], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [["2016", "Ireland"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>industry_name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=Ireland", "marker": {"color": "#19d3f3"}, "name": "country_name=Ireland", "offsetgroup": "country_name=Ireland", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["International Affairs"], "xaxis": "x", "y": [-1004.18], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [["2016", "Afghanistan"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>industry_name=%{x}<br>Net ...
#                         {"barmode": "relative", "height": 400, "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscal
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="d567461b-45cd-4482-b979-1aa67048e6b9" class="plotly-graph-div" style="height:400px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d567461b-45cd-4482-b979-1aa67048e6b9")) {
#                     Plotly.newPlot(
#                         'd567461b-45cd-4482-b979-1aa67048e6b9',
#                         [{"alignmentgroup": "True", "customdata": [["2017", "Venezuela, RB"], ["2017", "Venezuela, RB"], ["2017", "Venezuela, RB"], ["2017", "Venezuela, RB"], ["2017", "Venezuela, RB"], ["2017", "Venezuela, RB"], ["2017", "Venezuela, RB"], ["2017", "Venezuela, RB"], ["2017", "Venezuela, RB"], ["2017", "Venezuela, RB"], ["2017", "Venezuela, RB"], ["2017", "Venezuela, RB"], ["2017", "Venezuela, RB"], ["2017", "Venezuela, RB"], ["2017", "Venezuela, RB"], ["2017", "Venezuela, RB"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>industry_name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=Venezuela, RB", "marker": {"color": "#636efa"}, "name": "country_name=Venezuela, RB", "offsetgroup": "country_name=Venezuela, RB", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Information Technology & Services", "Wine & Spirits", "Marketing & Advertising", "Pharmaceuticals", "Telecommunications", "Food & Beverages", "Hospitality", "Accounting", "Investment Management", "Computer Software", "Civil Engineering", "Consumer Goods", "Management Consulting", "Automotive", "Cosmetics", "Internet"], "xaxis": "x", "y": [-1577.24, -1508.22, -1500.16, -1497.64, -1395.35, -1394.08, -1335.87, -1333.38, -1314.84, -1314.74, -1303.1, -1299.21, -1269.07, -1237.54, -1234.11, -1230.88], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [["2017", "Kuwait"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>industry_name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=Kuwait", "marker": {"color": "#EF553B"}, "name": "country_name=Kuwait", "offsetgroup": "country_name=Kuwait", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Military"], "xaxis": "x", "y": [-1495.33], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [["2017", "Pakistan"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>industry_name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=Pakistan", "marker": {"color": "#00cc96"}, "name": "country_name=Pakistan", "offsetgroup": "country_name=Pakistan", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Staffing & Recruiting"], "xaxis": "x", "y": [-1318.98], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [["2017", "Nigeria"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>industry_name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=Nigeria", "marker": {"color": "#ab63fa"}, "name": "country_name=Nigeria", "offsetgroup": "country_name=Nigeria", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Military"], "xaxis": "x", "y": [-1304.35], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [["2017", "Cyprus"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>industry_name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=Cyprus", "marker": {"color": "#FFA15A"}, "name": "country_name=Cyprus", "offsetgroup": "country_name=Cyprus", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Military"], "xaxis": "x", "y": [-1201.0], "yaxis": "y"}],
#                         {"barmode": "relative", "height": 400, "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type":
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="cafc6748-6c10-4317-90ab-0dccc8e00449" class="plotly-graph-div" style="height:400px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("cafc6748-6c10-4317-90ab-0dccc8e00449")) {
#                     Plotly.newPlot(
#                         'cafc6748-6c10-4317-90ab-0dccc8e00449',
#                         [{"alignmentgroup": "True", "customdata": [["2018", "Cyprus"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>industry_name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=Cyprus", "marker": {"color": "#636efa"}, "name": "country_name=Cyprus", "offsetgroup": "country_name=Cyprus", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Military"], "xaxis": "x", "y": [-2025.55], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [["2018", "Nigeria"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>industry_name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=Nigeria", "marker": {"color": "#EF553B"}, "name": "country_name=Nigeria", "offsetgroup": "country_name=Nigeria", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Military"], "xaxis": "x", "y": [-1916.87], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [["2018", "Venezuela, RB"], ["2018", "Venezuela, RB"], ["2018", "Venezuela, RB"], ["2018", "Venezuela, RB"], ["2018", "Venezuela, RB"], ["2018", "Venezuela, RB"], ["2018", "Venezuela, RB"], ["2018", "Venezuela, RB"], ["2018", "Venezuela, RB"], ["2018", "Venezuela, RB"], ["2018", "Venezuela, RB"], ["2018", "Venezuela, RB"], ["2018", "Venezuela, RB"], ["2018", "Venezuela, RB"], ["2018", "Venezuela, RB"], ["2018", "Venezuela, RB"], ["2018", "Venezuela, RB"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>industry_name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=Venezuela, RB", "marker": {"color": "#00cc96"}, "name": "country_name=Venezuela, RB", "offsetgroup": "country_name=Venezuela, RB", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Civil Engineering", "Information Technology & Services", "Wine & Spirits", "Marketing & Advertising", "Accounting", "Hospitality", "Architecture & Planning", "Computer Software", "Internet", "Telecommunications", "Management Consulting", "Mechanical or Industrial Engineering", "Pharmaceuticals", "Automotive", "Food & Beverages", "Investment Management", "Chemicals"], "xaxis": "x", "y": [-1786.84, -1784.12, -1761.89, -1686.15, -1682.98, -1639.55, -1619.05, -1618.44, -1589.19, -1566.75, -1526.6, -1525.64, -1495.16, -1427.68, -1380.75, -1367.07, -1366.86], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [["2018", "Nepal"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>industry_name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=Nepal", "marker": {"color": "#ab63fa"}, "name": "country_name=Nepal", "offsetgroup": "country_name=Nepal", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Higher Education"], "xaxis": "x", "y": [-1745.8], "yaxis": "y"}],
#                         {"barmode": "relative", "height": 400, "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "ty ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="0ebbf61c-4fbb-4796-8c9b-17094df38acb" class="plotly-graph-div" style="height:400px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0ebbf61c-4fbb-4796-8c9b-17094df38acb")) {
#                     Plotly.newPlot(
#                         '0ebbf61c-4fbb-4796-8c9b-17094df38acb',
#                         [{"alignmentgroup": "True", "customdata": [["2019", "Nigeria"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>industry_name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=Nigeria", "marker": {"color": "#636efa"}, "name": "country_name=Nigeria", "offsetgroup": "country_name=Nigeria", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Military"], "xaxis": "x", "y": [-3367.37], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [["2019", "Nepal"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>industry_name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=Nepal", "marker": {"color": "#EF553B"}, "name": "country_name=Nepal", "offsetgroup": "country_name=Nepal", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Higher Education"], "xaxis": "x", "y": [-1943.62], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [["2019", "Venezuela, RB"], ["2019", "Venezuela, RB"], ["2019", "Venezuela, RB"], ["2019", "Venezuela, RB"], ["2019", "Venezuela, RB"], ["2019", "Venezuela, RB"], ["2019", "Venezuela, RB"], ["2019", "Venezuela, RB"], ["2019", "Venezuela, RB"], ["2019", "Venezuela, RB"], ["2019", "Venezuela, RB"], ["2019", "Venezuela, RB"], ["2019", "Venezuela, RB"], ["2019", "Venezuela, RB"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>industry_name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=Venezuela, RB", "marker": {"color": "#00cc96"}, "name": "country_name=Venezuela, RB", "offsetgroup": "country_name=Venezuela, RB", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Hospitality", "Information Technology & Services", "Mechanical or Industrial Engineering", "Marketing & Advertising", "Civil Engineering", "Computer Software", "Internet", "Architecture & Planning", "Human Resources", "Management Consulting", "Construction", "Wine & Spirits", "Accounting", "Automotive"], "xaxis": "x", "y": [-1566.87, -1355.99, -1256.52, -1232.29, -1231.36, -1227.89, -1192.64, -1156.9, -1116.39, -1091.74, -1073.87, -1064.3, -1036.77, -1009.88], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [["2019", "Cyprus"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>industry_name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=Cyprus", "marker": {"color": "#ab63fa"}, "name": "country_name=Cyprus", "offsetgroup": "country_name=Cyprus", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Military"], "xaxis": "x", "y": [-1418.72], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [["2019", "Bahrain"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>industry_name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=Bahrain", "marker": {"color": "#FFA15A"}, "name": "country_name=Bahrain", "offsetgroup": "country_name=Bahrain", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Military"], "xaxis": "x", "y": [-1111.57], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [["2019", "Cameroon"]], "hoverlabel": {"namelength": 0}, "hovertemplate": "country_name=%{customdata[1]}<br>industry_name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}", "legendgroup": "country_name=Cameroon", "marker": {"color": "#19d3f3"}, "name": "country_name=Cameroon", "offsetgroup": "country_name=Cameroon", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Higher Education"], "xaxis": "x", "y": [-1086.73], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [["2019", "Tunisia"]], "hoverlabel": {"namelength": 0}, "hovertemplat ...
#                         {"barmode": "relative", "height": 400, "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.11111

# %%
df_3.head()
# Out:
#   base_country_code     base_country_name  ...  Unnamed: 24  Unnamed: 25
# 0                ae  United Arab Emirates  ...          NaN          NaN
# 1                ae  United Arab Emirates  ...          NaN          NaN
# 2                ae  United Arab Emirates  ...          NaN          NaN
# 3                ae  United Arab Emirates  ...          NaN          NaN
# 4                ae  United Arab Emirates  ...          NaN          NaN
#
# [5 rows x 26 columns]

# %%
df_3.shape
# Out:
# (4148, 26)

# %%
df_3.isnull().sum()
# Out:
# base_country_code              0
# base_country_name              0
# base_lat                       0
# base_long                      0
# base_country_wb_income         0
# base_country_wb_region         0
# target_country_code            0
# target_country_name            0
# target_lat                     0
# target_long                    0
# target_country_wb_income       0
# target_country_wb_region       0
# net_per_10K_2015               0
# net_per_10K_2016               0
# net_per_10K_2017               0
# net_per_10K_2018               0
# net_per_10K_2019               0
# Unnamed: 17                 4148
# Unnamed: 18                 4148
# Unnamed: 19                 4148
# Unnamed: 20                 4148
# Unnamed: 21                 4148
# Unnamed: 22                 4148
# Unnamed: 23                 4148
# Unnamed: 24                 4148
# Unnamed: 25                 4148
# dtype: int64

# %%
df_3_1=df_3.drop(columns=['Unnamed: 17','Unnamed: 18','Unnamed: 19','Unnamed: 20','Unnamed: 21','Unnamed: 22','Unnamed: 23','Unnamed: 24','Unnamed: 25'])
df_3_1.head()
# Out:
#   base_country_code     base_country_name  ...  net_per_10K_2018  net_per_10K_2019
# 0                ae  United Arab Emirates  ...             -0.05             -0.02
# 1                ae  United Arab Emirates  ...              0.55              0.78
# 2                ae  United Arab Emirates  ...             -0.02             -0.06
# 3                ae  United Arab Emirates  ...              0.01              0.23
# 4                ae  United Arab Emirates  ...             -0.01              0.02
#
# [5 rows x 17 columns]

# %%
#Renaming the columns

df_3_2= df_3_1.rename({'net_per_10K_2015': '2015', 'net_per_10K_2016': '2016', 'net_per_10K_2017': '2017', 'net_per_10K_2018': '2018', 'net_per_10K_2019': '2019'}, axis=1)
df_3_2.head()
# Out:
#   base_country_code     base_country_name   base_lat  ...  2017  2018  2019
# 0                ae  United Arab Emirates  23.424076  ...  0.11 -0.05 -0.02
# 1                ae  United Arab Emirates  23.424076  ...  0.57  0.55  0.78
# 2                ae  United Arab Emirates  23.424076  ...  0.11 -0.02 -0.06
# 3                ae  United Arab Emirates  23.424076  ...  0.04  0.01  0.23
# 4                ae  United Arab Emirates  23.424076  ...  0.03 -0.01  0.02
#
# [5 rows x 17 columns]

# %%
df_3_tidy=pd.melt(df_3_2,
             id_vars=['base_country_code','base_country_name','base_lat','base_long','base_country_wb_income','base_country_wb_region','target_country_code','target_country_name','target_lat','target_long','target_country_wb_income','target_country_wb_region'],
             var_name='Year',
             value_name='value' #giving the column name as 'value' because I need to combine all 4 datasets at the end
                  )
df_3_tidy.head()
# Out:
#   base_country_code     base_country_name  ...  Year  value
# 0                ae  United Arab Emirates  ...  2015   0.19
# 1                ae  United Arab Emirates  ...  2015   0.19
# 2                ae  United Arab Emirates  ...  2015  -0.01
# 3                ae  United Arab Emirates  ...  2015   0.16
# 4                ae  United Arab Emirates  ...  2015   0.10
#
# [5 rows x 14 columns]

# %%
df_3_3=df_3_tidy.sort_values(by='value',ascending=False).query('Year=="2015"').head(50)
df_3_3.head()
# Out:
#      base_country_code     base_country_name  ...  Year   value
# 2487                lu            Luxembourg  ...  2015  150.68
# 33                  ae  United Arab Emirates  ...  2015   91.75
# 3260                qa                 Qatar  ...  2015   71.44
# 3041                pa                Panama  ...  2015   60.58
# 2780                ng               Nigeria  ...  2015   55.30
#
# [5 rows x 14 columns]

# %%
df_3_3 = df_3_3[df_3_3["base_country_name"]!="Net"]

# %%
df_3_grouped = df_3_3.groupby(by=["base_country_name","target_country_name"]).sum()[["value"]]
df_3_grouped = df_3_grouped.reset_index()
df_3_grouped.head()
# Out:
#   base_country_name target_country_name  value
# 0            Angola            Portugal  23.24
# 1            Angola       United States  22.10
# 2           Bahrain               India  36.85
# 3          Botswana      United Kingdom  15.88
# 4  Congo, Dem. Rep.              France  15.40

# %%
import numpy as np
import holoviews as hv
import plotly.graph_objects as go

# %%
#hv.extension('bokeh')

# %%
all_nodes = df_3_grouped.base_country_name.values.tolist() + df_3_grouped.target_country_name.values.tolist()

# %%
source_indices = [all_nodes.index(country) for country in df_3_grouped.base_country_name]

# %%
target_indices = [all_nodes.index(measure) for measure in df_3_grouped.target_country_name]

# %%
colors = px.colors.qualitative.D3

node_colors_mappings = dict([(node,np.random.choice(colors)) for node in all_nodes])
node_colors = [node_colors_mappings[node] for node in all_nodes]
edge_colors = [node_colors_mappings[node] for node in df_3_grouped.base_country_name]

# %%
fig = go.Figure(data=[go.Sankey(
    node = dict(
      pad = 20,
      thickness = 20,
      line = dict(color = "black", width = 1.0),
      label =  all_nodes,
      color =  node_colors,
    ),

    link = dict(
      source =  source_indices,
      target =  target_indices,
      value =  df_3_grouped.value,
      color = edge_colors,
))])
fig.update_layout(title_text="Population Migration between New Zealand and European Countries",
                  height=600,
                  font_size=10,)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="73287896-2422-45bc-b35b-712fa28a5310" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("73287896-2422-45bc-b35b-712fa28a5310")) {
#                     Plotly.newPlot(
#                         '73287896-2422-45bc-b35b-712fa28a5310',
#                         [{"link": {"color": ["#E377C2", "#E377C2", "#2CA02C", "#FF7F0E", "#E377C2", "#E377C2", "#2CA02C", "#2CA02C", "#E377C2", "#E377C2", "#8C564B", "#17BECF", "#BCBD22", "#D62728", "#BCBD22", "#FF7F0E", "#17BECF", "#17BECF", "#17BECF", "#17BECF", "#D62728", "#D62728", "#D62728", "#FF7F0E", "#D62728", "#9467BD", "#9467BD", "#9467BD", "#9467BD", "#9467BD", "#E377C2", "#8C564B", "#8C564B", "#2CA02C", "#2CA02C", "#D62728", "#D62728", "#1F77B4", "#8C564B", "#BCBD22", "#7F7F7F", "#7F7F7F", "#BCBD22", "#9467BD", "#9467BD", "#9467BD", "#FF7F0E", "#BCBD22", "#BCBD22", "#9467BD"], "source": [0, 0, 2, 3, 4, 4, 6, 7, 8, 8, 10, 11, 12, 13, 14, 15, 16, 16, 16, 16, 20, 20, 22, 23, 24, 25, 25, 27, 27, 29, 30, 31, 31, 33, 33, 35, 35, 37, 38, 39, 40, 41, 42, 43, 43, 43, 46, 47, 47, 49], "target": [50, 51, 52, 53, 54, 51, 56, 51, 54, 51, 51, 51, 51, 51, 51, 52, 66, 54, 68, 69, 53, 51, 51, 69, 51, 38, 51, 53, 51, 52, 80, 81, 51, 83, 52, 52, 51, 52, 51, 51, 54, 51, 51, 52, 94, 51, 96, 53, 51, 51], "value": [23.24, 22.1, 36.85, 15.88, 15.4, 34.27, 21.11, 19.49, 28.58, 17.09, 20.21, 17.66, 17.87, 32.47, 40.35, 32.55, 49.67, 150.68, 25.37, 16.47, 15.85, 49.82, 15.19, 20.1, 21.69, 20.9, 22.39, 55.3, 37.12, 22.82, 60.58, 45.58, 29.81, 15.62, 71.44, 23.94, 29.05, 20.27, 21.3, 28.93, 36.12, 29.6, 20.1, 91.75, 23.63, 17.0, 23.38, 43.27, 33.6, 38.6]}, "node": {"color": ["#E377C2", "#E377C2", "#2CA02C", "#FF7F0E", "#E377C2", "#E377C2", "#2CA02C", "#2CA02C", "#E377C2", "#E377C2", "#8C564B", "#17BECF", "#BCBD22", "#D62728", "#BCBD22", "#FF7F0E", "#17BECF", "#17BECF", "#17BECF", "#17BECF", "#D62728", "#D62728", "#D62728", "#FF7F0E", "#D62728", "#9467BD", "#9467BD", "#9467BD", "#9467BD", "#9467BD", "#E377C2", "#8C564B", "#8C564B", "#2CA02C", "#2CA02C", "#D62728", "#D62728", "#1F77B4", "#8C564B", "#BCBD22", "#7F7F7F", "#7F7F7F", "#BCBD22", "#9467BD", "#9467BD", "#9467BD", "#FF7F0E", "#BCBD22", "#BCBD22", "#9467BD", "#2CA02C", "#D62728", "#E377C2", "#FF7F0E", "#BCBD22", "#D62728", "#FF7F0E", "#D62728", "#BCBD22", "#D62728", "#D62728", "#D62728", "#D62728", "#D62728", "#D62728", "#E377C2", "#7F7F7F", "#BCBD22", "#17BECF", "#BCBD22", "#FF7F0E", "#D62728", "#D62728", "#BCBD22", "#D62728", "#8C564B", "#D62728", "#FF7F0E", "#D62728", "#E377C2", "#7F7F7F", "#D62728", "#D62728", "#1F77B4", "#E377C2", "#E377C2", "#D62728", "#E377C2", "#D62728", "#D62728", "#BCBD22", "#D62728", "#D62728", "#E377C2", "#FF7F0E", "#D62728", "#FF7F0E", "#FF7F0E", "#D62728", "#D62728"], "label": ["Angola", "Angola", "Bahrain", "Botswana", "Congo, Dem. Rep.", "Congo, Dem. Rep.", "Cyprus", "Ethiopia", "Gabon", "Gabon", "Georgia", "Ghana", "Indonesia", "Iran, Islamic Rep.", "Kenya", "Kuwait", "Luxembourg", "Luxembourg", "Luxembourg", "Luxembourg", "Malawi", "Malawi", "Mali", "Malta", "Mozambique", "Namibia", "Namibia", "Nigeria", "Nigeria", "Oman", "Panama", "Papua New Guinea", "Papua New Guinea", "Qatar", "Qatar", "Saudi Arabia", "Saudi Arabia", "Singapore", "South Africa", "Sudan", "Switzerland", "Tanzania", "Uganda", "United Arab Emirates", "United Arab Emirates", "United Arab Emirates", "West Bank and Gaza", "Zambia", "Zambia", "Zimbabwe", "Portugal", "United States", "India", "United Kingdom", "France", "United States", "Turkey", "United States", "France", "United States", "United States", "United States", "United States", "United States", "United States", "India", "Belgium", "France", "Germany", "Italy", "United Kingdom", "United States", "United States", "Italy", "United States", "South Africa", "United States", "United Kingdom", "United States", "India", "Venezuela, RB", "Australia", "United States", "Egypt, Arab Rep.", "India", "India", "United States", "India", "United States", "United States", "France", "United States", "United States", "India", "Pakistan", "United States", "Israel", "United Kingdom", "United States", "United States"], "line": {"color": "black", "width": 1.0}, "pad": 20, "thickness": 20}, "type": "sankey"}],
#                         {"font": {"size": 10}, "height": 600, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin":

# %%
df_4_1=df_3_tidy.sort_values(by='value',ascending=False).query('Year=="2016"').head(50)
df_4_1.head()
# Out:
#      base_country_code     base_country_name  ...  Year   value
# 6635                lu            Luxembourg  ...  2016  124.48
# 4181                ae  United Arab Emirates  ...  2016   77.43
# 7408                qa                 Qatar  ...  2016   59.31
# 6770                mw                Malawi  ...  2016   48.52
# 6628                lu            Luxembourg  ...  2016   42.73
#
# [5 rows x 14 columns]

# %%
df_4_1 = df_4_1[df_4_1["base_country_name"]!="Net"]
df_4_grouped = df_4_1.groupby(by=["base_country_name","target_country_name"]).sum()[["value"]]
df_4_grouped = df_4_grouped.reset_index()
df_4_grouped.head()
# Out:
#   base_country_name target_country_name  value
# 0            Angola       United States  13.74
# 1         Australia               India  13.38
# 2           Bahrain               India  26.99
# 3             Chile       Venezuela, RB  17.54
# 4  Congo, Dem. Rep.              France  15.57

# %%
all_nodes_1 = df_4_grouped.base_country_name.values.tolist() + df_4_grouped.target_country_name.values.tolist()
source_indices_1 = [all_nodes_1.index(country) for country in df_4_grouped.base_country_name]
target_indices_1 = [all_nodes_1.index(measure) for measure in df_4_grouped.target_country_name]

colors = px.colors.qualitative.D3

node_colors_mappings_1 = dict([(node,np.random.choice(colors)) for node in all_nodes_1])
# node_colors_1 = [node_colors_mappings_1[node] for node in all_nodes]
# edge_colors_1 = [node_colors_mappings_1[node] for node in df_4_grouped.base_country_name]

# %%
fig_1 = go.Figure(data=[go.Sankey(
    node = dict(
      pad = 30,
      thickness = 30,
      line = dict(color = "black", width = 1.0),
      label =  all_nodes_1,
      color =  node_colors,
    ),

    link = dict(
      source =  source_indices_1,
      target =  target_indices_1,
      value =  df_4_grouped.value,
      color = edge_colors,
))])
fig_1.update_layout(title_text="Net migration of workers between countries for the year 2016",
                  height=600,
                  font_size=10,xaxis={'categoryorder':'total ascending'})
fig_1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="adc7eafb-f1d5-4a21-8778-d9176d69d4c2" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("adc7eafb-f1d5-4a21-8778-d9176d69d4c2")) {
#                     Plotly.newPlot(
#                         'adc7eafb-f1d5-4a21-8778-d9176d69d4c2',
#                         [{"link": {"color": ["#E377C2", "#E377C2", "#2CA02C", "#FF7F0E", "#E377C2", "#E377C2", "#2CA02C", "#2CA02C", "#E377C2", "#E377C2", "#8C564B", "#17BECF", "#BCBD22", "#D62728", "#BCBD22", "#FF7F0E", "#17BECF", "#17BECF", "#17BECF", "#17BECF", "#D62728", "#D62728", "#D62728", "#FF7F0E", "#D62728", "#9467BD", "#9467BD", "#9467BD", "#9467BD", "#9467BD", "#E377C2", "#8C564B", "#8C564B", "#2CA02C", "#2CA02C", "#D62728", "#D62728", "#1F77B4", "#8C564B", "#BCBD22", "#7F7F7F", "#7F7F7F", "#BCBD22", "#9467BD", "#9467BD", "#9467BD", "#FF7F0E", "#BCBD22", "#BCBD22", "#9467BD"], "source": [0, 1, 2, 3, 4, 4, 6, 6, 8, 9, 9, 11, 11, 13, 13, 13, 13, 17, 18, 18, 20, 21, 22, 22, 24, 25, 25, 27, 28, 29, 29, 31, 31, 33, 34, 34, 36, 36, 38, 39, 39, 41, 42, 43, 43, 43, 46, 47, 47, 49], "target": [50, 51, 51, 53, 54, 50, 56, 57, 50, 59, 50, 61, 51, 63, 54, 65, 66, 50, 66, 69, 50, 36, 38, 50, 51, 69, 50, 51, 53, 1, 50, 61, 51, 50, 51, 50, 51, 87, 50, 54, 65, 50, 50, 51, 94, 95, 96, 69, 50, 50], "value": [13.74, 13.38, 26.99, 17.54, 15.57, 16.63, 10.88, 23.53, 13.03, 12.68, 39.1, 12.32, 36.45, 42.73, 124.48, 22.88, 18.08, 48.52, 14.77, 18.82, 13.8, 17.14, 14.14, 16.75, 16.59, 27.59, 20.37, 18.86, 39.85, 31.94, 10.68, 13.92, 59.31, 18.79, 17.76, 17.19, 14.29, 14.23, 13.6, 28.36, 10.65, 19.93, 16.81, 77.43, 17.44, 12.07, 20.04, 27.6, 28.55, 37.76]}, "node": {"color": ["#E377C2", "#E377C2", "#2CA02C", "#1F77B4", "#2CA02C", "#2CA02C", "#17BECF", "#9467BD", "#8C564B", "#8C564B", "#17BECF", "#2CA02C", "#7F7F7F", "#D62728", "#BCBD22", "#BCBD22", "#1F77B4", "#1F77B4", "#1F77B4", "#1F77B4", "#7F7F7F", "#7F7F7F", "#2CA02C", "#2CA02C", "#2CA02C", "#FF7F0E", "#FF7F0E", "#1F77B4", "#1F77B4", "#BCBD22", "#D62728", "#9467BD", "#9467BD", "#D62728", "#D62728", "#7F7F7F", "#7F7F7F", "#D62728", "#17BECF", "#E377C2", "#9467BD", "#7F7F7F", "#1F77B4", "#2CA02C", "#2CA02C", "#2CA02C", "#17BECF", "#D62728", "#D62728", "#2CA02C", "#D62728", "#E377C2", "#8C564B", "#E377C2", "#FF7F0E", "#E377C2", "#8C564B", "#E377C2", "#FF7F0E", "#E377C2", "#E377C2", "#E377C2", "#E377C2", "#E377C2", "#E377C2", "#8C564B", "#7F7F7F", "#FF7F0E", "#FF7F0E", "#7F7F7F", "#E377C2", "#E377C2", "#E377C2", "#7F7F7F", "#E377C2", "#17BECF", "#E377C2", "#E377C2", "#E377C2", "#8C564B", "#7F7F7F", "#7F7F7F", "#E377C2", "#2CA02C", "#8C564B", "#8C564B", "#E377C2", "#8C564B", "#E377C2", "#E377C2", "#FF7F0E", "#E377C2", "#E377C2", "#8C564B", "#D62728", "#E377C2", "#1F77B4", "#E377C2", "#E377C2", "#E377C2"], "label": ["Angola", "Australia", "Bahrain", "Chile", "Congo, Dem. Rep.", "Congo, Dem. Rep.", "Cyprus", "Cyprus", "Ghana", "Kenya", "Kenya", "Kuwait", "Kuwait", "Luxembourg", "Luxembourg", "Luxembourg", "Luxembourg", "Malawi", "Malta", "Malta", "Mozambique", "Myanmar", "Namibia", "Namibia", "New Zealand", "Nigeria", "Nigeria", "Oman", "Panama", "Papua New Guinea", "Papua New Guinea", "Qatar", "Qatar", "Rwanda", "Saudi Arabia", "Saudi Arabia", "Singapore", "Singapore", "South Africa", "Switzerland", "Switzerland", "Tanzania", "Uganda", "United Arab Emirates", "United Arab Emirates", "United Arab Emirates", "West Bank and Gaza", "Zambia", "Zambia", "Zimbabwe", "United States", "India", "India", "Venezuela, RB", "France", "United States", "Greece", "Turkey", "United States", "Norway", "United States", "Egypt, Arab Rep.", "India", "Belgium", "France", "Germany", "Italy", "United States", "Italy", "United Kingdom", "United States", "Singapore", "South Africa", "United States", "India", "United Kingdom", "United States", "India", "Venezuela, RB", "Australia", "United States", "Egypt, Arab Rep.", "India", "United States", "India", "United States", "India", "Malaysia", "United States", "France", "Germany", "United States", "United States", "India", "Pakistan", "Philippines", "Israel", "United Kingdom", "United States", "United States"], "line": {"color": "black", "width": 1.0}, "pad": 30, "thickness": 30}, "type": "sankey"}],
#                         {"font": {"size": 10}, "height": 600, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scat

# %%
df_5_1=df_3_tidy.sort_values(by='value',ascending=False).query('Year=="2017"').head(50)
df_5_1.head()
# Out:
#       base_country_code     base_country_name  ...  Year  value
# 10783                lu            Luxembourg  ...  2017  87.00
# 8329                 ae  United Arab Emirates  ...  2017  54.55
# 11556                qa                 Qatar  ...  2017  33.18
# 9274                 cy                Cyprus  ...  2017  29.38
# 10776                lu            Luxembourg  ...  2017  28.53
#
# [5 rows x 14 columns]

# %%
df_5_1 = df_5_1[df_5_1["base_country_name"]!="Net"]
df_5_grouped = df_5_1.groupby(by=["base_country_name","target_country_name"]).sum()[["value"]]
df_5_grouped = df_5_grouped.reset_index()
df_5_grouped.head()
# Out:
#   base_country_name target_country_name  value
# 0         Argentina       Venezuela, RB  10.65
# 1         Australia               India  16.10
# 2           Bahrain               India  16.66
# 3            Canada               India  11.81
# 4             Chile       Venezuela, RB  26.02

# %%
all_nodes_2 = df_5_grouped.base_country_name.values.tolist() + df_5_grouped.target_country_name.values.tolist()
source_indices_2 = [all_nodes_2.index(country) for country in df_5_grouped.base_country_name]
target_indices_2 = [all_nodes_2.index(measure) for measure in df_5_grouped.target_country_name]

colors = px.colors.qualitative.D3

node_colors_mappings_2 = dict([(node,np.random.choice(colors)) for node in all_nodes_2])

# %%
fig_2 = go.Figure(data=[go.Sankey(
    node = dict(
      pad = 50,
      thickness = 50,
      line = dict(color = "black", width = 1.0),
      label =  all_nodes_2,
      color =  node_colors,
    ),

    link = dict(
      source =  source_indices_2,
      target =  target_indices_2,
      value =  df_5_grouped.value,
      color = edge_colors,
))])
fig_2.update_layout(title_text="Net migration of workers between countries for the year 2017",
                  height=600,
                  font_size=10)
fig_2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="a24bdc19-bc30-4b86-ba22-2a56517fcb10" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a24bdc19-bc30-4b86-ba22-2a56517fcb10")) {
#                     Plotly.newPlot(
#                         'a24bdc19-bc30-4b86-ba22-2a56517fcb10',
#                         [{"link": {"color": ["#E377C2", "#E377C2", "#2CA02C", "#FF7F0E", "#E377C2", "#E377C2", "#2CA02C", "#2CA02C", "#E377C2", "#E377C2", "#8C564B", "#17BECF", "#BCBD22", "#D62728", "#BCBD22", "#FF7F0E", "#17BECF", "#17BECF", "#17BECF", "#17BECF", "#D62728", "#D62728", "#D62728", "#FF7F0E", "#D62728", "#9467BD", "#9467BD", "#9467BD", "#9467BD", "#9467BD", "#E377C2", "#8C564B", "#8C564B", "#2CA02C", "#2CA02C", "#D62728", "#D62728", "#1F77B4", "#8C564B", "#BCBD22", "#7F7F7F", "#7F7F7F", "#BCBD22", "#9467BD", "#9467BD", "#9467BD", "#FF7F0E", "#BCBD22", "#BCBD22", "#9467BD"], "source": [0, 1, 2, 3, 4, 5, 5, 5, 8, 9, 10, 11, 12, 12, 14, 15, 15, 17, 17, 17, 17, 17, 17, 17, 24, 25, 25, 27, 28, 29, 30, 30, 32, 33, 34, 35, 36, 37, 38, 38, 40, 41, 42, 42, 42, 45, 46, 47, 47, 49], "target": [50, 51, 51, 51, 50, 55, 56, 57, 50, 50, 51, 61, 62, 51, 64, 65, 51, 67, 68, 10, 51, 71, 72, 57, 64, 71, 57, 38, 78, 51, 51, 78, 50, 1, 62, 51, 64, 64, 51, 89, 68, 56, 65, 51, 94, 50, 96, 57, 64, 64], "value": [10.65, 16.1, 16.66, 11.81, 26.02, 8.38, 29.38, 11.21, 7.86, 9.67, 8.35, 9.16, 13.28, 9.99, 12.55, 10.4, 24.31, 28.53, 87.0, 19.07, 8.01, 16.57, 9.16, 15.77, 12.33, 12.76, 12.7, 9.95, 7.97, 8.36, 14.69, 8.64, 24.28, 26.05, 19.94, 33.18, 7.89, 15.1, 12.93, 13.4, 17.38, 10.81, 8.95, 54.55, 8.93, 8.68, 7.76, 7.88, 8.32, 10.09]}, "node": {"color": ["#E377C2", "#E377C2", "#2CA02C", "#1F77B4", "#2CA02C", "#2CA02C", "#17BECF", "#9467BD", "#8C564B", "#8C564B", "#17BECF", "#2CA02C", "#7F7F7F", "#D62728", "#BCBD22", "#BCBD22", "#1F77B4", "#1F77B4", "#1F77B4", "#1F77B4", "#7F7F7F", "#7F7F7F", "#2CA02C", "#2CA02C", "#2CA02C", "#FF7F0E", "#FF7F0E", "#1F77B4", "#1F77B4", "#BCBD22", "#D62728", "#9467BD", "#9467BD", "#D62728", "#D62728", "#7F7F7F", "#7F7F7F", "#D62728", "#17BECF", "#E377C2", "#9467BD", "#7F7F7F", "#1F77B4", "#2CA02C", "#2CA02C", "#2CA02C", "#17BECF", "#D62728", "#D62728", "#2CA02C", "#D62728", "#E377C2", "#8C564B", "#E377C2", "#FF7F0E", "#E377C2", "#8C564B", "#E377C2", "#FF7F0E", "#E377C2", "#E377C2", "#E377C2", "#E377C2", "#E377C2", "#E377C2", "#8C564B", "#7F7F7F", "#FF7F0E", "#FF7F0E", "#7F7F7F", "#E377C2", "#E377C2", "#E377C2", "#7F7F7F", "#E377C2", "#17BECF", "#E377C2", "#E377C2", "#E377C2", "#8C564B", "#7F7F7F", "#7F7F7F", "#E377C2", "#2CA02C", "#8C564B", "#8C564B", "#E377C2", "#8C564B", "#E377C2", "#E377C2", "#FF7F0E", "#E377C2", "#E377C2", "#8C564B", "#D62728", "#E377C2", "#1F77B4", "#E377C2", "#E377C2", "#E377C2"], "label": ["Argentina", "Australia", "Bahrain", "Canada", "Chile", "Cyprus", "Cyprus", "Cyprus", "Dominican Republic", "Ecuador", "Germany", "Hong Kong SAR, China", "Ireland", "Ireland", "Kenya", "Kuwait", "Kuwait", "Luxembourg", "Luxembourg", "Luxembourg", "Luxembourg", "Luxembourg", "Luxembourg", "Luxembourg", "Malawi", "Malta", "Malta", "Myanmar", "Namibia", "Nepal", "New Zealand", "New Zealand", "Panama", "Papua New Guinea", "Portugal", "Qatar", "Rwanda", "Saudi Arabia", "Singapore", "Singapore", "Switzerland", "Syrian Arab Republic", "United Arab Emirates", "United Arab Emirates", "United Arab Emirates", "Uruguay", "West Bank and Gaza", "Zambia", "Zambia", "Zimbabwe", "Venezuela, RB", "India", "India", "India", "Venezuela, RB", "Greece", "Turkey", "United Kingdom", "Venezuela, RB", "Venezuela, RB", "India", "China", "Brazil", "India", "United States", "Egypt, Arab Rep.", "India", "Belgium", "France", "Germany", "India", "Italy", "Spain", "United Kingdom", "United States", "Italy", "United Kingdom", "Singapore", "South Africa", "India", "India", "South Africa", "Venezuela, RB", "Australia", "Brazil", "India", "United States", "United States", "India", "Malaysia", "France", "Turkey", "Egypt, Arab Rep.", "India", "Philippines", "Venezuela, RB", "Israel", "United Kingdom", "United States", "United States"], "line": {"color": "black", "width": 1.0}, "pad": 50, "thickness": 50}, "type": "sankey"}],
#                         {"font": {"size": 10}, "height": 600, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewi
