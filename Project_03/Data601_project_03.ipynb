# %% [markdown]
# <a href="https://colab.research.google.com/github/ajitjadhav10/DATA601/blob/main/Project_03/Data601_project_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DATA 601 : Final Project
# #### Topic: Analysis of Linkedin user migration data
# #### Name: Ajit Jadhav
# #### Instructor: Prof. John Wan
#
# ----

# %% [markdown]
# ### Following are some of the definitions of the terms that are used in this project:
#
# - Skill Group – Skill groups categorize the 50,000 detailed individual skills into approximately 250 skills groups (some skill groups may be excluded based data quality considerations). Skill related metrics are presented at the skill group rather than detailed skill level.
#
# - Migration Overview  – All the metrics are based on net migration (arrivals minus departures). These net migration figures are each normalized differently to enable fairer comparisons across samples. We calculate all on an annual basis, and report an average of the last three years.
#
# - Country Migration – Inter and intra country talent migration.  Based on user-reported location. When a user’s updated job location is different from their former location, LinkedIn recognizes this as a physical migration. Given as the net gain or loss of members from another country divided by the average LinkedIn membership of the target (or selected) country during the time period, multiplied by 10,000.
#
# - Industry Migration – Industries gained and lost. Based on the industry associated with a member’s company at the time of migration. The net gain or loss of members from another country working in a given industry divided by the number of LinkedIn members working in that industry in the target (or selected) country, multiplied by 10,000.
#
# - Skill Migration – Skills gained and lost. Based on the skills associated with a member’s profile at the time of migration. The net gain or loss of members from another country with a given skill divided by the number of LinkedIn members with that skill in the target (or selected) country, multiplied by 10,000.

# %%
#Importing relevant libraries

import pandas as pd
import plotly.express as px
import plotly.io as pio

# %%
import plotly

print(plotly.__version__)
# Out:
# 5.4.0

# %%
# !pip install plotly --upgrade
# Out:
# Requirement already satisfied: plotly in /usr/local/lib/python3.7/dist-packages (5.4.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from plotly) (8.0.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from plotly) (1.15.0)

# %%
#Having a look at all the templates on offer

pio.templates
# Out:
# Templates configuration
# -----------------------
#     Default template: 'plotly'
#     Available templates:
#         ['ggplot2', 'seaborn', 'simple_white', 'plotly',
#          'plotly_white', 'plotly_dark', 'presentation', 'xgridoff',
#          'ygridoff', 'gridon', 'none']

# %%
#Selecting a template for visualizations

pio.templates.default = "plotly_dark"

# %% [markdown]
# #### Dataset 1: Linkedin Skill Migration Dataset(Migration of LinkedIn members at the country-skill level)
#
# - Here I've cleaned and plotted the skill migration data on a bar chart.
#
# ---

# %%
## All these data sets gave been downloaded from the world bank website and are free to use: 
#Link 1: https://datacatalog.worldbank.org/search/dataset/0038045/Employment-Growth---LinkedIn-Data-
#Link 2: https://datacatalog.worldbank.org/search/dataset/0038044/Talent-Migration---LinkedIn-Data-

# importing all the datasets
# df_1 is skill migration dataset
# df_2 is industry migration dataset
# df_3 is country migration dataset
# df_9 is industry employment growth dataset

df_1=pd.read_csv('https://raw.githubusercontent.com/ajitjadhav10/DATA601/main/Project_03/skill_migration_public%20(2).csv')
df_2=pd.read_csv('https://raw.githubusercontent.com/ajitjadhav10/DATA601/main/Project_03/industry_migration_public.csv')
df_3=pd.read_csv('https://raw.githubusercontent.com/ajitjadhav10/DATA601/main/Project_03/country_migration_public.csv')
df_9=pd.read_csv('https://raw.githubusercontent.com/ajitjadhav10/DATA601/main/Project_03/public_use-industry-employment-growth.csv')
df_1.head(5)
# Out:
#   country_code country_name   wb_income  ... Unnamed: 26  Unnamed: 27 Unnamed: 28
# 0           af  Afghanistan  Low income  ...         NaN          NaN         NaN
# 1           af  Afghanistan  Low income  ...         NaN          NaN         NaN
# 2           af  Afghanistan  Low income  ...         NaN          NaN         NaN
# 3           af  Afghanistan  Low income  ...         NaN          NaN         NaN
# 4           af  Afghanistan  Low income  ...         NaN          NaN         NaN
#
# [5 rows x 29 columns]

# %%
#Checking the no. of rows and columns of the dataset

df_1.shape
# Out:
# (20647, 29)

# %%
#Checking for null values

df_1.isnull().sum()
# Out:
# country_code             3030
# country_name             3030
# wb_income                3030
# wb_region                3030
# skill_group_id           3030
# skill_group_category     3030
# skill_group_name         3030
# net_per_10K_2015         3030
# net_per_10K_2016         3030
# net_per_10K_2017         3030
# net_per_10K_2018         3030
# net_per_10K_2019         3030
# Unnamed: 12             20647
# Unnamed: 13             20647
# Unnamed: 14             20647
# Unnamed: 15             20647
# Unnamed: 16             20647
# Unnamed: 17             20647
# Unnamed: 18             20647
# Unnamed: 19             20647
# Unnamed: 20             20647
# Unnamed: 21             20647
# Unnamed: 22             20647
# Unnamed: 23             20647
# Unnamed: 24             20647
# Unnamed: 25             20647
# Unnamed: 26             20647
# Unnamed: 27             20647
# Unnamed: 28             20647
# dtype: int64

# %%
# Dropping all the columns which start with 'Unnamed:' as they contain no data

df_1_1=df_1.drop(columns=['Unnamed: 12','Unnamed: 13','Unnamed: 14','Unnamed: 15','Unnamed: 16','Unnamed: 17','Unnamed: 18','Unnamed: 19','Unnamed: 20','Unnamed: 21','Unnamed: 22','Unnamed: 23','Unnamed: 24','Unnamed: 25','Unnamed: 26','Unnamed: 27','Unnamed: 28'])
df_1_1.head(5)
# Out:
#   country_code country_name  ... net_per_10K_2018 net_per_10K_2019
# 0           af  Afghanistan  ...          -680.92         -1208.79
# 1           af  Afghanistan  ...          -532.22          -790.09
# 2           af  Afghanistan  ...          -600.44          -767.64
# 3           af  Afghanistan  ...          -406.50          -739.51
# 4           af  Afghanistan  ...          -581.71          -718.64
#
# [5 rows x 12 columns]

# %%
#Renaming the four year columns so that we have only the year as the column header

df_1_2= df_1_1.rename({'net_per_10K_2015': '2015', 'net_per_10K_2016': '2016', 'net_per_10K_2017': '2017', 'net_per_10K_2018': '2018', 'net_per_10K_2019': '2019'}, axis=1)
df_1_2.head()
# Out:
#   country_code country_name   wb_income  ...    2017    2018     2019
# 0           af  Afghanistan  Low income  ... -550.04 -680.92 -1208.79
# 1           af  Afghanistan  Low income  ... -776.06 -532.22  -790.09
# 2           af  Afghanistan  Low income  ... -756.59 -600.44  -767.64
# 3           af  Afghanistan  Low income  ... -964.73 -406.50  -739.51
# 4           af  Afghanistan  Low income  ... -842.32 -581.71  -718.64
#
# [5 rows x 12 columns]

# %%
#Using melt function to convert the data into long format from wide format

df_1_tidy=pd.melt(df_1_2,
             id_vars=['country_code','country_name','wb_income','wb_region','skill_group_id','skill_group_category','skill_group_name'],
             var_name='Year',
             value_name='value' #giving the column name as 'value' because I need to combine all 4 datasets at the end
                  )
df_1_tidy.head(5)
# Out:
#   country_code country_name   wb_income  ...        skill_group_name  Year    value
# 0           af  Afghanistan  Low income  ...  Information Management  2015  -791.59
# 1           af  Afghanistan  Low income  ...  Operational Efficiency  2015 -1610.25
# 2           af  Afghanistan  Low income  ...       National Security  2015 -1731.45
# 3           af  Afghanistan  Low income  ...        Software Testing  2015  -957.50
# 4           af  Afghanistan  Low income  ...                    Navy  2015 -1510.71
#
# [5 rows x 9 columns]

# %%
#Dropping null values

df_1_3=df_1_tidy.dropna()
df_1_3.head()
# Out:
#   country_code country_name   wb_income  ...        skill_group_name  Year    value
# 0           af  Afghanistan  Low income  ...  Information Management  2015  -791.59
# 1           af  Afghanistan  Low income  ...  Operational Efficiency  2015 -1610.25
# 2           af  Afghanistan  Low income  ...       National Security  2015 -1731.45
# 3           af  Afghanistan  Low income  ...        Software Testing  2015  -957.50
# 4           af  Afghanistan  Low income  ...                    Navy  2015 -1510.71
#
# [5 rows x 9 columns]

# %%
# Now we can see there are no null values in the dataset

df_1_3.isnull().sum()
# Out:
# country_code            0
# country_name            0
# wb_income               0
# wb_region               0
# skill_group_id          0
# skill_group_category    0
# skill_group_name        0
# Year                    0
# value                   0
# dtype: int64

# %%
#Checking the number of rows and columns after dropping the null values

df_1_3.shape
# Out:
# (88085, 9)

# %%
#Sorting the table w.r.t descending order of the values column

df_1_5=df_1_3.sort_values(by='value',ascending=False).reset_index()
df_1_5.head()
# Out:
#    index country_code country_name  ...     skill_group_name  Year    value
# 0   9570           ml         Mali  ...                 Army  2015  2824.97
# 1  50864           ml         Mali  ...                 Army  2017  1906.14
# 2  87851           ge      Georgia  ...  Customer Experience  2019  1901.99
# 3   9239           lu   Luxembourg  ...      Time Management  2015  1799.39
# 4  29889           lu   Luxembourg  ...             Teamwork  2016  1796.89
#
# [5 rows x 10 columns]

# %% [markdown]
# ## Question 1: Which skills and which countries has seen the most influx of talent?

# %%
#Plotting net skill migration per 10k vs skill group (country wise)
# These 5 graphs show us the top 20 skill groups and the countries which have seen the most influx of talent in these skill groups.

#This graph is for the year 2015
fig_4 = px.bar(df_1_5.query('Year=="2015"').head(20), 
                x="skill_group_name", 
                y="value",
                title="Net skill-migration per 10,000 vs Skill - 2015",
                labels={"skill_group_name":"Skill group","value":"Net migration per 10k"},
                color="country_name",
                hover_data=['Year','country_name'],
                height=400
               ).update_xaxes(categoryorder="total descending")
#fig_4.update_traces(marker_size=40)
fig_4.show()

#This graph is for the year 2016
fig_5 = px.bar(df_1_5.query('Year=="2016"').head(20), 
                x="skill_group_name", 
                y="value",
                title="Net skill-migration per 10,000 vs Skill group - 2016",
                labels={"skill_group_name":"Skill group","value":"Net migration per 10k"},
                color="country_name",
                hover_data=['Year','country_name'],
                height=400
               ).update_xaxes(categoryorder="total descending")
fig_5.show()

#This graph is for the year 2017
fig_6 = px.bar(df_1_5.query('Year=="2017"').head(20), 
                x="skill_group_name", 
                y="value",
                title="Net skill-migration per 10,000 vs Skill group - 2017",
                labels={"skill_group_name":"Skill group","value":"Net migration per 10k"},
                color="country_name",
                hover_data=['Year','country_name'],
                height=400
               ).update_xaxes(categoryorder="total descending")
fig_6.show()

#This graph is for the year 2018
fig_7 = px.bar(df_1_5.query('Year=="2018"').head(20), 
                x="skill_group_name", 
                y="value",
                title="Net skill-migration per 10,000 vs Skill group - 2018",
                labels={"skill_group_name":"Skill group","value":"Net migration per 10k"},
                color="country_name",
                hover_data=['Year','country_name'],
                height=400
               ).update_xaxes(categoryorder="total descending")
fig_7.show()


#This graph is for the year 2019
fig_8 = px.bar(df_1_5.query('Year=="2019"').head(20), 
                x="skill_group_name", 
                y="value",
                title="Net skill-migration per 10,000 vs Skill group - 2019",
                labels={"skill_group_name":"Skill group","value":"Net migration per 10k"},
                color="country_name",
                hover_data=['Year','country_name'],
                height=400
               ).update_xaxes(categoryorder="total descending")
fig_8.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.6.3.min.js"></script>                <div id="b00faee8-ba40-4cf6-a449-4f2d73d1217f" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b00faee8-ba40-4cf6-a449-4f2d73d1217f")) {                    Plotly.newPlot(                        "b00faee8-ba40-4cf6-a449-4f2d73d1217f",                        [{"alignmentgroup":"True","customdata":[["2015","Mali"],["2015","Mali"],["2015","Mali"]],"hovertemplate":"country_name=%{customdata[1]}<br>Skill group=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"Mali","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Mali","offsetgroup":"Mali","orientation":"v","showlegend":true,"textposition":"auto","x":["Army","People Management","Inventory Management"],"xaxis":"x","y":[2824.97,1496.1,1290.32],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2015","Luxembourg"],["2015","Luxembourg"],["2015","Luxembourg"],["2015","Luxembourg"]],"hovertemplate":"country_name=%{customdata[1]}<br>Skill group=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"Luxembourg","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Luxembourg","offsetgroup":"Luxembourg","orientation":"v","showlegend":true,"textposition":"auto","x":["Time Management","Teamwork","Ground Transportation","Digital Literacy"],"xaxis":"x","y":[1799.39,1657.96,1297.47,1273.93],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2015","Congo, Dem. Rep."],["2015","Congo, Dem. Rep."]],"hovertemplate":"country_name=%{customdata[1]}<br>Skill group=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"Congo, Dem. Rep.","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Congo, Dem. Rep.","offsetgroup":"Congo, Dem. Rep.","orientation":"v","showlegend":true,"textposition":"auto","x":["Employee Learning & Development","Graphic Design"],"xaxis":"x","y":[1536.42,1381.07],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2015","Myanmar"],["2015","Myanmar"],["2015","Myanmar"],["2015","Myanmar"],["2015","Myanmar"],["2015","Myanmar"]],"hovertemplate":"country_name=%{customdata[1]}<br>Skill group=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"Myanmar","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Myanmar","offsetgroup":"Myanmar","orientation":"v","showlegend":true,"textposition":"auto","x":["Environmental Consulting","Higher Education","Economics","Investment Banking","Educational Administration","Commercial Banking"],"xaxis":"x","y":[1289.63,1278.91,1256.28,1216.92,1194.27,1185.36],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2015","Qatar"]],"hovertemplate":"country_name=%{customdata[1]}<br>Skill group=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"Qatar","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Qatar","offsetgroup":"Qatar","orientation":"v","showlegend":true,"textposition":"auto","x":["Scientific Computing"],"xaxis":"x","y":[1254.57],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2015","United Arab Emirates"],["2015","United Arab Emirates"],["2015","United Arab Emirates"]],"hovertemplate":"country_name=%{customdata[1]}<br>Skill group=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"United Arab Emirates","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"United Arab Emirates","offsetgroup":"United Arab Emirates","orientation":"v","showlegend":true,"textposition":"auto","x":["Scientific Computing","Physiology","Artificial Intelligence (AI)"],"xaxis":"x","y":[1246.71,1176.02,1171.89],"yaxis":"y","type":"bar"},{"alignmentgr ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.6.3.min.js"></script>                <div id="62c579f8-8de8-432c-a4fa-14c0eda3fab1" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("62c579f8-8de8-432c-a4fa-14c0eda3fab1")) {                    Plotly.newPlot(                        "62c579f8-8de8-432c-a4fa-14c0eda3fab1",                        [{"alignmentgroup":"True","customdata":[["2016","Luxembourg"],["2016","Luxembourg"],["2016","Luxembourg"],["2016","Luxembourg"],["2016","Luxembourg"],["2016","Luxembourg"],["2016","Luxembourg"],["2016","Luxembourg"],["2016","Luxembourg"],["2016","Luxembourg"],["2016","Luxembourg"],["2016","Luxembourg"],["2016","Luxembourg"],["2016","Luxembourg"],["2016","Luxembourg"]],"hovertemplate":"country_name=%{customdata[1]}<br>Skill group=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"Luxembourg","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Luxembourg","offsetgroup":"Luxembourg","orientation":"v","showlegend":true,"textposition":"auto","x":["Teamwork","Scientific Computing","Analytical Reasoning","Mathematics","Physics","Time Management","Problem Solving","Social Perceptiveness","Sales Leads","Artificial Intelligence (AI)","Machining","Bookkeeping","Digital Literacy","Communication","Data Science"],"xaxis":"x","y":[1796.89,1672.25,1646.73,1605.8,1512.06,1381.01,1295.96,1267.37,1191.49,1161.23,1129.51,1121.05,1081.06,1061.74,1036.65],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2016","Myanmar"],["2016","Myanmar"]],"hovertemplate":"country_name=%{customdata[1]}<br>Skill group=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"Myanmar","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Myanmar","offsetgroup":"Myanmar","orientation":"v","showlegend":true,"textposition":"auto","x":["Law","Environmental Science"],"xaxis":"x","y":[1187.17,1125.46],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2016","Kuwait"]],"hovertemplate":"country_name=%{customdata[1]}<br>Skill group=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"Kuwait","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Kuwait","offsetgroup":"Kuwait","orientation":"v","showlegend":true,"textposition":"auto","x":["Machining"],"xaxis":"x","y":[1153.11],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2016","Congo, Dem. Rep."]],"hovertemplate":"country_name=%{customdata[1]}<br>Skill group=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"Congo, Dem. Rep.","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Congo, Dem. Rep.","offsetgroup":"Congo, Dem. Rep.","orientation":"v","showlegend":true,"textposition":"auto","x":["Social Media"],"xaxis":"x","y":[1133.72],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2016","Panama"]],"hovertemplate":"country_name=%{customdata[1]}<br>Skill group=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"Panama","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Panama","offsetgroup":"Panama","orientation":"v","showlegend":true,"textposition":"auto","x":["Machining"],"xaxis":"x","y":[1046.28],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorg ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.6.3.min.js"></script>                <div id="23eca01b-c42e-480d-8467-fedb09443a86" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("23eca01b-c42e-480d-8467-fedb09443a86")) {                    Plotly.newPlot(                        "23eca01b-c42e-480d-8467-fedb09443a86",                        [{"alignmentgroup":"True","customdata":[["2017","Mali"]],"hovertemplate":"country_name=%{customdata[1]}<br>Skill group=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"Mali","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Mali","offsetgroup":"Mali","orientation":"v","showlegend":true,"textposition":"auto","x":["Army"],"xaxis":"x","y":[1906.14],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2017","Luxembourg"],["2017","Luxembourg"],["2017","Luxembourg"],["2017","Luxembourg"],["2017","Luxembourg"],["2017","Luxembourg"],["2017","Luxembourg"],["2017","Luxembourg"],["2017","Luxembourg"],["2017","Luxembourg"],["2017","Luxembourg"],["2017","Luxembourg"],["2017","Luxembourg"],["2017","Luxembourg"],["2017","Luxembourg"],["2017","Luxembourg"]],"hovertemplate":"country_name=%{customdata[1]}<br>Skill group=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"Luxembourg","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Luxembourg","offsetgroup":"Luxembourg","orientation":"v","showlegend":true,"textposition":"auto","x":["Teamwork","Time Management","Artificial Intelligence (AI)","Scientific Computing","Industrial Design","Machining","Mathematics","Data Science","Problem Solving","Product Testing","Analytical Reasoning","Game Development","Sales Leads","Communication","Physics","Organic Chemistry"],"xaxis":"x","y":[1572.35,1527.26,1478.56,1336.78,1271.49,1192.59,1180.89,1119.18,1114.96,1104.69,1069.69,1051.03,1048.2,1026.83,1011.02,966.61],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2017","Kuwait"]],"hovertemplate":"country_name=%{customdata[1]}<br>Skill group=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"Kuwait","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Kuwait","offsetgroup":"Kuwait","orientation":"v","showlegend":true,"textposition":"auto","x":["Fluid Mechanics"],"xaxis":"x","y":[1381.04],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2017","Cyprus"]],"hovertemplate":"country_name=%{customdata[1]}<br>Skill group=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"Cyprus","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Cyprus","offsetgroup":"Cyprus","orientation":"v","showlegend":true,"textposition":"auto","x":["Game Development"],"xaxis":"x","y":[1112.89],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2017","Chile"]],"hovertemplate":"country_name=%{customdata[1]}<br>Skill group=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"Chile","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Chile","offsetgroup":"Chile","orientation":"v","showlegend":true,"textposition":"auto","x":["Oil & Gas"],"xaxis":"x","y":[1010.59],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"} ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.6.3.min.js"></script>                <div id="be0a03c2-e1f0-433f-996c-c3a3faf02909" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("be0a03c2-e1f0-433f-996c-c3a3faf02909")) {                    Plotly.newPlot(                        "be0a03c2-e1f0-433f-996c-c3a3faf02909",                        [{"alignmentgroup":"True","customdata":[["2018","Luxembourg"],["2018","Luxembourg"],["2018","Luxembourg"],["2018","Luxembourg"],["2018","Luxembourg"],["2018","Luxembourg"],["2018","Luxembourg"],["2018","Luxembourg"],["2018","Luxembourg"],["2018","Luxembourg"],["2018","Luxembourg"],["2018","Luxembourg"],["2018","Luxembourg"],["2018","Luxembourg"],["2018","Luxembourg"],["2018","Luxembourg"]],"hovertemplate":"country_name=%{customdata[1]}<br>Skill group=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"Luxembourg","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Luxembourg","offsetgroup":"Luxembourg","orientation":"v","showlegend":true,"textposition":"auto","x":["Analytical Reasoning","Teamwork","Time Management","Oil & Gas","Artificial Intelligence (AI)","Problem Solving","Computer Hardware","Scientific Computing","Communication","Mobile Application Development","Game Development","Machining","Data Science","Organic Chemistry","Development Tools","Web Development"],"xaxis":"x","y":[1515.79,1433.05,1426.15,1338.68,1274.61,1217.96,1135.52,1108.91,1102.09,1068.58,1059.94,1058.2,1054.65,1053.54,1008.86,985.5],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2018","Cyprus"]],"hovertemplate":"country_name=%{customdata[1]}<br>Skill group=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"Cyprus","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Cyprus","offsetgroup":"Cyprus","orientation":"v","showlegend":true,"textposition":"auto","x":["Game Development"],"xaxis":"x","y":[1136.36],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2018","United Arab Emirates"]],"hovertemplate":"country_name=%{customdata[1]}<br>Skill group=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"United Arab Emirates","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"United Arab Emirates","offsetgroup":"United Arab Emirates","orientation":"v","showlegend":true,"textposition":"auto","x":["Artificial Intelligence (AI)"],"xaxis":"x","y":[1068.14],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2018","Kuwait"]],"hovertemplate":"country_name=%{customdata[1]}<br>Skill group=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"Kuwait","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Kuwait","offsetgroup":"Kuwait","orientation":"v","showlegend":true,"textposition":"auto","x":["Chemical Processing"],"xaxis":"x","y":[1054.92],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2018","Chile"]],"hovertemplate":"country_name=%{customdata[1]}<br>Skill group=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"Chile","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Chile","offsetgroup":"Chile","orientation":"v","showlegend":true,"textposition":"auto","x":["Oil & Gas"],"xaxis":"x","y":[985.56],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endli ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.6.3.min.js"></script>                <div id="cee362ac-e3ba-4752-938f-3ab00a5357da" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cee362ac-e3ba-4752-938f-3ab00a5357da")) {                    Plotly.newPlot(                        "cee362ac-e3ba-4752-938f-3ab00a5357da",                        [{"alignmentgroup":"True","customdata":[["2019","Georgia"],["2019","Georgia"],["2019","Georgia"],["2019","Georgia"],["2019","Georgia"],["2019","Georgia"],["2019","Georgia"]],"hovertemplate":"country_name=%{customdata[1]}<br>Skill group=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"Georgia","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Georgia","offsetgroup":"Georgia","orientation":"v","showlegend":true,"textposition":"auto","x":["Customer Experience","Administrative Assistance","Enterprise Software","Physical Security","Software Testing","Inventory Management","Time Management"],"xaxis":"x","y":[1901.99,1359.01,1316.44,1278.05,1094.14,1076.11,1073.76],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2019","Luxembourg"],["2019","Luxembourg"],["2019","Luxembourg"],["2019","Luxembourg"],["2019","Luxembourg"],["2019","Luxembourg"],["2019","Luxembourg"],["2019","Luxembourg"],["2019","Luxembourg"],["2019","Luxembourg"],["2019","Luxembourg"],["2019","Luxembourg"]],"hovertemplate":"country_name=%{customdata[1]}<br>Skill group=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"Luxembourg","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Luxembourg","offsetgroup":"Luxembourg","orientation":"v","showlegend":true,"textposition":"auto","x":["Problem Solving","Teamwork","Scientific Computing","Analytical Reasoning","Time Management","Mathematics","Artificial Intelligence (AI)","Physics","Machining","Mobile Application Development","Data Science","Operational Efficiency"],"xaxis":"x","y":[1506.43,1345.65,1316.0,1311.73,1311.18,1294.77,1256.5,1113.91,1088.24,1072.19,1066.09,1064.11],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2019","Hong Kong SAR, China"]],"hovertemplate":"country_name=%{customdata[1]}<br>Skill group=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"Hong Kong SAR, China","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Hong Kong SAR, China","offsetgroup":"Hong Kong SAR, China","orientation":"v","showlegend":true,"textposition":"auto","x":["Linguistics"],"xaxis":"x","y":[1059.6],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet" ...

# %% [markdown]
# ## Question 2: Which skills and which countries have seen the most attrition(i.e outward migration from the skill group)?

# %%
#Plotting net skill migration per 10k vs skill group (country wise)

# These 5 graphs show us the bottom 20 skill groups and the countries which have seen the most attrition of talent in these skill groups.

#This graph is for the year 2015
fig_9 = px.bar(df_1_3.sort_values(by='value',ascending=True).query('Year=="2015"').head(20), 
                x="skill_group_name", 
                y="value",
                title="Net skill-migration per 10,000 vs Skill - 2015",
                labels={"skill_group_name":"Skill group","value":"Net migration per 10k"},
                color="country_name",
                hover_data=['Year','country_name'],
                height=400
               ).update_xaxes(categoryorder="total ascending")
#fig_4.update_traces(marker_size=40)
fig_9.show()

#This graph is for the year 2016
fig_10 = px.bar(df_1_3.sort_values(by='value',ascending=True).query('Year=="2016"').head(20), 
                x="skill_group_name", 
                y="value",
                title="Net skill-migration per 10,000 vs Skill - 2016",
                labels={"skill_group_name":"Skill group","value":"Net migration per 10k"},
                color="country_name",
                hover_data=['Year','country_name'],
                height=400
               ).update_xaxes(categoryorder="total ascending")
fig_10.show()

#This graph is for the year 2017
fig_11 = px.bar(df_1_3.sort_values(by='value',ascending=True).query('Year=="2017"').head(20), 
                x="skill_group_name", 
                y="value",
                title="Net skill-migration per 10,000 vs Skill - 2017",
                labels={"skill_group_name":"Skill group","value":"Net migration per 10k"},
                color="country_name",
                hover_data=['Year','country_name'],
                height=400
               ).update_xaxes(categoryorder="total ascending")
fig_11.show()

#This graph is for the year 2018
fig_12 = px.bar(df_1_3.sort_values(by='value',ascending=True).query('Year=="2018"').head(20), 
                x="skill_group_name", 
                y="value",
                title="Net skill-migration per 10,000 vs Skill - 2018",
                labels={"skill_group_name":"Skill group","value":"Net migration per 10k"},
                color="country_name",
                hover_data=['Year','country_name'],
                height=400
               ).update_xaxes(categoryorder="total ascending")
fig_12.show()

#This graph is for the year 2019
fig_13 = px.bar(df_1_3.sort_values(by='value',ascending=True).query('Year=="2019"').head(20), 
                x="skill_group_name", 
                y="value",
                title="Net skill-migration per 10,000 vs Skill - 2019",
                labels={"skill_group_name":"Skill group","value":"Net migration per 10k"},
                color="country_name",
                hover_data=['Year','country_name'],
                height=400
               ).update_xaxes(categoryorder="total ascending")
fig_13.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.6.3.min.js"></script>                <div id="02ac07eb-3c6a-4b68-98e1-c9cf2798636d" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("02ac07eb-3c6a-4b68-98e1-c9cf2798636d")) {                    Plotly.newPlot(                        "02ac07eb-3c6a-4b68-98e1-c9cf2798636d",                        [{"alignmentgroup":"True","customdata":[["2015","Cuba"],["2015","Cuba"],["2015","Cuba"],["2015","Cuba"],["2015","Cuba"],["2015","Cuba"],["2015","Cuba"]],"hovertemplate":"country_name=%{customdata[1]}<br>Skill group=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"Cuba","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Cuba","offsetgroup":"Cuba","orientation":"v","showlegend":true,"textposition":"auto","x":["Mobile Application Development","Human Computer Interaction","Software Development Life Cycle (SDLC)","Data Science","Data Storage Technologies","Scientific Computing","Development Tools"],"xaxis":"x","y":[-3037.38,-2386.58,-2190.15,-1885.79,-1734.81,-1713.31,-1601.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2015","Iceland"]],"hovertemplate":"country_name=%{customdata[1]}<br>Skill group=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"Iceland","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Iceland","offsetgroup":"Iceland","orientation":"v","showlegend":true,"textposition":"auto","x":["Employee Learning & Development"],"xaxis":"x","y":[-2447.11],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2015","Libya"]],"hovertemplate":"country_name=%{customdata[1]}<br>Skill group=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"Libya","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Libya","offsetgroup":"Libya","orientation":"v","showlegend":true,"textposition":"auto","x":["Physical Security"],"xaxis":"x","y":[-1925.5],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2015","Afghanistan"],["2015","Afghanistan"]],"hovertemplate":"country_name=%{customdata[1]}<br>Skill group=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"Afghanistan","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Afghanistan","offsetgroup":"Afghanistan","orientation":"v","showlegend":true,"textposition":"auto","x":["National Security","Operational Efficiency"],"xaxis":"x","y":[-1731.45,-1610.25],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2015","Venezuela, RB"],["2015","Venezuela, RB"],["2015","Venezuela, RB"],["2015","Venezuela, RB"],["2015","Venezuela, RB"],["2015","Venezuela, RB"],["2015","Venezuela, RB"],["2015","Venezuela, RB"],["2015","Venezuela, RB"]],"hovertemplate":"country_name=%{customdata[1]}<br>Skill group=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"Venezuela, RB","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Venezuela, RB","offsetgroup":"Venezuela, RB","orientation":"v","showlegend":true,"textposition":"auto","x":["Software Testing","Industrial Design","Sales Leads","Game Development","Operational Efficiency","Mobile Application Development","Analytical Reasoning","Problem Solving","Software Development Life Cycle (SDLC)"],"xaxis":"x","y":[-1717.64,-1679.15,-1675.34,-1674.14,-1647.7,-1631.38,-1581.51,-1572.24,-1568.18],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fill ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.6.3.min.js"></script>                <div id="890f569d-e0a9-4026-ad6c-ca318e795927" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("890f569d-e0a9-4026-ad6c-ca318e795927")) {                    Plotly.newPlot(                        "890f569d-e0a9-4026-ad6c-ca318e795927",                        [{"alignmentgroup":"True","customdata":[["2016","Venezuela, RB"],["2016","Venezuela, RB"],["2016","Venezuela, RB"],["2016","Venezuela, RB"],["2016","Venezuela, RB"],["2016","Venezuela, RB"],["2016","Venezuela, RB"],["2016","Venezuela, RB"],["2016","Venezuela, RB"],["2016","Venezuela, RB"],["2016","Venezuela, RB"],["2016","Venezuela, RB"],["2016","Venezuela, RB"],["2016","Venezuela, RB"],["2016","Venezuela, RB"],["2016","Venezuela, RB"],["2016","Venezuela, RB"]],"hovertemplate":"country_name=%{customdata[1]}<br>Skill group=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"Venezuela, RB","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Venezuela, RB","offsetgroup":"Venezuela, RB","orientation":"v","showlegend":true,"textposition":"auto","x":["Flexible Approach","Operational Efficiency","Artificial Intelligence (AI)","Structural Engineering","Software Testing","Time Management","Problem Solving","Structural Analysis","Analytical Reasoning","Human Computer Interaction","Mobile Application Development","Sales Leads","Software Development Life Cycle (SDLC)","Environmental Engineering","Customer Experience","Machining","Scientific Computing"],"xaxis":"x","y":[-2435.26,-2134.93,-2104.3,-2065.4,-2058.37,-2056.98,-2027.66,-2022.09,-1987.86,-1972.02,-1957.09,-1954.75,-1842.81,-1804.31,-1793.66,-1774.9,-1771.48],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2016","Cuba"],["2016","Cuba"],["2016","Cuba"]],"hovertemplate":"country_name=%{customdata[1]}<br>Skill group=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"Cuba","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Cuba","offsetgroup":"Cuba","orientation":"v","showlegend":true,"textposition":"auto","x":["Human Computer Interaction","Mobile Application Development","Software Development Life Cycle (SDLC)"],"xaxis":"x","y":[-2052.55,-1968.18,-1928.25],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"] ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.6.3.min.js"></script>                <div id="72c99ad3-645d-4137-b177-5743d319c09d" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("72c99ad3-645d-4137-b177-5743d319c09d")) {                    Plotly.newPlot(                        "72c99ad3-645d-4137-b177-5743d319c09d",                        [{"alignmentgroup":"True","customdata":[["2017","Algeria"],["2017","Algeria"],["2017","Algeria"],["2017","Algeria"],["2017","Algeria"],["2017","Algeria"],["2017","Algeria"]],"hovertemplate":"country_name=%{customdata[1]}<br>Skill group=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"Algeria","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Algeria","offsetgroup":"Algeria","orientation":"v","showlegend":true,"textposition":"auto","x":["Recruiting","Enterprise Software","Inventory Management","Human Resources (HR)","Data Storage Technologies","Management Consulting","Development Tools"],"xaxis":"x","y":[-6604.67,-6060.98,-4858.51,-3471.35,-2960.83,-2955.29,-2158.62],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2017","Venezuela, RB"],["2017","Venezuela, RB"],["2017","Venezuela, RB"],["2017","Venezuela, RB"],["2017","Venezuela, RB"],["2017","Venezuela, RB"],["2017","Venezuela, RB"],["2017","Venezuela, RB"],["2017","Venezuela, RB"],["2017","Venezuela, RB"],["2017","Venezuela, RB"],["2017","Venezuela, RB"],["2017","Venezuela, RB"]],"hovertemplate":"country_name=%{customdata[1]}<br>Skill group=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"Venezuela, RB","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Venezuela, RB","offsetgroup":"Venezuela, RB","orientation":"v","showlegend":true,"textposition":"auto","x":["Sales Leads","Human Computer Interaction","Flexible Approach","Software Testing","Artificial Intelligence (AI)","Structural Engineering","Scientific Computing","Operational Efficiency","Industrial Design","Problem Solving","Mobile Application Development","Machining","Game Development"],"xaxis":"x","y":[-3274.3,-2646.19,-2542.23,-2469.0,-2435.67,-2403.48,-2399.77,-2382.85,-2340.68,-2305.74,-2295.46,-2170.74,-2168.79],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"# ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.6.3.min.js"></script>                <div id="84d9b148-a5db-49ff-9be6-399b59b644f1" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("84d9b148-a5db-49ff-9be6-399b59b644f1")) {                    Plotly.newPlot(                        "84d9b148-a5db-49ff-9be6-399b59b644f1",                        [{"alignmentgroup":"True","customdata":[["2018","Venezuela, RB"],["2018","Venezuela, RB"],["2018","Venezuela, RB"],["2018","Venezuela, RB"],["2018","Venezuela, RB"],["2018","Venezuela, RB"],["2018","Venezuela, RB"],["2018","Venezuela, RB"],["2018","Venezuela, RB"],["2018","Venezuela, RB"],["2018","Venezuela, RB"],["2018","Venezuela, RB"],["2018","Venezuela, RB"],["2018","Venezuela, RB"],["2018","Venezuela, RB"],["2018","Venezuela, RB"],["2018","Venezuela, RB"],["2018","Venezuela, RB"],["2018","Venezuela, RB"],["2018","Venezuela, RB"]],"hovertemplate":"country_name=%{customdata[1]}<br>Skill group=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"Venezuela, RB","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Venezuela, RB","offsetgroup":"Venezuela, RB","orientation":"v","showlegend":true,"textposition":"auto","x":["Flexible Approach","Human Computer Interaction","Sales Leads","Structural Engineering","Machining","Mobile Application Development","Structural Analysis","Software Testing","Scientific Computing","Social Perceptiveness","Time Management","Artificial Intelligence (AI)","Industrial Design","Problem Solving","Customer Experience","Electronic Control Systems","Environmental Engineering","Documentation","Chemical Processing","Analytical Reasoning"],"xaxis":"x","y":[-3629.02,-3171.94,-3094.17,-3020.0,-2949.09,-2822.98,-2814.19,-2797.99,-2778.32,-2743.94,-2735.03,-2679.14,-2670.13,-2665.84,-2635.06,-2624.44,-2608.7,-2588.3,-2574.58,-2543.06],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fd ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.6.3.min.js"></script>                <div id="4d6ad06f-3e8c-4807-9b94-46812cbba475" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4d6ad06f-3e8c-4807-9b94-46812cbba475")) {                    Plotly.newPlot(                        "4d6ad06f-3e8c-4807-9b94-46812cbba475",                        [{"alignmentgroup":"True","customdata":[["2019","Venezuela, RB"],["2019","Venezuela, RB"],["2019","Venezuela, RB"],["2019","Venezuela, RB"],["2019","Venezuela, RB"],["2019","Venezuela, RB"],["2019","Venezuela, RB"],["2019","Venezuela, RB"],["2019","Venezuela, RB"],["2019","Venezuela, RB"],["2019","Venezuela, RB"],["2019","Venezuela, RB"],["2019","Venezuela, RB"],["2019","Venezuela, RB"],["2019","Venezuela, RB"],["2019","Venezuela, RB"],["2019","Venezuela, RB"],["2019","Venezuela, RB"],["2019","Venezuela, RB"],["2019","Venezuela, RB"]],"hovertemplate":"country_name=%{customdata[1]}<br>Skill group=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"Venezuela, RB","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Venezuela, RB","offsetgroup":"Venezuela, RB","orientation":"v","showlegend":true,"textposition":"auto","x":["Flexible Approach","Social Perceptiveness","Analytical Reasoning","Sales Leads","Human Computer Interaction","Problem Solving","Structural Analysis","Artificial Intelligence (AI)","Customer Experience","Chemical Processing","Mobile Application Development","Electronic Control Systems","Information Management","Nonprofit Management","Time Management","Environmental Engineering","Operational Efficiency","Structural Engineering","Fluid Mechanics","Dentistry"],"xaxis":"x","y":[-4022.04,-3834.49,-2724.71,-2641.97,-2395.31,-2392.5,-2360.06,-2212.81,-2212.3,-2136.98,-2108.01,-2106.54,-2100.52,-2098.94,-2097.23,-2080.58,-2056.16,-2035.93,-2022.78,-1994.42],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888 ...

# %% [markdown]
# #### Dataset 2: Linkedin Industry Migration Dataset
#
# - Here I've cleaned and plotted the Linkedin industry migration data on a bar chart.
#
# ---

# %%
#industry migration dataset
# Having a look at the first 3 rows of the dataset

df_2.head(3)
# Out:
#   country_code          country_name  ... Unnamed: 28 Unnamed: 29
# 0           ae  United Arab Emirates  ...         NaN         NaN
# 1           ae  United Arab Emirates  ...         NaN         NaN
# 2           ae  United Arab Emirates  ...         NaN         NaN
#
# [3 rows x 30 columns]

# %%
#Checking the number of rows and columns of the dataset

df_2.shape
# Out:
# (5295, 30)

# %%
#Checking for null values

df_2.isnull().sum()
# Out:
# country_code             0
# country_name             0
# wb_income                0
# wb_region                0
# isic_section_index       0
# isic_section_name        0
# industry_id              0
# industry_name            0
# net_per_10K_2015         0
# net_per_10K_2016         0
# net_per_10K_2017         0
# net_per_10K_2018         0
# net_per_10K_2019         0
# Unnamed: 13           5295
# Unnamed: 14           5295
# Unnamed: 15           5295
# Unnamed: 16           5295
# Unnamed: 17           5295
# Unnamed: 18           5295
# Unnamed: 19           5295
# Unnamed: 20           5295
# Unnamed: 21           5295
# Unnamed: 22           5295
# Unnamed: 23           5295
# Unnamed: 24           5295
# Unnamed: 25           5295
# Unnamed: 26           5295
# Unnamed: 27           5295
# Unnamed: 28           5295
# Unnamed: 29           5295
# dtype: int64

# %%
# Dropping all the columns which start with 'Unnamed:' as they contain no data

df_2_1=df_2.drop(columns=['Unnamed: 13','Unnamed: 14','Unnamed: 15','Unnamed: 16','Unnamed: 17','Unnamed: 18','Unnamed: 19','Unnamed: 20','Unnamed: 21','Unnamed: 22','Unnamed: 23','Unnamed: 24','Unnamed: 25','Unnamed: 26','Unnamed: 27','Unnamed: 28','Unnamed: 29'])
df_2_1.head(3)
# Out:
#   country_code          country_name  ... net_per_10K_2018 net_per_10K_2019
# 0           ae  United Arab Emirates  ...            68.51            49.55
# 1           ae  United Arab Emirates  ...           149.57           182.22
# 2           ae  United Arab Emirates  ...           409.18           407.41
#
# [3 rows x 13 columns]

# %%
#Renaming the 5 year columns to only the year

df_2_2= df_2_1.rename({'net_per_10K_2015': '2015', 'net_per_10K_2016': '2016', 'net_per_10K_2017': '2017', 'net_per_10K_2018': '2018', 'net_per_10K_2019': '2019'}, axis=1)
df_2_2.head()
# Out:
#   country_code          country_name    wb_income  ...    2017    2018    2019
# 0           ae  United Arab Emirates  High income  ...    8.20   68.51   49.55
# 1           ae  United Arab Emirates  High income  ...  112.98  149.57  182.22
# 2           ae  United Arab Emirates  High income  ...  596.48  409.18  407.41
# 3           ae  United Arab Emirates  High income  ...  163.99  236.69  188.07
# 4           ae  United Arab Emirates  High income  ...  877.71  852.39  519.40
#
# [5 rows x 13 columns]

# %%
# Using the melt function to convert the data from a wide format to a long format

df_2_tidy=pd.melt(df_2_2,
             id_vars=['country_code','country_name','wb_income','wb_region','isic_section_index','isic_section_name','industry_id','industry_name'],
             var_name='Year',
             value_name='value' #giving the column name as 'value' because I need to combine all 4 datasets at the end
                  )
df_2_tidy.head(5)
# Out:
#   country_code          country_name  ...  Year    value
# 0           ae  United Arab Emirates  ...  2015   378.74
# 1           ae  United Arab Emirates  ...  2015   100.97
# 2           ae  United Arab Emirates  ...  2015  1079.36
# 3           ae  United Arab Emirates  ...  2015   401.46
# 4           ae  United Arab Emirates  ...  2015  1840.33
#
# [5 rows x 10 columns]

# %% [markdown]
# ## Question 3: Which industries and which countries have seen the most influx of talent?

# %%
#Plotting net industry migration per 10k vs industry (country wise)

# These 5 graphs show us the top 20 industries and the countries which have seen the most influx of talent in these industries.

#This graph is for the year 2015
fig_14 = px.bar(df_2_tidy.sort_values(by='value',ascending=False).query('Year=="2015"').head(20), 
                x="industry_name", 
                y="value",
                title="Plotting net industry migration per 10k vs industry (country wise) - 2015",
                labels={"industry_name":"Industry Name","value":"Net migration per 10k"},
                color="country_name",
                hover_data=['Year','country_name'],
                height=500
                ).update_xaxes(categoryorder="total ascending")

fig_14.show()

#This graph is for the year 2016
fig_15 = px.bar(df_2_tidy.sort_values(by='value',ascending=False).query('Year=="2016"').head(20), 
                x="industry_name", 
                y="value",
                title="Plotting net industry migration per 10k vs industry (country wise) - 2016",
                labels={"industry_name":"Industry Name","value":"Net migration per 10k"},
                color="country_name",
                hover_data=['Year','country_name'],
                height=500
               ).update_xaxes(categoryorder="total ascending")
fig_15.show()

#This graph is for the year 2017
fig_16 = px.bar(df_2_tidy.sort_values(by='value',ascending=False).query('Year=="2017"').head(20), 
                x="industry_name", 
                y="value",
                title="Plotting net industry migration per 10k vs industry (country wise) - 2017",
                labels={"industry_name":"Industry Name","value":"Net migration per 10k"},
                color="country_name",
                hover_data=['Year','country_name'],
                height=500
               ).update_xaxes(categoryorder="total ascending")
fig_16.show()

#This graph is for the year 2018
fig_17 = px.bar(df_2_tidy.sort_values(by='value',ascending=False).query('Year=="2018"').head(20), 
                x="industry_name",
                y="value",
                title="Plotting net industry migration per 10k vs industry (country wise) - 2018",
                labels={"industry_name":"Industry Name","value":"Net migration per 10k"},
                color="country_name",
                hover_data=['Year','country_name'],
                height=500
               ).update_xaxes(categoryorder="total ascending")
fig_17.show()

#This graph is for the year 2019
fig_18 = px.bar(df_2_tidy.sort_values(by='value',ascending=False).query('Year=="2019"').head(20), 
                x="industry_name", 
                y="value",
                title="Plotting net industry migration per 10k vs industry (country wise) - 2019",
                labels={"industry_name":"Industry Name","value":"Net migration per 10k"},
                color="country_name",
                hover_data=['Year','country_name'],
                height=500
               ).update_xaxes(categoryorder="total ascending")
fig_18.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.6.3.min.js"></script>                <div id="8e314215-f9e2-43b4-a21a-cddf57e3ff54" class="plotly-graph-div" style="height:500px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8e314215-f9e2-43b4-a21a-cddf57e3ff54")) {                    Plotly.newPlot(                        "8e314215-f9e2-43b4-a21a-cddf57e3ff54",                        [{"alignmentgroup":"True","customdata":[["2015","United Arab Emirates"],["2015","United Arab Emirates"],["2015","United Arab Emirates"],["2015","United Arab Emirates"],["2015","United Arab Emirates"],["2015","United Arab Emirates"],["2015","United Arab Emirates"],["2015","United Arab Emirates"],["2015","United Arab Emirates"],["2015","United Arab Emirates"]],"hovertemplate":"country_name=%{customdata[1]}<br>Industry Name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"United Arab Emirates","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"United Arab Emirates","offsetgroup":"United Arab Emirates","orientation":"v","showlegend":true,"textposition":"auto","x":["E-Learning","Internet","Computer Games","Wine & Spirits","International Affairs","Tobacco","Capital Markets","Outsourcing/Offshoring","Accounting","Animation"],"xaxis":"x","y":[2280.6,1840.33,1662.82,1487.6,1468.53,1377.42,1345.11,1329.1,1308.05,1264.88],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2015","Luxembourg"],["2015","Luxembourg"]],"hovertemplate":"country_name=%{customdata[1]}<br>Industry Name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"Luxembourg","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Luxembourg","offsetgroup":"Luxembourg","orientation":"v","showlegend":true,"textposition":"auto","x":["Food Production","Internet"],"xaxis":"x","y":[2054.79,1537.7],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2015","Cote d'Ivoire"]],"hovertemplate":"country_name=%{customdata[1]}<br>Industry Name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"Cote d'Ivoire","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Cote d'Ivoire","offsetgroup":"Cote d'Ivoire","orientation":"v","showlegend":true,"textposition":"auto","x":["International Trade & Development"],"xaxis":"x","y":[1839.48],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2015","Qatar"],["2015","Qatar"],["2015","Qatar"],["2015","Qatar"],["2015","Qatar"],["2015","Qatar"]],"hovertemplate":"country_name=%{customdata[1]}<br>Industry Name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"Qatar","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Qatar","offsetgroup":"Qatar","orientation":"v","showlegend":true,"textposition":"auto","x":["Transportation/Trucking/Railroad","Food Production","Renewables & Environment","Health, Wellness & Fitness","Consumer Services","Outsourcing/Offshoring"],"xaxis":"x","y":[1820.85,1646.25,1571.27,1553.76,1396.51,1288.98],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2015","Panama"]],"hovertemplate":"country_name=%{customdata[1]}<br>Industry Name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"Panama","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Panama","offsetgroup":"Panama","orientation":"v","showlegend":true,"textposition":"auto","x":["Hospital & Health Care"],"xaxis":"x","y":[1442.89],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","wid ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.6.3.min.js"></script>                <div id="aa771e50-0930-4fcd-9872-8db5c70a6be0" class="plotly-graph-div" style="height:500px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("aa771e50-0930-4fcd-9872-8db5c70a6be0")) {                    Plotly.newPlot(                        "aa771e50-0930-4fcd-9872-8db5c70a6be0",                        [{"alignmentgroup":"True","customdata":[["2016","Luxembourg"],["2016","Luxembourg"],["2016","Luxembourg"],["2016","Luxembourg"],["2016","Luxembourg"]],"hovertemplate":"country_name=%{customdata[1]}<br>Industry Name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"Luxembourg","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Luxembourg","offsetgroup":"Luxembourg","orientation":"v","showlegend":true,"textposition":"auto","x":["Internet","Consumer Goods","Mechanical or Industrial Engineering","Food Production","Accounting"],"xaxis":"x","y":[1787.58,1388.95,1279.68,1256.23,1206.24],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2016","United Arab Emirates"],["2016","United Arab Emirates"],["2016","United Arab Emirates"],["2016","United Arab Emirates"],["2016","United Arab Emirates"],["2016","United Arab Emirates"],["2016","United Arab Emirates"]],"hovertemplate":"country_name=%{customdata[1]}<br>Industry Name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"United Arab Emirates","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"United Arab Emirates","offsetgroup":"United Arab Emirates","orientation":"v","showlegend":true,"textposition":"auto","x":["Wine & Spirits","E-Learning","Internet","Accounting","Outsourcing/Offshoring","Animation","Computer Games"],"xaxis":"x","y":[1616.52,1492.85,1368.42,1261.62,1207.32,1159.13,1153.85],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2016","Qatar"],["2016","Qatar"],["2016","Qatar"],["2016","Qatar"]],"hovertemplate":"country_name=%{customdata[1]}<br>Industry Name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"Qatar","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Qatar","offsetgroup":"Qatar","orientation":"v","showlegend":true,"textposition":"auto","x":["Food Production","Renewables & Environment","Transportation/Trucking/Railroad","Leisure, Travel & Tourism"],"xaxis":"x","y":[1440.58,1395.75,1334.97,1159.06],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2016","Japan"]],"hovertemplate":"country_name=%{customdata[1]}<br>Industry Name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"Japan","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Japan","offsetgroup":"Japan","orientation":"v","showlegend":true,"textposition":"auto","x":["Aviation & Aerospace"],"xaxis":"x","y":[1327.59],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2016","Cote d'Ivoire"]],"hovertemplate":"country_name=%{customdata[1]}<br>Industry Name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"Cote d'Ivoire","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Cote d'Ivoire","offsetgroup":"Cote d'Ivoire","orientation":"v","showlegend":true,"textposition":"auto","x":["International Trade & Development"],"xaxis":"x","y":[1317.92],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2016","Malta"],["2016","Malta"]],"hovertemplate":"country_name=%{customdata[1]}<br>Industry Name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"Malta","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Malta","offsetgroup":"Malta","orientation":"v","showlegend":true,"textposition":"auto","x":["Marketing & Advertising" ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.6.3.min.js"></script>                <div id="dde3d75c-d0e5-4a81-bd08-5d05991d97bf" class="plotly-graph-div" style="height:500px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dde3d75c-d0e5-4a81-bd08-5d05991d97bf")) {                    Plotly.newPlot(                        "dde3d75c-d0e5-4a81-bd08-5d05991d97bf",                        [{"alignmentgroup":"True","customdata":[["2017","Luxembourg"],["2017","Luxembourg"],["2017","Luxembourg"],["2017","Luxembourg"],["2017","Luxembourg"],["2017","Luxembourg"],["2017","Luxembourg"],["2017","Luxembourg"]],"hovertemplate":"country_name=%{customdata[1]}<br>Industry Name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"Luxembourg","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Luxembourg","offsetgroup":"Luxembourg","orientation":"v","showlegend":true,"textposition":"auto","x":["Internet","Consumer Goods","Accounting","Management Consulting","Computer Software","Higher Education","Staffing & Recruiting","Food Production"],"xaxis":"x","y":[1981.38,1216.73,1050.4,978.4,968.91,942.68,879.12,869.17],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2017","United Arab Emirates"],["2017","United Arab Emirates"],["2017","United Arab Emirates"],["2017","United Arab Emirates"],["2017","United Arab Emirates"]],"hovertemplate":"country_name=%{customdata[1]}<br>Industry Name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"United Arab Emirates","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"United Arab Emirates","offsetgroup":"United Arab Emirates","orientation":"v","showlegend":true,"textposition":"auto","x":["E-Learning","Accounting","Wine & Spirits","Internet","Tobacco"],"xaxis":"x","y":[1362.36,1044.37,912.0,877.71,870.1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2017","Japan"]],"hovertemplate":"country_name=%{customdata[1]}<br>Industry Name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"Japan","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Japan","offsetgroup":"Japan","orientation":"v","showlegend":true,"textposition":"auto","x":["Aviation & Aerospace"],"xaxis":"x","y":[1031.67],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2017","Cyprus"]],"hovertemplate":"country_name=%{customdata[1]}<br>Industry Name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"Cyprus","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Cyprus","offsetgroup":"Cyprus","orientation":"v","showlegend":true,"textposition":"auto","x":["Marketing & Advertising"],"xaxis":"x","y":[1006.93],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2017","Switzerland"]],"hovertemplate":"country_name=%{customdata[1]}<br>Industry Name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"Switzerland","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Switzerland","offsetgroup":"Switzerland","orientation":"v","showlegend":true,"textposition":"auto","x":["E-Learning"],"xaxis":"x","y":[968.91],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2017","Ireland"]],"hovertemplate":"country_name=%{customdata[1]}<br>Industry Name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"Ireland","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Ireland","offsetgroup":"Ireland","orientation":"v","showlegend":true,"textposition":"auto","x":["International Affairs"],"xaxis":"x","y":[924.37],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2017","Malta"]],"hovertemplate":"country_name=%{customdata[1]}<br>Industry Name=%{x}<br>Net migratio ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.6.3.min.js"></script>                <div id="3417468e-d06f-46c8-ae70-f9243638ff00" class="plotly-graph-div" style="height:500px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3417468e-d06f-46c8-ae70-f9243638ff00")) {                    Plotly.newPlot(                        "3417468e-d06f-46c8-ae70-f9243638ff00",                        [{"alignmentgroup":"True","customdata":[["2018","Luxembourg"],["2018","Luxembourg"],["2018","Luxembourg"],["2018","Luxembourg"],["2018","Luxembourg"],["2018","Luxembourg"],["2018","Luxembourg"],["2018","Luxembourg"],["2018","Luxembourg"],["2018","Luxembourg"],["2018","Luxembourg"]],"hovertemplate":"country_name=%{customdata[1]}<br>Industry Name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"Luxembourg","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Luxembourg","offsetgroup":"Luxembourg","orientation":"v","showlegend":true,"textposition":"auto","x":["Accounting","Food Production","Computer Software","Machinery","Internet","Staffing & Recruiting","Management Consulting","Consumer Goods","Non-Profit Organization Management","Research","Financial Services"],"xaxis":"x","y":[1500.0,1287.36,1184.13,1169.95,1168.6,1012.57,950.1,916.54,868.44,856.21,817.49],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2018","United Arab Emirates"],["2018","United Arab Emirates"],["2018","United Arab Emirates"],["2018","United Arab Emirates"]],"hovertemplate":"country_name=%{customdata[1]}<br>Industry Name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"United Arab Emirates","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"United Arab Emirates","offsetgroup":"United Arab Emirates","orientation":"v","showlegend":true,"textposition":"auto","x":["Accounting","Computer Games","E-Learning","Internet"],"xaxis":"x","y":[1187.61,1127.47,904.86,852.39],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2018","Cyprus"],["2018","Cyprus"]],"hovertemplate":"country_name=%{customdata[1]}<br>Industry Name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"Cyprus","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Cyprus","offsetgroup":"Cyprus","orientation":"v","showlegend":true,"textposition":"auto","x":["Internet","Hospitality"],"xaxis":"x","y":[1186.06,840.94],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2018","Qatar"]],"hovertemplate":"country_name=%{customdata[1]}<br>Industry Name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"Qatar","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Qatar","offsetgroup":"Qatar","orientation":"v","showlegend":true,"textposition":"auto","x":["Food Production"],"xaxis":"x","y":[1144.49],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2018","Ireland"]],"hovertemplate":"country_name=%{customdata[1]}<br>Industry Name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"Ireland","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Ireland","offsetgroup":"Ireland","orientation":"v","showlegend":true,"textposition":"auto","x":["Animation"],"xaxis":"x","y":[917.1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2018","Canada"]],"hovertemplate":"country_name=%{customdata[1]}<br>Industry Name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"Canada","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Canada","offsetgroup":"Canada","orientation":"v","showlegend":true,"textposition":"auto","x":["Outsourcing/Offshoring"],"xaxis":"x","y":[856.55],"yaxis":"y","type":"bar"}],                        {"template":{" ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.6.3.min.js"></script>                <div id="1b8386b0-885c-43af-8eda-fee40c1fe47d" class="plotly-graph-div" style="height:500px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1b8386b0-885c-43af-8eda-fee40c1fe47d")) {                    Plotly.newPlot(                        "1b8386b0-885c-43af-8eda-fee40c1fe47d",                        [{"alignmentgroup":"True","customdata":[["2019","Luxembourg"],["2019","Luxembourg"],["2019","Luxembourg"],["2019","Luxembourg"],["2019","Luxembourg"],["2019","Luxembourg"],["2019","Luxembourg"],["2019","Luxembourg"],["2019","Luxembourg"],["2019","Luxembourg"],["2019","Luxembourg"],["2019","Luxembourg"],["2019","Luxembourg"]],"hovertemplate":"country_name=%{customdata[1]}<br>Industry Name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"Luxembourg","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Luxembourg","offsetgroup":"Luxembourg","orientation":"v","showlegend":true,"textposition":"auto","x":["Accounting","Internet","Consumer Goods","Higher Education","Staffing & Recruiting","Logistics & Supply Chain","Legal Services","Information Technology & Services","Financial Services","Automotive","Food Production","Management Consulting","Computer Software"],"xaxis":"x","y":[1820.99,1561.98,916.87,889.13,861.03,824.31,800.65,761.45,756.89,755.4,738.21,706.08,670.05],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2019","Georgia"],["2019","Georgia"]],"hovertemplate":"country_name=%{customdata[1]}<br>Industry Name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"Georgia","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Georgia","offsetgroup":"Georgia","orientation":"v","showlegend":true,"textposition":"auto","x":["Higher Education","Information Technology & Services"],"xaxis":"x","y":[1321.56,669.04],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2019","Qatar"]],"hovertemplate":"country_name=%{customdata[1]}<br>Industry Name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"Qatar","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Qatar","offsetgroup":"Qatar","orientation":"v","showlegend":true,"textposition":"auto","x":["Food Production"],"xaxis":"x","y":[955.84],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2019","Canada"]],"hovertemplate":"country_name=%{customdata[1]}<br>Industry Name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"Canada","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Canada","offsetgroup":"Canada","orientation":"v","showlegend":true,"textposition":"auto","x":["Outsourcing/Offshoring"],"xaxis":"x","y":[905.94],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2019","Ireland"]],"hovertemplate":"country_name=%{customdata[1]}<br>Industry Name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"Ireland","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Ireland","offsetgroup":"Ireland","orientation":"v","showlegend":true,"textposition":"auto","x":["International Affairs"],"xaxis":"x","y":[737.22],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2019","Japan"]],"hovertemplate":"country_name=%{customdata[1]}<br>Industry Name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"Japan","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Japan","offsetgroup":"Japan","orientation":"v","showlegend":true,"textposition":"auto","x":["Aviation & Aerospace"],"xaxis":"x","y":[698.45],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2019","United Arab Emirates"]],"hovertemplate":"count ...

# %% [markdown]
# ## Question 4: Which industries and which countries have seen the most attrition of talent?

# %%
#Plotting net industry migration per 10k vs industry (country wise)

# These 5 graphs show us the bottom 20 industries and the countries which have seen the most attrition of talent in these industries.

#This graph is for the year 2015
fig_19 = px.bar(df_2_tidy.sort_values(by='value',ascending=True).query('Year=="2015"').head(20), 
                x="industry_name", 
                y="value",
                title="Net industry migration per 10k vs industry (country wise) - 2015",
                labels={"industry_name":"Industry Name","value":"Net migration per 10k"},
                color="country_name",
                hover_data=['Year','country_name'],
                height=500
               ).update_xaxes(categoryorder="total ascending")
#fig_4.update_traces(marker_size=40)
fig_19.show()

#This graph is for the year 2016
fig_20 = px.bar(df_2_tidy.sort_values(by='value',ascending=True).query('Year=="2016"').head(20), 
                x="industry_name", 
                y="value",
                title="Net industry migration per 10k vs industry (country wise) - 2016",
                labels={"industry_name":"Industry Name","value":"Net migration per 10k"},
                color="country_name",
                hover_data=['Year','country_name'],
                height=500
               ).update_xaxes(categoryorder="total ascending")
fig_20.show()

#This graph is for the year 2017
fig_21 = px.bar(df_2_tidy.sort_values(by='value',ascending=True).query('Year=="2017"').head(20), 
                x="industry_name", 
                y="value",
                title="Net industry migration per 10k vs industry (country wise) - 2017",
                labels={"industry_name":"Industry Name","value":"Net migration per 10k"},
                color="country_name",
                hover_data=['Year','country_name'],
                height=500
               ).update_xaxes(categoryorder="total ascending")
fig_21.show()

#This graph is for the year 2018
fig_22 = px.bar(df_2_tidy.sort_values(by='value',ascending=True).query('Year=="2018"').head(20), 
                x="industry_name",
                y="value",
                title="Net industry migration per 10k vs industry (country wise) - 2018",
                labels={"industry_name":"Industry Name","value":"Net migration per 10k"},
                color="country_name",
                hover_data=['Year','country_name'],
                height=500
               ).update_xaxes(categoryorder="total ascending")
fig_22.show()

#This graph is for the year 2019
fig_23 = px.bar(df_2_tidy.sort_values(by='value',ascending=True).query('Year=="2019"').head(20), 
                x="industry_name", 
                y="value",
                title="Net industry migration per 10k vs industry (country wise) - 2019",
                labels={"industry_name":"Industry Name","value":"Net migration per 10k"},
                color="country_name",
                hover_data=['Year','country_name'],
                height=500
               ).update_xaxes(categoryorder="total ascending")
fig_23.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.6.3.min.js"></script>                <div id="9f945efa-a781-4984-b628-3485f2a2003f" class="plotly-graph-div" style="height:500px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9f945efa-a781-4984-b628-3485f2a2003f")) {                    Plotly.newPlot(                        "9f945efa-a781-4984-b628-3485f2a2003f",                        [{"alignmentgroup":"True","customdata":[["2015","Gabon"]],"hovertemplate":"country_name=%{customdata[1]}<br>Industry Name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"Gabon","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Gabon","offsetgroup":"Gabon","orientation":"v","showlegend":true,"textposition":"auto","x":["Construction"],"xaxis":"x","y":[-1185.25],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2015","Afghanistan"],["2015","Afghanistan"],["2015","Afghanistan"],["2015","Afghanistan"]],"hovertemplate":"country_name=%{customdata[1]}<br>Industry Name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"Afghanistan","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Afghanistan","offsetgroup":"Afghanistan","orientation":"v","showlegend":true,"textposition":"auto","x":["Military","Logistics & Supply Chain","Defense & Space","Oil & Energy"],"xaxis":"x","y":[-1172.34,-917.05,-869.73,-688.49],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2015","Venezuela, RB"],["2015","Venezuela, RB"],["2015","Venezuela, RB"],["2015","Venezuela, RB"],["2015","Venezuela, RB"],["2015","Venezuela, RB"],["2015","Venezuela, RB"],["2015","Venezuela, RB"]],"hovertemplate":"country_name=%{customdata[1]}<br>Industry Name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"Venezuela, RB","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Venezuela, RB","offsetgroup":"Venezuela, RB","orientation":"v","showlegend":true,"textposition":"auto","x":["Wine & Spirits","Information Technology & Services","Telecommunications","Marketing & Advertising","Consumer Goods","Investment Management","Accounting","Pharmaceuticals"],"xaxis":"x","y":[-1131.22,-794.13,-781.01,-778.24,-763.83,-741.64,-741.42,-703.04],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2015","Korea, Rep."],["2015","Korea, Rep."]],"hovertemplate":"country_name=%{customdata[1]}<br>Industry Name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"Korea, Rep.","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Korea, Rep.","offsetgroup":"Korea, Rep.","orientation":"v","showlegend":true,"textposition":"auto","x":["Military","Defense & Space"],"xaxis":"x","y":[-1104.17,-800.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2015","Cyprus"]],"hovertemplate":"country_name=%{customdata[1]}<br>Industry Name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"Cyprus","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Cyprus","offsetgroup":"Cyprus","orientation":"v","showlegend":true,"textposition":"auto","x":["Military"],"xaxis":"x","y":[-1052.63],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2015","Bahrain"]],"hovertemplate":"country_name=%{customdata[1]}<br>Industry Name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"Bahrain","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Bahrain","offsetgroup":"Bahrain","orientation":"v","showlegend":true,"textposition":"auto","x":["Military"],"xaxis":"x","y":[-998.98],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2015","Japan"]],"hovertemplate":"country_name=%{customdata[1]}<br>Industry Name=%{x}<br>Net migration per 10 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.6.3.min.js"></script>                <div id="034b3323-3cee-44f9-b651-80b36ca9ed10" class="plotly-graph-div" style="height:500px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("034b3323-3cee-44f9-b651-80b36ca9ed10")) {                    Plotly.newPlot(                        "034b3323-3cee-44f9-b651-80b36ca9ed10",                        [{"alignmentgroup":"True","customdata":[["2016","Kuwait"]],"hovertemplate":"country_name=%{customdata[1]}<br>Industry Name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"Kuwait","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Kuwait","offsetgroup":"Kuwait","orientation":"v","showlegend":true,"textposition":"auto","x":["Military"],"xaxis":"x","y":[-1876.78],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2016","Korea, Rep."]],"hovertemplate":"country_name=%{customdata[1]}<br>Industry Name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"Korea, Rep.","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Korea, Rep.","offsetgroup":"Korea, Rep.","orientation":"v","showlegend":true,"textposition":"auto","x":["Military"],"xaxis":"x","y":[-1630.7],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2016","Venezuela, RB"],["2016","Venezuela, RB"],["2016","Venezuela, RB"],["2016","Venezuela, RB"],["2016","Venezuela, RB"],["2016","Venezuela, RB"],["2016","Venezuela, RB"],["2016","Venezuela, RB"],["2016","Venezuela, RB"],["2016","Venezuela, RB"],["2016","Venezuela, RB"],["2016","Venezuela, RB"],["2016","Venezuela, RB"]],"hovertemplate":"country_name=%{customdata[1]}<br>Industry Name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"Venezuela, RB","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Venezuela, RB","offsetgroup":"Venezuela, RB","orientation":"v","showlegend":true,"textposition":"auto","x":["Investment Management","Pharmaceuticals","Telecommunications","Information Technology & Services","Marketing & Advertising","Consumer Goods","Food & Beverages","Wine & Spirits","Computer Software","Hospitality","Cosmetics","Accounting","Entertainment"],"xaxis":"x","y":[-1442.65,-1336.51,-1129.7,-1113.19,-1091.2,-1026.22,-1022.03,-980.76,-952.88,-927.38,-910.55,-908.77,-906.04],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2016","Bahrain"]],"hovertemplate":"country_name=%{customdata[1]}<br>Industry Name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"Bahrain","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Bahrain","offsetgroup":"Bahrain","orientation":"v","showlegend":true,"textposition":"auto","x":["Military"],"xaxis":"x","y":[-1174.17],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2016","Nigeria"]],"hovertemplate":"country_name=%{customdata[1]}<br>Industry Name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"Nigeria","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Nigeria","offsetgroup":"Nigeria","orientation":"v","showlegend":true,"textposition":"auto","x":["Military"],"xaxis":"x","y":[-1070.38],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2016","Ireland"]],"hovertemplate":"country_name=%{customdata[1]}<br>Industry Name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"Ireland","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Ireland","offsetgroup":"Ireland","orientation":"v","showlegend":true,"textposition":"auto","x":["International Affairs"],"xaxis":"x","y":[-1004.18],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2016","Afghanistan"]],"hovertemplate":"country_name=%{cust ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.6.3.min.js"></script>                <div id="ab7cddbf-c251-4984-a10c-5edd5e9400ab" class="plotly-graph-div" style="height:500px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ab7cddbf-c251-4984-a10c-5edd5e9400ab")) {                    Plotly.newPlot(                        "ab7cddbf-c251-4984-a10c-5edd5e9400ab",                        [{"alignmentgroup":"True","customdata":[["2017","Venezuela, RB"],["2017","Venezuela, RB"],["2017","Venezuela, RB"],["2017","Venezuela, RB"],["2017","Venezuela, RB"],["2017","Venezuela, RB"],["2017","Venezuela, RB"],["2017","Venezuela, RB"],["2017","Venezuela, RB"],["2017","Venezuela, RB"],["2017","Venezuela, RB"],["2017","Venezuela, RB"],["2017","Venezuela, RB"],["2017","Venezuela, RB"],["2017","Venezuela, RB"],["2017","Venezuela, RB"]],"hovertemplate":"country_name=%{customdata[1]}<br>Industry Name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"Venezuela, RB","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Venezuela, RB","offsetgroup":"Venezuela, RB","orientation":"v","showlegend":true,"textposition":"auto","x":["Information Technology & Services","Wine & Spirits","Marketing & Advertising","Pharmaceuticals","Telecommunications","Food & Beverages","Hospitality","Accounting","Investment Management","Computer Software","Civil Engineering","Consumer Goods","Management Consulting","Automotive","Cosmetics","Internet"],"xaxis":"x","y":[-1577.24,-1508.22,-1500.16,-1497.64,-1395.35,-1394.08,-1335.87,-1333.38,-1314.84,-1314.74,-1303.1,-1299.21,-1269.07,-1237.54,-1234.11,-1230.88],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2017","Kuwait"]],"hovertemplate":"country_name=%{customdata[1]}<br>Industry Name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"Kuwait","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Kuwait","offsetgroup":"Kuwait","orientation":"v","showlegend":true,"textposition":"auto","x":["Military"],"xaxis":"x","y":[-1495.33],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2017","Pakistan"]],"hovertemplate":"country_name=%{customdata[1]}<br>Industry Name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"Pakistan","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Pakistan","offsetgroup":"Pakistan","orientation":"v","showlegend":true,"textposition":"auto","x":["Staffing & Recruiting"],"xaxis":"x","y":[-1318.98],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2017","Nigeria"]],"hovertemplate":"country_name=%{customdata[1]}<br>Industry Name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"Nigeria","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Nigeria","offsetgroup":"Nigeria","orientation":"v","showlegend":true,"textposition":"auto","x":["Military"],"xaxis":"x","y":[-1304.35],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2017","Cyprus"]],"hovertemplate":"country_name=%{customdata[1]}<br>Industry Name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"Cyprus","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Cyprus","offsetgroup":"Cyprus","orientation":"v","showlegend":true,"textposition":"auto","x":["Military"],"xaxis":"x","y":[-1201.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet" ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.6.3.min.js"></script>                <div id="312d18eb-e88d-49ab-9840-a73044630643" class="plotly-graph-div" style="height:500px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("312d18eb-e88d-49ab-9840-a73044630643")) {                    Plotly.newPlot(                        "312d18eb-e88d-49ab-9840-a73044630643",                        [{"alignmentgroup":"True","customdata":[["2018","Cyprus"]],"hovertemplate":"country_name=%{customdata[1]}<br>Industry Name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"Cyprus","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Cyprus","offsetgroup":"Cyprus","orientation":"v","showlegend":true,"textposition":"auto","x":["Military"],"xaxis":"x","y":[-2025.55],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2018","Nigeria"]],"hovertemplate":"country_name=%{customdata[1]}<br>Industry Name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"Nigeria","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Nigeria","offsetgroup":"Nigeria","orientation":"v","showlegend":true,"textposition":"auto","x":["Military"],"xaxis":"x","y":[-1916.87],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2018","Venezuela, RB"],["2018","Venezuela, RB"],["2018","Venezuela, RB"],["2018","Venezuela, RB"],["2018","Venezuela, RB"],["2018","Venezuela, RB"],["2018","Venezuela, RB"],["2018","Venezuela, RB"],["2018","Venezuela, RB"],["2018","Venezuela, RB"],["2018","Venezuela, RB"],["2018","Venezuela, RB"],["2018","Venezuela, RB"],["2018","Venezuela, RB"],["2018","Venezuela, RB"],["2018","Venezuela, RB"],["2018","Venezuela, RB"]],"hovertemplate":"country_name=%{customdata[1]}<br>Industry Name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"Venezuela, RB","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Venezuela, RB","offsetgroup":"Venezuela, RB","orientation":"v","showlegend":true,"textposition":"auto","x":["Civil Engineering","Information Technology & Services","Wine & Spirits","Marketing & Advertising","Accounting","Hospitality","Architecture & Planning","Computer Software","Internet","Telecommunications","Management Consulting","Mechanical or Industrial Engineering","Pharmaceuticals","Automotive","Food & Beverages","Investment Management","Chemicals"],"xaxis":"x","y":[-1786.84,-1784.12,-1761.89,-1686.15,-1682.98,-1639.55,-1619.05,-1618.44,-1589.19,-1566.75,-1526.6,-1525.64,-1495.16,-1427.68,-1380.75,-1367.07,-1366.86],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2018","Nepal"]],"hovertemplate":"country_name=%{customdata[1]}<br>Industry Name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"Nepal","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Nepal","offsetgroup":"Nepal","orientation":"v","showlegend":true,"textposition":"auto","x":["Higher Education"],"xaxis":"x","y":[-1745.8],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour": ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.6.3.min.js"></script>                <div id="99096c2f-3371-42d1-a0fe-5a0425d05269" class="plotly-graph-div" style="height:500px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("99096c2f-3371-42d1-a0fe-5a0425d05269")) {                    Plotly.newPlot(                        "99096c2f-3371-42d1-a0fe-5a0425d05269",                        [{"alignmentgroup":"True","customdata":[["2019","Nigeria"]],"hovertemplate":"country_name=%{customdata[1]}<br>Industry Name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"Nigeria","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Nigeria","offsetgroup":"Nigeria","orientation":"v","showlegend":true,"textposition":"auto","x":["Military"],"xaxis":"x","y":[-3367.37],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2019","Nepal"]],"hovertemplate":"country_name=%{customdata[1]}<br>Industry Name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"Nepal","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Nepal","offsetgroup":"Nepal","orientation":"v","showlegend":true,"textposition":"auto","x":["Higher Education"],"xaxis":"x","y":[-1943.62],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2019","Venezuela, RB"],["2019","Venezuela, RB"],["2019","Venezuela, RB"],["2019","Venezuela, RB"],["2019","Venezuela, RB"],["2019","Venezuela, RB"],["2019","Venezuela, RB"],["2019","Venezuela, RB"],["2019","Venezuela, RB"],["2019","Venezuela, RB"],["2019","Venezuela, RB"],["2019","Venezuela, RB"],["2019","Venezuela, RB"],["2019","Venezuela, RB"]],"hovertemplate":"country_name=%{customdata[1]}<br>Industry Name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"Venezuela, RB","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Venezuela, RB","offsetgroup":"Venezuela, RB","orientation":"v","showlegend":true,"textposition":"auto","x":["Hospitality","Information Technology & Services","Mechanical or Industrial Engineering","Marketing & Advertising","Civil Engineering","Computer Software","Internet","Architecture & Planning","Human Resources","Management Consulting","Construction","Wine & Spirits","Accounting","Automotive"],"xaxis":"x","y":[-1566.87,-1355.99,-1256.52,-1232.29,-1231.36,-1227.89,-1192.64,-1156.9,-1116.39,-1091.74,-1073.87,-1064.3,-1036.77,-1009.88],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2019","Cyprus"]],"hovertemplate":"country_name=%{customdata[1]}<br>Industry Name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"Cyprus","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Cyprus","offsetgroup":"Cyprus","orientation":"v","showlegend":true,"textposition":"auto","x":["Military"],"xaxis":"x","y":[-1418.72],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2019","Bahrain"]],"hovertemplate":"country_name=%{customdata[1]}<br>Industry Name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"Bahrain","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Bahrain","offsetgroup":"Bahrain","orientation":"v","showlegend":true,"textposition":"auto","x":["Military"],"xaxis":"x","y":[-1111.57],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["2019","Cameroon"]],"hovertemplate":"country_name=%{customdata[1]}<br>Industry Name=%{x}<br>Net migration per 10k=%{y}<br>Year=%{customdata[0]}<extra></extra>","legendgroup":"Cameroon","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Cameroon","offsetgroup":"Cameroon","orientation":"v","showlegend":true,"textposition":"auto","x":["Higher Education"],"xaxis":"x","y":[-1086.73],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata ...

# %% [markdown]
# #### Dataset 3: Linkedin Country Migration Dataset(Migration of LinkedIn members from one country to another country)
#
# - Here I've cleaned and plotted the skill migration data on Sankey diagrams.
#
# ---

# %%
#Country Migration dataset
# Having a look at the first 3 rows of the dataset
df_3.head(3)
# Out:
#   base_country_code     base_country_name  ...  Unnamed: 24  Unnamed: 25
# 0                ae  United Arab Emirates  ...          NaN          NaN
# 1                ae  United Arab Emirates  ...          NaN          NaN
# 2                ae  United Arab Emirates  ...          NaN          NaN
#
# [3 rows x 26 columns]

# %%
# Checking the number of rows and columns of the dataset

df_3.shape
# Out:
# (4148, 26)

# %%
# Checking for null values

df_3.isnull().sum()
# Out:
# base_country_code              0
# base_country_name              0
# base_lat                       0
# base_long                      0
# base_country_wb_income         0
# base_country_wb_region         0
# target_country_code            0
# target_country_name            0
# target_lat                     0
# target_long                    0
# target_country_wb_income       0
# target_country_wb_region       0
# net_per_10K_2015               0
# net_per_10K_2016               0
# net_per_10K_2017               0
# net_per_10K_2018               0
# net_per_10K_2019               0
# Unnamed: 17                 4148
# Unnamed: 18                 4148
# Unnamed: 19                 4148
# Unnamed: 20                 4148
# Unnamed: 21                 4148
# Unnamed: 22                 4148
# Unnamed: 23                 4148
# Unnamed: 24                 4148
# Unnamed: 25                 4148
# dtype: int64

# %%
#Dropping all columns starting with 'Unnamed:' as they contain no relevant data

df_3_1=df_3.drop(columns=['Unnamed: 17','Unnamed: 18','Unnamed: 19','Unnamed: 20','Unnamed: 21','Unnamed: 22','Unnamed: 23','Unnamed: 24','Unnamed: 25'])
df_3_1.head(3)
# Out:
#   base_country_code     base_country_name  ...  net_per_10K_2018  net_per_10K_2019
# 0                ae  United Arab Emirates  ...             -0.05             -0.02
# 1                ae  United Arab Emirates  ...              0.55              0.78
# 2                ae  United Arab Emirates  ...             -0.02             -0.06
#
# [3 rows x 17 columns]

# %%
#Renaming the 5 year columns to just the name of the year

df_3_2= df_3_1.rename({'net_per_10K_2015': '2015', 'net_per_10K_2016': '2016', 'net_per_10K_2017': '2017', 'net_per_10K_2018': '2018', 'net_per_10K_2019': '2019'}, axis=1)
df_3_2.head(3)
# Out:
#   base_country_code     base_country_name   base_lat  ...  2017  2018  2019
# 0                ae  United Arab Emirates  23.424076  ...  0.11 -0.05 -0.02
# 1                ae  United Arab Emirates  23.424076  ...  0.57  0.55  0.78
# 2                ae  United Arab Emirates  23.424076  ...  0.11 -0.02 -0.06
#
# [3 rows x 17 columns]

# %%
# Using the melt function to convert the data into long format from a wide format

df_3_tidy=pd.melt(df_3_2,
             id_vars=['base_country_code','base_country_name','base_lat','base_long','base_country_wb_income','base_country_wb_region','target_country_code','target_country_name','target_lat','target_long','target_country_wb_income','target_country_wb_region'],
             var_name='Year',
             value_name='value' #giving the column name as 'value' because I need to combine all 4 datasets at the end
                  )
df_3_tidy.head()
# Out:
#   base_country_code     base_country_name  ...  Year  value
# 0                ae  United Arab Emirates  ...  2015   0.19
# 1                ae  United Arab Emirates  ...  2015   0.19
# 2                ae  United Arab Emirates  ...  2015  -0.01
# 3                ae  United Arab Emirates  ...  2015   0.16
# 4                ae  United Arab Emirates  ...  2015   0.10
#
# [5 rows x 14 columns]

# %%
# Using the query function to get the data for only 2015 and sorting the data in ascending order

df_3_3=df_3_tidy.sort_values(by='value',ascending=False).query('Year=="2015"').head(50)
df_3_3.head()
# Out:
#      base_country_code     base_country_name  ...  Year   value
# 2487                lu            Luxembourg  ...  2015  150.68
# 33                  ae  United Arab Emirates  ...  2015   91.75
# 3260                qa                 Qatar  ...  2015   71.44
# 3041                pa                Panama  ...  2015   60.58
# 2780                ng               Nigeria  ...  2015   55.30
#
# [5 rows x 14 columns]

# %%
df_3_3 = df_3_3[df_3_3["base_country_name"]!="Net"]

# %%
#Grouping the data by base country name and target country name

df_3_grouped = df_3_3.groupby(by=["base_country_name","target_country_name"]).sum()[["value"]]
df_3_grouped = df_3_grouped.reset_index()
df_3_grouped.head()
# Out:
#   base_country_name target_country_name  value
# 0            Angola            Portugal  23.24
# 1            Angola       United States  22.10
# 2           Bahrain               India  36.85
# 3          Botswana      United Kingdom  15.88
# 4  Congo, Dem. Rep.              France  15.40

# %%
import numpy as np
import holoviews as hv
import plotly.graph_objects as go

# %%
#hv.extension('bokeh')

# %%
# Creating a list of all possible nodes for the sankey diagram

all_nodes = df_3_grouped.base_country_name.values.tolist() + df_3_grouped.target_country_name.values.tolist()

# %%
# Generating source nodes
source_indices = [all_nodes.index(country) for country in df_3_grouped.base_country_name]

# %%
# Generating target nodes
target_indices = [all_nodes.index(measure) for measure in df_3_grouped.target_country_name]

# %%
colors = px.colors.qualitative.D3

node_colors_mappings = dict([(node,np.random.choice(colors)) for node in all_nodes])
node_colors = [node_colors_mappings[node] for node in all_nodes]
edge_colors = [node_colors_mappings[node] for node in df_3_grouped.base_country_name]

# %% [markdown]
# ## Question 5: Which countries had the most influx of talent in 2015?

# %%
# Plotting the first Sankey diagram for top 50 countries - 2015

fig = go.Figure(data=[go.Sankey(
    node = dict(
      pad = 20,
      thickness = 20,
      line = dict(color = "black", width = 1.0),
      label =  all_nodes,
      color =  node_colors,
    ),

    link = dict(
      source =  source_indices,
      target =  target_indices,
      value =  df_3_grouped.value,
      color = edge_colors,
))])
fig.update_layout(title_text="Net Linkedin-migration between countries for the year 2015",
                  height=600,
                  font_size=10)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.6.3.min.js"></script>                <div id="603228a5-ba7a-4233-aa9c-3bb71c08c885" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("603228a5-ba7a-4233-aa9c-3bb71c08c885")) {                    Plotly.newPlot(                        "603228a5-ba7a-4233-aa9c-3bb71c08c885",                        [{"link":{"color":["#BCBD22","#BCBD22","#1F77B4","#D62728","#8C564B","#8C564B","#FF7F0E","#FF7F0E","#D62728","#D62728","#BCBD22","#FF7F0E","#8C564B","#FF7F0E","#BCBD22","#17BECF","#8C564B","#8C564B","#8C564B","#8C564B","#17BECF","#17BECF","#E377C2","#D62728","#7F7F7F","#BCBD22","#BCBD22","#1F77B4","#1F77B4","#BCBD22","#BCBD22","#FF7F0E","#FF7F0E","#E377C2","#E377C2","#2CA02C","#2CA02C","#2CA02C","#7F7F7F","#7F7F7F","#1F77B4","#E377C2","#7F7F7F","#E377C2","#E377C2","#E377C2","#D62728","#8C564B","#8C564B","#D62728"],"source":[0,0,2,3,4,4,6,7,8,8,10,11,12,13,14,15,16,16,16,16,20,20,22,23,24,25,25,27,27,29,30,31,31,33,33,35,35,37,38,39,40,41,42,43,43,43,46,47,47,49],"target":[50,51,52,53,54,51,56,51,54,51,51,51,51,51,51,52,66,54,68,69,53,51,51,69,51,38,51,53,51,52,80,81,51,83,52,52,51,52,51,51,54,51,51,52,94,51,96,53,51,51],"value":[23.24,22.1,36.85,15.88,15.4,34.27,21.11,19.49,28.58,17.09,20.21,17.66,17.87,32.47,40.35,32.55,49.67,150.68,25.37,16.47,15.85,49.82,15.19,20.1,21.69,20.9,22.39,55.3,37.12,22.82,60.58,45.58,29.81,15.62,71.44,23.94,29.05,20.27,21.3,28.93,36.12,29.6,20.1,91.75,23.63,17.0,23.38,43.27,33.6,38.6]},"node":{"color":["#BCBD22","#BCBD22","#1F77B4","#D62728","#8C564B","#8C564B","#FF7F0E","#FF7F0E","#D62728","#D62728","#BCBD22","#FF7F0E","#8C564B","#FF7F0E","#BCBD22","#17BECF","#8C564B","#8C564B","#8C564B","#8C564B","#17BECF","#17BECF","#E377C2","#D62728","#7F7F7F","#BCBD22","#BCBD22","#1F77B4","#1F77B4","#BCBD22","#BCBD22","#FF7F0E","#FF7F0E","#E377C2","#E377C2","#2CA02C","#2CA02C","#2CA02C","#7F7F7F","#7F7F7F","#1F77B4","#E377C2","#7F7F7F","#E377C2","#E377C2","#E377C2","#D62728","#8C564B","#8C564B","#D62728","#1F77B4","#9467BD","#2CA02C","#2CA02C","#D62728","#9467BD","#2CA02C","#9467BD","#D62728","#9467BD","#9467BD","#9467BD","#9467BD","#9467BD","#9467BD","#2CA02C","#8C564B","#D62728","#7F7F7F","#D62728","#2CA02C","#9467BD","#9467BD","#D62728","#9467BD","#7F7F7F","#9467BD","#2CA02C","#9467BD","#2CA02C","#BCBD22","#8C564B","#9467BD","#8C564B","#2CA02C","#2CA02C","#9467BD","#2CA02C","#9467BD","#9467BD","#D62728","#9467BD","#9467BD","#2CA02C","#7F7F7F","#9467BD","#BCBD22","#2CA02C","#9467BD","#9467BD"],"label":["Angola","Angola","Bahrain","Botswana","Congo, Dem. Rep.","Congo, Dem. Rep.","Cyprus","Ethiopia","Gabon","Gabon","Georgia","Ghana","Indonesia","Iran, Islamic Rep.","Kenya","Kuwait","Luxembourg","Luxembourg","Luxembourg","Luxembourg","Malawi","Malawi","Mali","Malta","Mozambique","Namibia","Namibia","Nigeria","Nigeria","Oman","Panama","Papua New Guinea","Papua New Guinea","Qatar","Qatar","Saudi Arabia","Saudi Arabia","Singapore","South Africa","Sudan","Switzerland","Tanzania","Uganda","United Arab Emirates","United Arab Emirates","United Arab Emirates","West Bank and Gaza","Zambia","Zambia","Zimbabwe","Portugal","United States","India","United Kingdom","France","United States","Turkey","United States","France","United States","United States","United States","United States","United States","United States","India","Belgium","France","Germany","Italy","United Kingdom","United States","United States","Italy","United States","South Africa","United States","United Kingdom","United States","India","Venezuela, RB","Australia","United States","Egypt, Arab Rep.","India","India","United States","India","United States","United States","France","United States","United States","India","Pakistan","United States","Israel","United Kingdom","United States","United States"],"line":{"color":"bla ...

# %%
# Using the query function to get the data for only 2016 and sorting the data in ascending order

df_4_1=df_3_tidy.sort_values(by='value',ascending=False).query('Year=="2016"').head(50)
df_4_1.head()
# Out:
#      base_country_code     base_country_name  ...  Year   value
# 6635                lu            Luxembourg  ...  2016  124.48
# 4181                ae  United Arab Emirates  ...  2016   77.43
# 7408                qa                 Qatar  ...  2016   59.31
# 6770                mw                Malawi  ...  2016   48.52
# 6628                lu            Luxembourg  ...  2016   42.73
#
# [5 rows x 14 columns]

# %%
#Grouping the data by base country name and target country name


df_4_1 = df_4_1[df_4_1["base_country_name"]!="Net"]
df_4_grouped = df_4_1.groupby(by=["base_country_name","target_country_name"]).sum()[["value"]]
df_4_grouped = df_4_grouped.reset_index()
df_4_grouped.head()
# Out:
#   base_country_name target_country_name  value
# 0            Angola       United States  13.74
# 1         Australia               India  13.38
# 2           Bahrain               India  26.99
# 3             Chile       Venezuela, RB  17.54
# 4  Congo, Dem. Rep.              France  15.57

# %%
# Creating a list of all possible nodes for the sankey diagram
# Generating source nodes
# Generating target nodes

all_nodes_1 = df_4_grouped.base_country_name.values.tolist() + df_4_grouped.target_country_name.values.tolist()
source_indices_1 = [all_nodes_1.index(country) for country in df_4_grouped.base_country_name]
target_indices_1 = [all_nodes_1.index(measure) for measure in df_4_grouped.target_country_name]

colors = px.colors.qualitative.D3

node_colors_mappings_1 = dict([(node,np.random.choice(colors)) for node in all_nodes_1])
# node_colors_1 = [node_colors_mappings_1[node] for node in all_nodes]
# edge_colors_1 = [node_colors_mappings_1[node] for node in df_4_grouped.base_country_name]

# %% [markdown]
# ## Question 6: Which countries had the most influx of talent in 2016?

# %%
# Plotting the first Sankey diagram for top 50 countries - 2016

fig_1 = go.Figure(data=[go.Sankey(
    node = dict(
      pad = 20,
      thickness = 20,
      line = dict(color = "black", width = 1.0),
      label =  all_nodes_1,
      color =  node_colors,
    ),

    link = dict(
      source =  source_indices_1,
      target =  target_indices_1,
      value =  df_4_grouped.value,
      color = edge_colors,
))])
fig_1.update_layout(title_text="Net migration of workers between countries for the year 2016",
                  height=600,
                  font_size=10,xaxis={'categoryorder':'total ascending'})
fig_1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.6.3.min.js"></script>                <div id="ff04af40-7faa-42fd-bc9b-842d6686f5c6" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ff04af40-7faa-42fd-bc9b-842d6686f5c6")) {                    Plotly.newPlot(                        "ff04af40-7faa-42fd-bc9b-842d6686f5c6",                        [{"link":{"color":["#BCBD22","#BCBD22","#1F77B4","#D62728","#8C564B","#8C564B","#FF7F0E","#FF7F0E","#D62728","#D62728","#BCBD22","#FF7F0E","#8C564B","#FF7F0E","#BCBD22","#17BECF","#8C564B","#8C564B","#8C564B","#8C564B","#17BECF","#17BECF","#E377C2","#D62728","#7F7F7F","#BCBD22","#BCBD22","#1F77B4","#1F77B4","#BCBD22","#BCBD22","#FF7F0E","#FF7F0E","#E377C2","#E377C2","#2CA02C","#2CA02C","#2CA02C","#7F7F7F","#7F7F7F","#1F77B4","#E377C2","#7F7F7F","#E377C2","#E377C2","#E377C2","#D62728","#8C564B","#8C564B","#D62728"],"source":[0,1,2,3,4,4,6,6,8,9,9,11,11,13,13,13,13,17,18,18,20,21,22,22,24,25,25,27,28,29,29,31,31,33,34,34,36,36,38,39,39,41,42,43,43,43,46,47,47,49],"target":[50,51,51,53,54,50,56,57,50,59,50,61,51,63,54,65,66,50,66,69,50,36,38,50,51,69,50,51,53,1,50,61,51,50,51,50,51,87,50,54,65,50,50,51,94,95,96,69,50,50],"value":[13.74,13.38,26.99,17.54,15.57,16.63,10.88,23.53,13.03,12.68,39.1,12.32,36.45,42.73,124.48,22.88,18.08,48.52,14.77,18.82,13.8,17.14,14.14,16.75,16.59,27.59,20.37,18.86,39.85,31.94,10.68,13.92,59.31,18.79,17.76,17.19,14.29,14.23,13.6,28.36,10.65,19.93,16.81,77.43,17.44,12.07,20.04,27.6,28.55,37.76]},"node":{"color":["#BCBD22","#BCBD22","#1F77B4","#D62728","#8C564B","#8C564B","#FF7F0E","#FF7F0E","#D62728","#D62728","#BCBD22","#FF7F0E","#8C564B","#FF7F0E","#BCBD22","#17BECF","#8C564B","#8C564B","#8C564B","#8C564B","#17BECF","#17BECF","#E377C2","#D62728","#7F7F7F","#BCBD22","#BCBD22","#1F77B4","#1F77B4","#BCBD22","#BCBD22","#FF7F0E","#FF7F0E","#E377C2","#E377C2","#2CA02C","#2CA02C","#2CA02C","#7F7F7F","#7F7F7F","#1F77B4","#E377C2","#7F7F7F","#E377C2","#E377C2","#E377C2","#D62728","#8C564B","#8C564B","#D62728","#1F77B4","#9467BD","#2CA02C","#2CA02C","#D62728","#9467BD","#2CA02C","#9467BD","#D62728","#9467BD","#9467BD","#9467BD","#9467BD","#9467BD","#9467BD","#2CA02C","#8C564B","#D62728","#7F7F7F","#D62728","#2CA02C","#9467BD","#9467BD","#D62728","#9467BD","#7F7F7F","#9467BD","#2CA02C","#9467BD","#2CA02C","#BCBD22","#8C564B","#9467BD","#8C564B","#2CA02C","#2CA02C","#9467BD","#2CA02C","#9467BD","#9467BD","#D62728","#9467BD","#9467BD","#2CA02C","#7F7F7F","#9467BD","#BCBD22","#2CA02C","#9467BD","#9467BD"],"label":["Angola","Australia","Bahrain","Chile","Congo, Dem. Rep.","Congo, Dem. Rep.","Cyprus","Cyprus","Ghana","Kenya","Kenya","Kuwait","Kuwait","Luxembourg","Luxembourg","Luxembourg","Luxembourg","Malawi","Malta","Malta","Mozambique","Myanmar","Namibia","Namibia","New Zealand","Nigeria","Nigeria","Oman","Panama","Papua New Guinea","Papua New Guinea","Qatar","Qatar","Rwanda","Saudi Arabia","Saudi Arabia","Singapore","Singapore","South Africa","Switzerland","Switzerland","Tanzania","Uganda","United Arab Emirates","United Arab Emirates","United Arab Emirates","West Bank and Gaza","Zambia","Zambia","Zimbabwe","United States","India","India","Venezuela, RB","France","United States","Greece","Turkey","United States","Norway","United States","Egypt, Arab Rep.","India","Belgium","France","Germany","Italy","United States","Italy","United Kingdom","United States","Singapore","South Africa","United States","India","United Kingdom","United States","India","Venezuela, RB","Australia","United States","Egypt, Arab Rep.","India","United States","India","United States","India","Malaysia","United States","France","Germany","United States","United States","India","Pakistan","Philippines","Israel","United Kingdom","United States","United States"],"line":{"color":"black","width":1.0},"pad":20,"th ...

# %%
# Using the query function to get the data for only 2017 and sorting the data in ascending order

df_5_1=df_3_tidy.sort_values(by='value',ascending=False).query('Year=="2017"').head(50)
df_5_1.head()
# Out:
#       base_country_code     base_country_name  ...  Year  value
# 10783                lu            Luxembourg  ...  2017  87.00
# 8329                 ae  United Arab Emirates  ...  2017  54.55
# 11556                qa                 Qatar  ...  2017  33.18
# 9274                 cy                Cyprus  ...  2017  29.38
# 10776                lu            Luxembourg  ...  2017  28.53
#
# [5 rows x 14 columns]

# %%
#Grouping the data by base country name and target country name


df_5_1 = df_5_1[df_5_1["base_country_name"]!="Net"]
df_5_grouped = df_5_1.groupby(by=["base_country_name","target_country_name"]).sum()[["value"]]
df_5_grouped = df_5_grouped.reset_index()
df_5_grouped.head()
# Out:
#   base_country_name target_country_name  value
# 0         Argentina       Venezuela, RB  10.65
# 1         Australia               India  16.10
# 2           Bahrain               India  16.66
# 3            Canada               India  11.81
# 4             Chile       Venezuela, RB  26.02

# %%
# Creating a list of all possible nodes for the sankey diagram
# Generating source nodes
# Generating target nodes

all_nodes_2 = df_5_grouped.base_country_name.values.tolist() + df_5_grouped.target_country_name.values.tolist()
source_indices_2 = [all_nodes_2.index(country) for country in df_5_grouped.base_country_name]
target_indices_2 = [all_nodes_2.index(measure) for measure in df_5_grouped.target_country_name]

colors = px.colors.qualitative.D3

node_colors_mappings_2 = dict([(node,np.random.choice(colors)) for node in all_nodes_2])

# %% [markdown]
# ## Question 7: Which countries had the most influx of talent in 2017?

# %%
# Plotting the first Sankey diagram for top 50 countries - 2017

fig_2 = go.Figure(data=[go.Sankey(
    node = dict(
      pad = 20,
      thickness = 20,
      line = dict(color = "black", width = 1.0),
      label =  all_nodes_2,
      color =  node_colors,
    ),

    link = dict(
      source =  source_indices_2,
      target =  target_indices_2,
      value =  df_5_grouped.value,
      color = edge_colors,
))])
fig_2.update_layout(title_text="Net migration of workers between countries for the year 2017",
                  height=600,
                  font_size=10)
fig_2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.6.3.min.js"></script>                <div id="302a82ab-54eb-400f-b297-f74d29e92398" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("302a82ab-54eb-400f-b297-f74d29e92398")) {                    Plotly.newPlot(                        "302a82ab-54eb-400f-b297-f74d29e92398",                        [{"link":{"color":["#BCBD22","#BCBD22","#1F77B4","#D62728","#8C564B","#8C564B","#FF7F0E","#FF7F0E","#D62728","#D62728","#BCBD22","#FF7F0E","#8C564B","#FF7F0E","#BCBD22","#17BECF","#8C564B","#8C564B","#8C564B","#8C564B","#17BECF","#17BECF","#E377C2","#D62728","#7F7F7F","#BCBD22","#BCBD22","#1F77B4","#1F77B4","#BCBD22","#BCBD22","#FF7F0E","#FF7F0E","#E377C2","#E377C2","#2CA02C","#2CA02C","#2CA02C","#7F7F7F","#7F7F7F","#1F77B4","#E377C2","#7F7F7F","#E377C2","#E377C2","#E377C2","#D62728","#8C564B","#8C564B","#D62728"],"source":[0,1,2,3,4,5,5,5,8,9,10,11,12,12,14,15,15,17,17,17,17,17,17,17,24,25,25,27,28,29,30,30,32,33,34,35,36,37,38,38,40,41,42,42,42,45,46,47,47,49],"target":[50,51,51,51,50,55,56,57,50,50,51,61,62,51,64,65,51,67,68,10,51,71,72,57,64,71,57,38,78,51,51,78,50,1,62,51,64,64,51,89,68,56,65,51,94,50,96,57,64,64],"value":[10.65,16.1,16.66,11.81,26.02,8.38,29.38,11.21,7.86,9.67,8.35,9.16,13.28,9.99,12.55,10.4,24.31,28.53,87.0,19.07,8.01,16.57,9.16,15.77,12.33,12.76,12.7,9.95,7.97,8.36,14.69,8.64,24.28,26.05,19.94,33.18,7.89,15.1,12.93,13.4,17.38,10.81,8.95,54.55,8.93,8.68,7.76,7.88,8.32,10.09]},"node":{"color":["#BCBD22","#BCBD22","#1F77B4","#D62728","#8C564B","#8C564B","#FF7F0E","#FF7F0E","#D62728","#D62728","#BCBD22","#FF7F0E","#8C564B","#FF7F0E","#BCBD22","#17BECF","#8C564B","#8C564B","#8C564B","#8C564B","#17BECF","#17BECF","#E377C2","#D62728","#7F7F7F","#BCBD22","#BCBD22","#1F77B4","#1F77B4","#BCBD22","#BCBD22","#FF7F0E","#FF7F0E","#E377C2","#E377C2","#2CA02C","#2CA02C","#2CA02C","#7F7F7F","#7F7F7F","#1F77B4","#E377C2","#7F7F7F","#E377C2","#E377C2","#E377C2","#D62728","#8C564B","#8C564B","#D62728","#1F77B4","#9467BD","#2CA02C","#2CA02C","#D62728","#9467BD","#2CA02C","#9467BD","#D62728","#9467BD","#9467BD","#9467BD","#9467BD","#9467BD","#9467BD","#2CA02C","#8C564B","#D62728","#7F7F7F","#D62728","#2CA02C","#9467BD","#9467BD","#D62728","#9467BD","#7F7F7F","#9467BD","#2CA02C","#9467BD","#2CA02C","#BCBD22","#8C564B","#9467BD","#8C564B","#2CA02C","#2CA02C","#9467BD","#2CA02C","#9467BD","#9467BD","#D62728","#9467BD","#9467BD","#2CA02C","#7F7F7F","#9467BD","#BCBD22","#2CA02C","#9467BD","#9467BD"],"label":["Argentina","Australia","Bahrain","Canada","Chile","Cyprus","Cyprus","Cyprus","Dominican Republic","Ecuador","Germany","Hong Kong SAR, China","Ireland","Ireland","Kenya","Kuwait","Kuwait","Luxembourg","Luxembourg","Luxembourg","Luxembourg","Luxembourg","Luxembourg","Luxembourg","Malawi","Malta","Malta","Myanmar","Namibia","Nepal","New Zealand","New Zealand","Panama","Papua New Guinea","Portugal","Qatar","Rwanda","Saudi Arabia","Singapore","Singapore","Switzerland","Syrian Arab Republic","United Arab Emirates","United Arab Emirates","United Arab Emirates","Uruguay","West Bank and Gaza","Zambia","Zambia","Zimbabwe","Venezuela, RB","India","India","India","Venezuela, RB","Greece","Turkey","United Kingdom","Venezuela, RB","Venezuela, RB","India","China","Brazil","India","United States","Egypt, Arab Rep.","India","Belgium","France","Germany","India","Italy","Spain","United Kingdom","United States","Italy","United Kingdom","Singapore","South Africa","India","India","South Africa","Venezuela, RB","Australia","Brazil","India","United States","United States","India","Malaysia","France","Turkey","Egypt, Arab Rep.","India","Philippines","Venezuela, RB","Israel","United Kingdom","United States","United States"],"line":{"color":"black","width":1.0},"pad":20,"thickness":20},"type":"sankey"}],            ...

# %%
# Using the query function to get the data for only 2018 and sorting the data in ascending order


df_6_1=df_3_tidy.sort_values(by='value',ascending=False).query('Year=="2018"').head(50)
df_6_1.head()
# Out:
#       base_country_code     base_country_name  ...  Year  value
# 14931                lu            Luxembourg  ...  2018  91.41
# 12477                ae  United Arab Emirates  ...  2018  57.91
# 15704                qa                 Qatar  ...  2018  52.77
# 15653                pt              Portugal  ...  2018  36.47
# 14824                kw                Kuwait  ...  2018  36.08
#
# [5 rows x 14 columns]

# %%
#Grouping the data by base country name and target country name

df_6_1 = df_6_1[df_6_1["base_country_name"]!="Net"]
df_6_grouped = df_6_1.groupby(by=["base_country_name","target_country_name"]).sum()[["value"]]
df_6_grouped = df_6_grouped.reset_index()
df_6_grouped.head()
# Out:
#   base_country_name target_country_name  value
# 0       Afghanistan               India   8.72
# 1         Argentina       Venezuela, RB  18.00
# 2         Australia               India  16.76
# 3           Bahrain               India  30.52
# 4           Bahrain        Saudi Arabia   7.60

# %%
# Creating a list of all possible nodes for the sankey diagram
# Generating source nodes
# Generating target nodes

all_nodes_3 = df_6_grouped.base_country_name.values.tolist() + df_6_grouped.target_country_name.values.tolist()
source_indices_3 = [all_nodes_3.index(country) for country in df_6_grouped.base_country_name]
target_indices_3 = [all_nodes_3.index(measure) for measure in df_6_grouped.target_country_name]

colors = px.colors.qualitative.D3

node_colors_mappings_3 = dict([(node,np.random.choice(colors)) for node in all_nodes_3])

# %% [markdown]
# ## Question 8: Which countries had the most influx of talent in 2018?

# %%
# Plotting the first Sankey diagram for top 50 countries - 2018

fig_3 = go.Figure(data=[go.Sankey(
    node = dict(
      pad = 20,
      thickness = 20,
      line = dict(color = "black", width = 1.0),
      label =  all_nodes_3,
      color =  node_colors,
    ),

    link = dict(
      source =  source_indices_3,
      target =  target_indices_3,
      value =  df_6_grouped.value,
      color = edge_colors,
))])
fig_3.update_layout(title_text="Net migration of workers between countries for the year 2018",
                  height=600,
                  font_size=10)
fig_3.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.6.3.min.js"></script>                <div id="1ae401dc-209f-49d5-a46f-98ed312335c6" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1ae401dc-209f-49d5-a46f-98ed312335c6")) {                    Plotly.newPlot(                        "1ae401dc-209f-49d5-a46f-98ed312335c6",                        [{"link":{"color":["#BCBD22","#BCBD22","#1F77B4","#D62728","#8C564B","#8C564B","#FF7F0E","#FF7F0E","#D62728","#D62728","#BCBD22","#FF7F0E","#8C564B","#FF7F0E","#BCBD22","#17BECF","#8C564B","#8C564B","#8C564B","#8C564B","#17BECF","#17BECF","#E377C2","#D62728","#7F7F7F","#BCBD22","#BCBD22","#1F77B4","#1F77B4","#BCBD22","#BCBD22","#FF7F0E","#FF7F0E","#E377C2","#E377C2","#2CA02C","#2CA02C","#2CA02C","#7F7F7F","#7F7F7F","#1F77B4","#E377C2","#7F7F7F","#E377C2","#E377C2","#E377C2","#D62728","#8C564B","#8C564B","#D62728"],"source":[0,1,2,3,3,5,6,7,8,8,8,11,12,13,14,15,16,16,18,19,20,20,22,22,22,22,22,22,28,29,30,31,31,33,34,35,36,37,38,38,40,41,41,43,43,45,46,46,48,49],"target":[50,51,50,50,40,50,51,51,58,59,60,51,62,62,50,65,66,50,40,62,70,50,72,73,14,50,76,60,62,76,50,50,82,50,51,2,51,66,50,40,62,50,92,73,14,59,70,50,51,62],"value":[8.72,18.0,16.76,30.52,7.6,18.42,25.59,9.27,10.57,33.59,12.2,11.59,23.27,30.26,10.08,9.21,15.79,15.53,11.38,10.05,12.65,36.08,29.6,91.41,17.15,8.29,18.26,11.52,9.81,17.62,14.45,13.24,10.38,10.46,14.62,9.96,13.24,36.47,52.77,8.75,15.24,19.86,14.44,15.49,7.69,12.49,8.86,57.91,10.48,12.22]},"node":{"color":["#BCBD22","#BCBD22","#1F77B4","#D62728","#8C564B","#8C564B","#FF7F0E","#FF7F0E","#D62728","#D62728","#BCBD22","#FF7F0E","#8C564B","#FF7F0E","#BCBD22","#17BECF","#8C564B","#8C564B","#8C564B","#8C564B","#17BECF","#17BECF","#E377C2","#D62728","#7F7F7F","#BCBD22","#BCBD22","#1F77B4","#1F77B4","#BCBD22","#BCBD22","#FF7F0E","#FF7F0E","#E377C2","#E377C2","#2CA02C","#2CA02C","#2CA02C","#7F7F7F","#7F7F7F","#1F77B4","#E377C2","#7F7F7F","#E377C2","#E377C2","#E377C2","#D62728","#8C564B","#8C564B","#D62728","#1F77B4","#9467BD","#2CA02C","#2CA02C","#D62728","#9467BD","#2CA02C","#9467BD","#D62728","#9467BD","#9467BD","#9467BD","#9467BD","#9467BD","#9467BD","#2CA02C","#8C564B","#D62728","#7F7F7F","#D62728","#2CA02C","#9467BD","#9467BD","#D62728","#9467BD","#7F7F7F","#9467BD","#2CA02C","#9467BD","#2CA02C","#BCBD22","#8C564B","#9467BD","#8C564B","#2CA02C","#2CA02C","#9467BD","#2CA02C","#9467BD","#9467BD","#D62728","#9467BD","#9467BD","#2CA02C","#7F7F7F","#9467BD","#BCBD22","#2CA02C","#9467BD","#9467BD"],"label":["Afghanistan","Argentina","Australia","Bahrain","Bahrain","Canada","Chile","Colombia","Cyprus","Cyprus","Cyprus","Ecuador","Gabon","Georgia","Germany","Hong Kong SAR, China","Ireland","Ireland","Jordan","Kenya","Kuwait","Kuwait","Luxembourg","Luxembourg","Luxembourg","Luxembourg","Luxembourg","Luxembourg","Malawi","Malta","Nepal","New Zealand","New Zealand","Oman","Panama","Papua New Guinea","Peru","Portugal","Qatar","Qatar","Saudi Arabia","Singapore","Singapore","Switzerland","Switzerland","Syrian Arab Republic","United Arab Emirates","United Arab Emirates","Uruguay","Zambia","India","Venezuela, RB","India","India","Saudi Arabia","India","Venezuela, RB","Venezuela, RB","Greece","Turkey","United Kingdom","Venezuela, RB","United States","United States","India","China","Brazil","India","Saudi Arabia","United States","Egypt, Arab Rep.","India","Belgium","France","Germany","India","Italy","United Kingdom","United States","Italy","India","India","South Africa","India","Venezuela, RB","Australia","Venezuela, RB","Brazil","India","Saudi Arabia","United States","India","Malaysia","France","Germany","Turkey","Egypt, Arab Rep.","India","Venezuela, RB","United States"],"line":{"color":"black","width":1.0},"pad":20,"thickness":20},"type":"sankey"}],                        {"template":{"data" ...

# %%
# Using the query function to get the data for only 2019 and sorting the data in ascending order


df_7_1=df_3_tidy.sort_values(by='value',ascending=False).query('Year=="2019"').head(50)
df_7_1.head()
# Out:
#       base_country_code     base_country_name  ...  Year  value
# 19079                lu            Luxembourg  ...  2019  87.71
# 18266                ge               Georgia  ...  2019  74.18
# 16625                ae  United Arab Emirates  ...  2019  55.60
# 19852                qa                 Qatar  ...  2019  51.95
# 19801                pt              Portugal  ...  2019  40.21
#
# [5 rows x 14 columns]

# %%
#Grouping the data by base country name and target country name

df_7_1 = df_7_1[df_7_1["base_country_name"]!="Net"]
df_7_grouped = df_7_1.groupby(by=["base_country_name","target_country_name"]).sum()[["value"]]
df_7_grouped = df_7_grouped.reset_index()
df_7_grouped.head()
# Out:
#   base_country_name target_country_name  value
# 0       Afghanistan              Brazil  13.72
# 1       Afghanistan               India  12.52
# 2         Argentina       Venezuela, RB   8.50
# 3         Australia               India  16.44
# 4           Bahrain               India  25.99

# %%
# Creating a list of all possible nodes for the sankey diagram
# Generating source nodes
# Generating target nodes

all_nodes_4 = df_7_grouped.base_country_name.values.tolist() + df_7_grouped.target_country_name.values.tolist()
source_indices_4 = [all_nodes_4.index(country) for country in df_7_grouped.base_country_name]
target_indices_4 = [all_nodes_4.index(measure) for measure in df_7_grouped.target_country_name]

colors = px.colors.qualitative.D3

node_colors_mappings_4 = dict([(node,np.random.choice(colors)) for node in all_nodes_4])

# %% [markdown]
# ## Question 9: Which countries had the most influx of talent in 2019?

# %%
# Plotting the first Sankey diagram for top 50 countries - 2019

fig_24 = go.Figure(data=[go.Sankey(
    node = dict(
      pad = 20,
      thickness = 20,
      line = dict(color = "black", width = 1.0),
      label =  all_nodes_4,
      color =  node_colors,
    ),

    link = dict(
      source =  source_indices_4,
      target =  target_indices_4,
      value =  df_7_grouped.value,
      color = edge_colors,
))])
fig_24.update_layout(title_text="Net migration of workers between countries for the year 2019",
                  height=600,
                  font_size=10)
fig_24.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.6.3.min.js"></script>                <div id="dbab826e-4e12-4d6e-b021-a30dfd9ace59" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dbab826e-4e12-4d6e-b021-a30dfd9ace59")) {                    Plotly.newPlot(                        "dbab826e-4e12-4d6e-b021-a30dfd9ace59",                        [{"link":{"color":["#BCBD22","#BCBD22","#1F77B4","#D62728","#8C564B","#8C564B","#FF7F0E","#FF7F0E","#D62728","#D62728","#BCBD22","#FF7F0E","#8C564B","#FF7F0E","#BCBD22","#17BECF","#8C564B","#8C564B","#8C564B","#8C564B","#17BECF","#17BECF","#E377C2","#D62728","#7F7F7F","#BCBD22","#BCBD22","#1F77B4","#1F77B4","#BCBD22","#BCBD22","#FF7F0E","#FF7F0E","#E377C2","#E377C2","#2CA02C","#2CA02C","#2CA02C","#7F7F7F","#7F7F7F","#1F77B4","#E377C2","#7F7F7F","#E377C2","#E377C2","#E377C2","#D62728","#8C564B","#8C564B","#D62728"],"source":[0,0,2,3,4,5,6,7,7,9,10,11,12,13,14,14,16,17,17,19,19,19,19,19,19,19,26,26,28,29,30,30,32,33,34,35,36,37,38,38,40,41,42,42,44,45,45,47,48,49],"target":[50,51,52,51,51,51,52,57,47,59,60,60,51,63,50,51,60,67,51,69,70,12,51,73,34,47,73,47,60,51,51,81,52,3,50,51,51,60,51,89,51,51,70,12,57,51,96,51,52,60],"value":[13.72,12.52,8.5,16.44,25.99,23.2,21.15,24.41,11.91,7.53,37.11,74.18,10.61,7.99,16.98,21.8,8.47,11.15,32.77,22.36,87.71,18.16,10.9,15.29,8.78,14.73,8.61,8.25,13.4,13.0,12.55,15.82,10.87,10.42,40.21,51.95,14.37,13.16,21.57,15.73,21.17,7.45,15.48,7.77,11.64,55.6,7.98,8.1,7.97,16.26]},"node":{"color":["#BCBD22","#BCBD22","#1F77B4","#D62728","#8C564B","#8C564B","#FF7F0E","#FF7F0E","#D62728","#D62728","#BCBD22","#FF7F0E","#8C564B","#FF7F0E","#BCBD22","#17BECF","#8C564B","#8C564B","#8C564B","#8C564B","#17BECF","#17BECF","#E377C2","#D62728","#7F7F7F","#BCBD22","#BCBD22","#1F77B4","#1F77B4","#BCBD22","#BCBD22","#FF7F0E","#FF7F0E","#E377C2","#E377C2","#2CA02C","#2CA02C","#2CA02C","#7F7F7F","#7F7F7F","#1F77B4","#E377C2","#7F7F7F","#E377C2","#E377C2","#E377C2","#D62728","#8C564B","#8C564B","#D62728","#1F77B4","#9467BD","#2CA02C","#2CA02C","#D62728","#9467BD","#2CA02C","#9467BD","#D62728","#9467BD","#9467BD","#9467BD","#9467BD","#9467BD","#9467BD","#2CA02C","#8C564B","#D62728","#7F7F7F","#D62728","#2CA02C","#9467BD","#9467BD","#D62728","#9467BD","#7F7F7F","#9467BD","#2CA02C","#9467BD","#2CA02C","#BCBD22","#8C564B","#9467BD","#8C564B","#2CA02C","#2CA02C","#9467BD","#2CA02C","#9467BD","#9467BD","#D62728","#9467BD","#9467BD","#2CA02C","#7F7F7F","#9467BD","#BCBD22","#2CA02C","#9467BD","#9467BD"],"label":["Afghanistan","Afghanistan","Argentina","Australia","Bahrain","Canada","Chile","Cyprus","Cyprus","Estonia","Gabon","Georgia","Germany","Hong Kong SAR, China","Ireland","Ireland","Kenya","Kuwait","Kuwait","Luxembourg","Luxembourg","Luxembourg","Luxembourg","Luxembourg","Luxembourg","Luxembourg","Malta","Malta","Myanmar","Nepal","New Zealand","New Zealand","Panama","Papua New Guinea","Portugal","Qatar","Rwanda","Saudi Arabia","Singapore","Singapore","Sudan","Sweden","Switzerland","Switzerland","Syrian Arab Republic","United Arab Emirates","United Arab Emirates","United Kingdom","Uruguay","Zambia","Brazil","India","Venezuela, RB","India","India","India","Venezuela, RB","Turkey","United Kingdom","Ukraine","United States","United States","India","China","Brazil","India","United States","Egypt, Arab Rep.","India","Belgium","France","Germany","India","Italy","Portugal","United Kingdom","Italy","United Kingdom","United States","India","India","South Africa","Venezuela, RB","Australia","Brazil","India","India","United States","India","Malaysia","India","India","France","Germany","Turkey","India","Pakistan","India","Venezuela, RB","United States"],"line":{"color":"black","width":1.0},"pad":20,"thickness":20},"type":"sankey"}],                        {"template":{"data":{"bar":[{"error_x":{"colo ...

# %% [markdown]
# #### Dataset 4: Linkedin Employment Growth from Industry Transition
#
# - Here I've cleaned and plotted the Employment Growth data of each year from 2015 to 2019 with Linkedin Industry transition from 2015 to 2019 on a bar chart for testing my hypothesis.
#
# ---

# %%
#Employment growth from industry transition dataset 2015 to 2019
# Having a look at the top few rows of the data

df_9.head()
# Out:
#   country_code          country_name  ... growth_rate_2018 growth_rate_2019
# 0           ae  United Arab Emirates  ...         1.004815        -0.062138
# 1           ae  United Arab Emirates  ...         1.851416         2.260594
# 2           ae  United Arab Emirates  ...         4.814815         2.842339
# 3           ae  United Arab Emirates  ...         0.598991         0.431699
# 4           ae  United Arab Emirates  ...         1.504827         0.081610
#
# [5 rows x 13 columns]

# %%
# Checking the number of rows and columns of the dataset

df_9.shape
# Out:
# (7335, 13)

# %%
# Checking for null values
df_9.isnull().sum()
# Out:
# country_code          0
# country_name          0
# wb_region             0
# wb_income             0
# isic_section_index    0
# isic_section_name     0
# industry_id           0
# industry_name         0
# growth_rate_2015      0
# growth_rate_2016      0
# growth_rate_2017      0
# growth_rate_2018      0
# growth_rate_2019      0
# dtype: int64

# %%
#Renaming the four year columns so that we have only the year as the column header

df_9_2= df_9.rename({'growth_rate_2015': '2015', 'growth_rate_2016': '2016', 'growth_rate_2017': '2017', 'growth_rate_2018': '2018', 'growth_rate_2019': '2019'}, axis=1)
df_9_2.head(3)
# Out:
#   country_code          country_name  ...      2018      2019
# 0           ae  United Arab Emirates  ...  1.004815 -0.062138
# 1           ae  United Arab Emirates  ...  1.851416  2.260594
# 2           ae  United Arab Emirates  ...  4.814815  2.842339
#
# [3 rows x 13 columns]

# %%
# Using the melt function to convert the data into long format from a wide format

df_9_tidy=pd.melt(df_9_2,
             id_vars=['country_code','country_name','wb_region','wb_income','isic_section_index','isic_section_name','industry_id','industry_name'],
             var_name='Year',
             value_name='value' #giving the column name as 'value' because I need to combine all 4 datasets at the end
                  )
df_9_tidy.head(3)
# Out:
#   country_code          country_name  ...  Year      value
# 0           ae  United Arab Emirates  ...  2015   7.800000
# 1           ae  United Arab Emirates  ...  2015   3.301483
# 2           ae  United Arab Emirates  ...  2015  17.136659
#
# [3 rows x 10 columns]

# %%
# Arranging the data in descending order and filter out only the data for the year 2015

df_9_2015_1=df_9_tidy.sort_values(by='value',ascending=False).query('Year=="2015"')
df_9_2015_1.head()
# Out:
#      country_code  country_name  ...  Year       value
# 1595           cy        Cyprus  ...  2015  108.450704
# 4108           lu    Luxembourg  ...  2015   60.902256
# 4131           lu    Luxembourg  ...  2015   54.054054
# 5919           sa  Saudi Arabia  ...  2015   42.187500
# 4406           mm       Myanmar  ...  2015   40.924092
#
# [5 rows x 10 columns]

# %%
# Grouping the data by industry name

df_9_2015_grouped = df_9_2015_1.groupby(by=["industry_name"]).mean()[["value"]].reset_index()
df_9_2015_grouped.head()
# Out:
#                     industry_name     value
# 0                      Accounting -2.822065
# 1  Alternative Dispute Resolution  1.790485
# 2                       Animation  1.162554
# 3         Architecture & Planning -0.596580
# 4                   Arts & Crafts  0.255324

# %%
# Arranging the data in descending order and filter out only the data for the year 2015

df_2_2015_1=df_2_tidy.sort_values(by='value',ascending=False).query('Year=="2015"')
df_2_2015_1.head(3)
# Out:
#      country_code          country_name  ...  Year    value
# 101            ae  United Arab Emirates  ...  2015  2280.60
# 3165           lu            Luxembourg  ...  2015  2054.79
# 4              ae  United Arab Emirates  ...  2015  1840.33
#
# [3 rows x 10 columns]

# %%
df_2_2015_grouped = df_2_2015_1.groupby(by=["industry_name"]).mean()[["value"]].reset_index()
df_2_2015_grouped.head()
# Out:
#              industry_name       value
# 0               Accounting   56.659275
# 1        Airlines/Aviation   40.550000
# 2                Animation  206.468182
# 3        Apparel & Fashion  126.884667
# 4  Architecture & Planning   89.301509

# %% [markdown]
# # Testing our Hypothesis:
#
# ### Migration of workers into an industry leads to growth of that industry
#
#
#   - In the following graphs, we'll compare industry migration for each year with the growth of industries in that year and we'll try to see if the industry which had the most incoming migrants showed the most growth.
#   - We'll check this for all years from 2015 to 2019.
#
# ---

# %%
# Plotting the average growth in each industry across the world for the year 2015

fig_28 = px.bar(df_9_2015_grouped.sort_values(by='value',ascending=False).head(20), 
                x="industry_name", 
                y="value",
                title="Average Growth in industry vs Industry name - 2015",
                labels={"industry_name":"Industry Name","value":"Average Growth in Industry across the world(in %)"},
                color="industry_name",
                #hover_data=['Year','country_name'],
                height=500
                ).update_xaxes(categoryorder="total ascending")

fig_28.show()

#Plotting the average industry migration vs industry for the year 2015

fig_29 = px.bar(df_2_2015_grouped.sort_values(by='value',ascending=False).head(20), 
                x="industry_name", 
                y="value",
                title="Plotting average industry migration per 10k vs industry (country wise) - 2015",
                labels={"industry_name":"Industry Name","value":"Average migration per 10k"},
                color="industry_name",
                #hover_data=['Year','country_name'],
                height=500
                ).update_xaxes(categoryorder="total ascending")

fig_29.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.6.3.min.js"></script>                <div id="43c923b8-d192-4aa6-9413-80dc15ea89de" class="plotly-graph-div" style="height:500px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("43c923b8-d192-4aa6-9413-80dc15ea89de")) {                    Plotly.newPlot(                        "43c923b8-d192-4aa6-9413-80dc15ea89de",                        [{"alignmentgroup":"True","hovertemplate":"Industry Name=%{x}<br>Average Growth in Industry across the world(in %)=%{y}<extra></extra>","legendgroup":"Venture Capital & Private Equity","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Venture Capital & Private Equity","offsetgroup":"Venture Capital & Private Equity","orientation":"v","showlegend":true,"textposition":"auto","x":["Venture Capital & Private Equity"],"xaxis":"x","y":[3.397227235318181],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Industry Name=%{x}<br>Average Growth in Industry across the world(in %)=%{y}<extra></extra>","legendgroup":"Internet","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Internet","offsetgroup":"Internet","orientation":"v","showlegend":true,"textposition":"auto","x":["Internet"],"xaxis":"x","y":[2.329660116881893],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Industry Name=%{x}<br>Average Growth in Industry across the world(in %)=%{y}<extra></extra>","legendgroup":"Biotechnology","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Biotechnology","offsetgroup":"Biotechnology","orientation":"v","showlegend":true,"textposition":"auto","x":["Biotechnology"],"xaxis":"x","y":[2.1336206653052625],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Industry Name=%{x}<br>Average Growth in Industry across the world(in %)=%{y}<extra></extra>","legendgroup":"Aviation & Aerospace","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Aviation & Aerospace","offsetgroup":"Aviation & Aerospace","orientation":"v","showlegend":true,"textposition":"auto","x":["Aviation & Aerospace"],"xaxis":"x","y":[2.0899002894842122],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Industry Name=%{x}<br>Average Growth in Industry across the world(in %)=%{y}<extra></extra>","legendgroup":"Renewables & Environment","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Renewables & Environment","offsetgroup":"Renewables & Environment","orientation":"v","showlegend":true,"textposition":"auto","x":["Renewables & Environment"],"xaxis":"x","y":[2.0220482718288286],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Industry Name=%{x}<br>Average Growth in Industry across the world(in %)=%{y}<extra></extra>","legendgroup":"Computer & Network Security","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Computer & Network Security","offsetgroup":"Computer & Network Security","orientation":"v","showlegend":true,"textposition":"auto","x":["Computer & Network Security"],"xaxis":"x","y":[1.9936557206043948],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Industry Name=%{x}<br>Average Growth in Industry across the world(in %)=%{y}<extra></extra>","legendgroup":"Executive Office","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Executive Office","offsetgroup":"Executive Office","orientation":"v","showlegend":true,"textposition":"auto","x":["Executive Office"],"xaxis":"x","y":[1.8229153875526303],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Industry Name=%{x}<br>Average Growth in Industry across the world(in %)=%{y}<extra></extra>","legendgroup":"Alternative Dispute Resolution","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Alternative Dispute Resolution","offsetgroup":"Alternative Dispute Resolution","orientation":"v","showlegend":true,"textpositi ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.6.3.min.js"></script>                <div id="04257186-68e1-4483-b288-37fcc4db484d" class="plotly-graph-div" style="height:500px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("04257186-68e1-4483-b288-37fcc4db484d")) {                    Plotly.newPlot(                        "04257186-68e1-4483-b288-37fcc4db484d",                        [{"alignmentgroup":"True","hovertemplate":"Industry Name=%{x}<br>Average migration per 10k=%{y}<extra></extra>","legendgroup":"Venture Capital & Private Equity","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Venture Capital & Private Equity","offsetgroup":"Venture Capital & Private Equity","orientation":"v","showlegend":true,"textposition":"auto","x":["Venture Capital & Private Equity"],"xaxis":"x","y":[359.56105263157883],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Industry Name=%{x}<br>Average migration per 10k=%{y}<extra></extra>","legendgroup":"E-Learning","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"E-Learning","offsetgroup":"E-Learning","orientation":"v","showlegend":true,"textposition":"auto","x":["E-Learning"],"xaxis":"x","y":[355.12208333333336],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Industry Name=%{x}<br>Average migration per 10k=%{y}<extra></extra>","legendgroup":"Computer & Network Security","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Computer & Network Security","offsetgroup":"Computer & Network Security","orientation":"v","showlegend":true,"textposition":"auto","x":["Computer & Network Security"],"xaxis":"x","y":[242.97500000000002],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Industry Name=%{x}<br>Average migration per 10k=%{y}<extra></extra>","legendgroup":"Capital Markets","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Capital Markets","offsetgroup":"Capital Markets","orientation":"v","showlegend":true,"textposition":"auto","x":["Capital Markets"],"xaxis":"x","y":[236.9409090909091],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Industry Name=%{x}<br>Average migration per 10k=%{y}<extra></extra>","legendgroup":"Internet","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Internet","offsetgroup":"Internet","orientation":"v","showlegend":true,"textposition":"auto","x":["Internet"],"xaxis":"x","y":[223.3641095890411],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Industry Name=%{x}<br>Average migration per 10k=%{y}<extra></extra>","legendgroup":"Renewables & Environment","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Renewables & Environment","offsetgroup":"Renewables & Environment","orientation":"v","showlegend":true,"textposition":"auto","x":["Renewables & Environment"],"xaxis":"x","y":[221.20282608695643],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Industry Name=%{x}<br>Average migration per 10k=%{y}<extra></extra>","legendgroup":"Animation","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Animation","offsetgroup":"Animation","orientation":"v","showlegend":true,"textposition":"auto","x":["Animation"],"xaxis":"x","y":[206.46818181818182],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Industry Name=%{x}<br>Average migration per 10k=%{y}<extra></extra>","legendgroup":"Primary/Secondary Education","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Primary/Secondary Education","offsetgroup":"Primary/Secondary Education","orientation":"v","showlegend":true,"textposition":"auto","x":["Primary/Secondary Education"],"xaxis":"x","y":[197.32121212121223],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Industry Name=%{x}<br>Average migration per 10k=%{y}<extra></extra>","legendgroup":"Executive Office","marker ...

# %% [markdown]
# ### Inference from the graphs
#
# - By comparing these two graphs of Average Growth in Industry Vs Average Industry Migration for the year 2015, we can conclude that there is some correlation between the two and Industry Nigration does affect Growth of an Industry, but that is the case in some industires and not all. Hence, our Hypothesis is partially true and not completely true

# %% [markdown]
# ### 2. Now we'll check the same for the year 2016
# - i.e :  we'll compare industry migration for each year with the growth of industries in that year and we'll try to see if the industry which had the most incoming migrants showed the most growth.

# %%
# Arranging the data in descending order and filter out only the data for the year 2015

df_9_2016_1=df_9_tidy.sort_values(by='value',ascending=False).query('Year=="2016"')
df_9_2016_1.head()
# Out:
#       country_code          country_name  ...  Year      value
# 8930            cy                Cyprus  ...  2016  76.041667
# 11377           lt             Lithuania  ...  2016  59.322034
# 7776            az            Azerbaijan  ...  2016  37.583893
# 10902           jp                 Japan  ...  2016  36.197183
# 7368            ae  United Arab Emirates  ...  2016  35.074627
#
# [5 rows x 10 columns]

# %%
# Grouping the data by industry name

df_9_2016_grouped = df_9_2016_1.groupby(by=["industry_name"]).mean()[["value"]].reset_index()
df_9_2016_grouped.head()
# Out:
#                     industry_name     value
# 0                      Accounting -2.147486
# 1  Alternative Dispute Resolution  5.334737
# 2                       Animation  0.932062
# 3         Architecture & Planning -0.517969
# 4                   Arts & Crafts  0.210892

# %%
# Arranging the data in descending order and filter out only the data for the year 2016

df_2_2016_1=df_2_tidy.sort_values(by='value',ascending=False).query('Year=="2016"')
df_2_2016_1.head(3)
# Out:
#      country_code          country_name  ...  Year    value
# 8454           lu            Luxembourg  ...  2016  1787.58
# 5404           ae  United Arab Emirates  ...  2016  1616.52
# 5396           ae  United Arab Emirates  ...  2016  1492.85
#
# [3 rows x 10 columns]

# %%
df_2_2016_grouped = df_2_2016_1.groupby(by=["industry_name"]).mean()[["value"]].reset_index()
df_2_2016_grouped.head()
# Out:
#              industry_name       value
# 0               Accounting   55.480435
# 1        Airlines/Aviation   31.089265
# 2                Animation  290.241818
# 3        Apparel & Fashion   83.243778
# 4  Architecture & Planning   31.397358

# %%
# Plotting the average growth in each industry across the world for the year 2016

fig_30 = px.bar(df_9_2016_grouped.sort_values(by='value',ascending=False).head(20), 
                x="industry_name", 
                y="value",
                title="Growth in industry vs Industry name - 2016",
                labels={"industry_name":"Industry Name","value":"Growth in Industry across the world(in %)"},
                color="industry_name",
                #hover_data=['Year','country_name'],
                height=500
                ).update_xaxes(categoryorder="total ascending")

fig_30.show()

#Plotting the average industry migration vs industry for the year 2016

fig_31 = px.bar(df_2_2016_grouped.sort_values(by='value',ascending=False).head(20), 
                x="industry_name", 
                y="value",
                title="Plotting average industry migration per 10k vs industry (country wise) - 2016",
                labels={"industry_name":"Industry Name","value":"Average migration per 10k"},
                color="industry_name",
                #hover_data=['Year','country_name'],
                height=500
                ).update_xaxes(categoryorder="total ascending")

fig_31.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.6.3.min.js"></script>                <div id="637bee80-e584-48ba-a4a0-7f4efd0d1f64" class="plotly-graph-div" style="height:500px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("637bee80-e584-48ba-a4a0-7f4efd0d1f64")) {                    Plotly.newPlot(                        "637bee80-e584-48ba-a4a0-7f4efd0d1f64",                        [{"alignmentgroup":"True","hovertemplate":"Industry Name=%{x}<br>Growth in Industry across the world(in %)=%{y}<extra></extra>","legendgroup":"Alternative Dispute Resolution","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Alternative Dispute Resolution","offsetgroup":"Alternative Dispute Resolution","orientation":"v","showlegend":true,"textposition":"auto","x":["Alternative Dispute Resolution"],"xaxis":"x","y":[5.334737314333332],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Industry Name=%{x}<br>Growth in Industry across the world(in %)=%{y}<extra></extra>","legendgroup":"Venture Capital & Private Equity","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Venture Capital & Private Equity","offsetgroup":"Venture Capital & Private Equity","orientation":"v","showlegend":true,"textposition":"auto","x":["Venture Capital & Private Equity"],"xaxis":"x","y":[3.659387247848484],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Industry Name=%{x}<br>Growth in Industry across the world(in %)=%{y}<extra></extra>","legendgroup":"Computer & Network Security","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Computer & Network Security","offsetgroup":"Computer & Network Security","orientation":"v","showlegend":true,"textposition":"auto","x":["Computer & Network Security"],"xaxis":"x","y":[2.8924974696153836],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Industry Name=%{x}<br>Growth in Industry across the world(in %)=%{y}<extra></extra>","legendgroup":"Aviation & Aerospace","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Aviation & Aerospace","offsetgroup":"Aviation & Aerospace","orientation":"v","showlegend":true,"textposition":"auto","x":["Aviation & Aerospace"],"xaxis":"x","y":[2.3517570091473687],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Industry Name=%{x}<br>Growth in Industry across the world(in %)=%{y}<extra></extra>","legendgroup":"Renewables & Environment","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Renewables & Environment","offsetgroup":"Renewables & Environment","orientation":"v","showlegend":true,"textposition":"auto","x":["Renewables & Environment"],"xaxis":"x","y":[2.2990927739999982],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Industry Name=%{x}<br>Growth in Industry across the world(in %)=%{y}<extra></extra>","legendgroup":"Internet","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Internet","offsetgroup":"Internet","orientation":"v","showlegend":true,"textposition":"auto","x":["Internet"],"xaxis":"x","y":[1.5905986030472439],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Industry Name=%{x}<br>Growth in Industry across the world(in %)=%{y}<extra></extra>","legendgroup":"Executive Office","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Executive Office","offsetgroup":"Executive Office","orientation":"v","showlegend":true,"textposition":"auto","x":["Executive Office"],"xaxis":"x","y":[1.577041935855263],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Industry Name=%{x}<br>Growth in Industry across the world(in %)=%{y}<extra></extra>","legendgroup":"Biotechnology","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Biotechnology","offsetgroup":"Biotechnology","orientation":"v","showlegend":true,"textposition":"auto","x":["Biotechnology"],"xaxis":"x","y" ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.6.3.min.js"></script>                <div id="4f145b5b-7e3d-46ad-a3ac-09b6f61ba3bc" class="plotly-graph-div" style="height:500px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4f145b5b-7e3d-46ad-a3ac-09b6f61ba3bc")) {                    Plotly.newPlot(                        "4f145b5b-7e3d-46ad-a3ac-09b6f61ba3bc",                        [{"alignmentgroup":"True","hovertemplate":"Industry Name=%{x}<br>Average migration per 10k=%{y}<extra></extra>","legendgroup":"Venture Capital & Private Equity","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Venture Capital & Private Equity","offsetgroup":"Venture Capital & Private Equity","orientation":"v","showlegend":true,"textposition":"auto","x":["Venture Capital & Private Equity"],"xaxis":"x","y":[307.42157894736846],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Industry Name=%{x}<br>Average migration per 10k=%{y}<extra></extra>","legendgroup":"Animation","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Animation","offsetgroup":"Animation","orientation":"v","showlegend":true,"textposition":"auto","x":["Animation"],"xaxis":"x","y":[290.2418181818182],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Industry Name=%{x}<br>Average migration per 10k=%{y}<extra></extra>","legendgroup":"E-Learning","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"E-Learning","offsetgroup":"E-Learning","orientation":"v","showlegend":true,"textposition":"auto","x":["E-Learning"],"xaxis":"x","y":[282.82416666666666],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Industry Name=%{x}<br>Average migration per 10k=%{y}<extra></extra>","legendgroup":"Renewables & Environment","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Renewables & Environment","offsetgroup":"Renewables & Environment","orientation":"v","showlegend":true,"textposition":"auto","x":["Renewables & Environment"],"xaxis":"x","y":[218.20391304347828],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Industry Name=%{x}<br>Average migration per 10k=%{y}<extra></extra>","legendgroup":"Commercial Real Estate","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Commercial Real Estate","offsetgroup":"Commercial Real Estate","orientation":"v","showlegend":true,"textposition":"auto","x":["Commercial Real Estate"],"xaxis":"x","y":[192.35999999999999],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Industry Name=%{x}<br>Average migration per 10k=%{y}<extra></extra>","legendgroup":"Computer & Network Security","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Computer & Network Security","offsetgroup":"Computer & Network Security","orientation":"v","showlegend":true,"textposition":"auto","x":["Computer & Network Security"],"xaxis":"x","y":[189.14],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Industry Name=%{x}<br>Average migration per 10k=%{y}<extra></extra>","legendgroup":"Internet","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Internet","offsetgroup":"Internet","orientation":"v","showlegend":true,"textposition":"auto","x":["Internet"],"xaxis":"x","y":[182.9631506849316],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Industry Name=%{x}<br>Average migration per 10k=%{y}<extra></extra>","legendgroup":"Gambling & Casinos","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Gambling & Casinos","offsetgroup":"Gambling & Casinos","orientation":"v","showlegend":true,"textposition":"auto","x":["Gambling & Casinos"],"xaxis":"x","y":[179.8706666666666],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Industry Name=%{x}<br>Average migration per 10k=%{y}<extra></extra>","legendgroup":"Motion Pictures & Film","marker":{"color":"#FF ...

# %% [markdown]
# ### Inference from the graphs
#
# - By comparing these two graphs of Average Growth in Industry Vs Average Industry Migration for the year 2016, we can conclude that there is some correlation between the two and Industry Nigration does affect Growth of an Industry, but that is the case in some industires and not all. Hence, our Hypothesis is partially true and not completely true

# %% [markdown]
# ### 3. Now we'll check the same for the year 2017
# - i.e :  we'll compare industry migration for each year with the growth of industries in that year and we'll try to see if the industry which had the most incoming migrants showed the most growth.

# %%
# Arranging the data in descending order and filter out only the data for the year 2017

df_9_2017_1=df_9_tidy.sort_values(by='value',ascending=False).query('Year=="2017"')
df_9_2017_1.head(3)
# Out:
#       country_code country_name  ...  Year      value
# 16265           cy       Cyprus  ...  2017  45.985401
# 16202           cr   Costa Rica  ...  2017  29.477612
# 17191           ge      Georgia  ...  2017  29.032258
#
# [3 rows x 10 columns]

# %%
# Grouping the data by industry name

df_9_2017_grouped = df_9_2017_1.groupby(by=["industry_name"]).mean()[["value"]].reset_index()
df_9_2017_grouped.head()
# Out:
#                     industry_name     value
# 0                      Accounting -2.421918
# 1  Alternative Dispute Resolution  2.909024
# 2                       Animation  2.024420
# 3         Architecture & Planning -0.467918
# 4                   Arts & Crafts  0.456148

# %%
# Arranging the data in descending order and filter out only the data for the year 2016

df_2_2017_1=df_2_tidy.sort_values(by='value',ascending=False).query('Year=="2017"')
df_2_2017_1.head(3)
# Out:
#       country_code          country_name  ...  Year    value
# 13749           lu            Luxembourg  ...  2017  1981.38
# 10691           ae  United Arab Emirates  ...  2017  1362.36
# 13756           lu            Luxembourg  ...  2017  1216.73
#
# [3 rows x 10 columns]

# %%
df_2_2017_grouped = df_2_2017_1.groupby(by=["industry_name"]).mean()[["value"]].reset_index()
df_2_2017_grouped.head()
# Out:
#              industry_name       value
# 0               Accounting   45.165217
# 1        Airlines/Aviation   17.095294
# 2                Animation  167.250909
# 3        Apparel & Fashion   59.191778
# 4  Architecture & Planning   52.910755

# %%
# Plotting the average growth in each industry across the world for the year 2017

fig_32 = px.bar(df_9_2017_grouped.sort_values(by='value',ascending=False).head(20), 
                x="industry_name", 
                y="value",
                title="Growth in industry vs Industry name - 2017",
                labels={"industry_name":"Industry Name","value":"Growth in Industry across the world(in %)"},
                color="industry_name",
                #hover_data=['Year','country_name'],
                height=500
                ).update_xaxes(categoryorder="total ascending")

fig_32.show()

#Plotting the average industry migration vs industry for the year 2017

fig_33 = px.bar(df_2_2017_grouped.sort_values(by='value',ascending=False).head(20), 
                x="industry_name", 
                y="value",
                title="Plotting average industry migration per 10k vs industry (country wise) - 2017",
                labels={"industry_name":"Industry Name","value":"Average migration per 10k"},
                color="industry_name",
                #hover_data=['Year','country_name'],
                height=500
                ).update_xaxes(categoryorder="total ascending")

fig_33.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.6.3.min.js"></script>                <div id="3cba81a7-76d8-4099-82ce-6b25c3d977c2" class="plotly-graph-div" style="height:500px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3cba81a7-76d8-4099-82ce-6b25c3d977c2")) {                    Plotly.newPlot(                        "3cba81a7-76d8-4099-82ce-6b25c3d977c2",                        [{"alignmentgroup":"True","hovertemplate":"Industry Name=%{x}<br>Growth in Industry across the world(in %)=%{y}<extra></extra>","legendgroup":"Venture Capital & Private Equity","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Venture Capital & Private Equity","offsetgroup":"Venture Capital & Private Equity","orientation":"v","showlegend":true,"textposition":"auto","x":["Venture Capital & Private Equity"],"xaxis":"x","y":[4.151968931696969],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Industry Name=%{x}<br>Growth in Industry across the world(in %)=%{y}<extra></extra>","legendgroup":"Alternative Dispute Resolution","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Alternative Dispute Resolution","offsetgroup":"Alternative Dispute Resolution","orientation":"v","showlegend":true,"textposition":"auto","x":["Alternative Dispute Resolution"],"xaxis":"x","y":[2.909023645833333],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Industry Name=%{x}<br>Growth in Industry across the world(in %)=%{y}<extra></extra>","legendgroup":"Renewables & Environment","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Renewables & Environment","offsetgroup":"Renewables & Environment","orientation":"v","showlegend":true,"textposition":"auto","x":["Renewables & Environment"],"xaxis":"x","y":[2.350494551162161],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Industry Name=%{x}<br>Growth in Industry across the world(in %)=%{y}<extra></extra>","legendgroup":"Animation","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Animation","offsetgroup":"Animation","orientation":"v","showlegend":true,"textposition":"auto","x":["Animation"],"xaxis":"x","y":[2.0244200535384618],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Industry Name=%{x}<br>Growth in Industry across the world(in %)=%{y}<extra></extra>","legendgroup":"Computer & Network Security","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Computer & Network Security","offsetgroup":"Computer & Network Security","orientation":"v","showlegend":true,"textposition":"auto","x":["Computer & Network Security"],"xaxis":"x","y":[1.9326428369010984],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Industry Name=%{x}<br>Growth in Industry across the world(in %)=%{y}<extra></extra>","legendgroup":"Wireless","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Wireless","offsetgroup":"Wireless","orientation":"v","showlegend":true,"textposition":"auto","x":["Wireless"],"xaxis":"x","y":[1.8549683862586213],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Industry Name=%{x}<br>Growth in Industry across the world(in %)=%{y}<extra></extra>","legendgroup":"Mining & Metals","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Mining & Metals","offsetgroup":"Mining & Metals","orientation":"v","showlegend":true,"textposition":"auto","x":["Mining & Metals"],"xaxis":"x","y":[1.6960091654576246],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Industry Name=%{x}<br>Growth in Industry across the world(in %)=%{y}<extra></extra>","legendgroup":"Investment Management","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Investment Management","offsetgroup":"Investment Management","orientation":"v","showlegend":true,"textposition":"auto","x":["Investment Management"],"xaxis":"x","y":[1.434660139681 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.6.3.min.js"></script>                <div id="0ec36e57-492e-4208-8e34-ca6f7b7d251f" class="plotly-graph-div" style="height:500px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0ec36e57-492e-4208-8e34-ca6f7b7d251f")) {                    Plotly.newPlot(                        "0ec36e57-492e-4208-8e34-ca6f7b7d251f",                        [{"alignmentgroup":"True","hovertemplate":"Industry Name=%{x}<br>Average migration per 10k=%{y}<extra></extra>","legendgroup":"Venture Capital & Private Equity","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Venture Capital & Private Equity","offsetgroup":"Venture Capital & Private Equity","orientation":"v","showlegend":true,"textposition":"auto","x":["Venture Capital & Private Equity"],"xaxis":"x","y":[288.9184210526317],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Industry Name=%{x}<br>Average migration per 10k=%{y}<extra></extra>","legendgroup":"E-Learning","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"E-Learning","offsetgroup":"E-Learning","orientation":"v","showlegend":true,"textposition":"auto","x":["E-Learning"],"xaxis":"x","y":[251.18625],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Industry Name=%{x}<br>Average migration per 10k=%{y}<extra></extra>","legendgroup":"Animation","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Animation","offsetgroup":"Animation","orientation":"v","showlegend":true,"textposition":"auto","x":["Animation"],"xaxis":"x","y":[167.25090909090906],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Industry Name=%{x}<br>Average migration per 10k=%{y}<extra></extra>","legendgroup":"Computer & Network Security","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Computer & Network Security","offsetgroup":"Computer & Network Security","orientation":"v","showlegend":true,"textposition":"auto","x":["Computer & Network Security"],"xaxis":"x","y":[165.98],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Industry Name=%{x}<br>Average migration per 10k=%{y}<extra></extra>","legendgroup":"Capital Markets","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Capital Markets","offsetgroup":"Capital Markets","orientation":"v","showlegend":true,"textposition":"auto","x":["Capital Markets"],"xaxis":"x","y":[164.76454545454544],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Industry Name=%{x}<br>Average migration per 10k=%{y}<extra></extra>","legendgroup":"Philanthropy","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Philanthropy","offsetgroup":"Philanthropy","orientation":"v","showlegend":true,"textposition":"auto","x":["Philanthropy"],"xaxis":"x","y":[160.02899999999997],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Industry Name=%{x}<br>Average migration per 10k=%{y}<extra></extra>","legendgroup":"Information Services","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Information Services","offsetgroup":"Information Services","orientation":"v","showlegend":true,"textposition":"auto","x":["Information Services"],"xaxis":"x","y":[159.70269230769236],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Industry Name=%{x}<br>Average migration per 10k=%{y}<extra></extra>","legendgroup":"Gambling & Casinos","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Gambling & Casinos","offsetgroup":"Gambling & Casinos","orientation":"v","showlegend":true,"textposition":"auto","x":["Gambling & Casinos"],"xaxis":"x","y":[149.3973333333333],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Industry Name=%{x}<br>Average migration per 10k=%{y}<extra></extra>","legendgroup":"Internet","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Internet","o ...

# %% [markdown]
# ### Inference from the graphs
#
# - By comparing these two graphs of Average Growth in Industry Vs Average Industry Migration for the year 2017, we can conclude that there is some correlation between the two and Industry Nigration does affect Growth of an Industry, but that is the case in some industires and not all. Hence, our Hypothesis is partially true and not completely true

# %% [markdown]
# ### 4. Now we'll check the same for the year 2018
# - i.e :  we'll compare industry migration for each year with the growth of industries in that year and we'll try to see if the industry which had the most incoming migrants showed the most growth.

# %%
# Arranging the data in descending order and filter out only the data for the year 2018

df_9_2018_1=df_9_tidy.sort_values(by='value',ascending=False).query('Year=="2018"')
df_9_2018_1.head(3)
# Out:
#       country_code country_name  ...  Year      value
# 27099           om         Oman  ...  2018  31.707317
# 27759           qa        Qatar  ...  2018  28.767123
# 27061           nz  New Zealand  ...  2018  27.142857
#
# [3 rows x 10 columns]

# %%
# Grouping the data by industry name

df_9_2018_grouped = df_9_2018_1.groupby(by=["industry_name"]).mean()[["value"]].reset_index()
df_9_2018_grouped.head()
# Out:
#                     industry_name     value
# 0                      Accounting -1.794996
# 1  Alternative Dispute Resolution  2.034910
# 2                       Animation  1.951378
# 3         Architecture & Planning -0.192784
# 4                   Arts & Crafts  0.143605

# %%
# Arranging the data in descending order and filter out only the data for the year 2018

df_2_2018_1=df_2_tidy.sort_values(by='value',ascending=False).query('Year=="2018"')
df_2_2018_1.head(3)
# Out:
#       country_code          country_name  ...  Year    value
# 19059           lu            Luxembourg  ...  2018  1500.00
# 19050           lu            Luxembourg  ...  2018  1287.36
# 15923           ae  United Arab Emirates  ...  2018  1187.61
#
# [3 rows x 10 columns]

# %%
df_2_2018_grouped = df_2_2018_1.groupby(by=["industry_name"]).mean()[["value"]].reset_index()
df_2_2018_grouped.head()
# Out:
#              industry_name       value
# 0               Accounting   50.902174
# 1        Airlines/Aviation    6.232206
# 2                Animation  119.192727
# 3        Apparel & Fashion   49.491556
# 4  Architecture & Planning   16.225094

# %%
# Plotting the average growth in each industry across the world for the year 2018

fig_34 = px.bar(df_9_2018_grouped.sort_values(by='value',ascending=False).head(20), 
                x="industry_name", 
                y="value",
                title="Growth in industry vs Industry name - 2018",
                labels={"industry_name":"Industry Name","value":"Growth in Industry across the world(in %)"},
                color="industry_name",
                #hover_data=['Year','country_name'],
                height=500
                ).update_xaxes(categoryorder="total ascending")

fig_34.show()

#Plotting the average industry migration vs industry for the year 2018

fig_35 = px.bar(df_2_2018_grouped.sort_values(by='value',ascending=False).head(20), 
                x="industry_name", 
                y="value",
                title="Plotting average industry migration per 10k vs industry (country wise) - 2018",
                labels={"industry_name":"Industry Name","value":"Average migration per 10k"},
                color="industry_name",
                #hover_data=['Year','country_name'],
                height=500
                ).update_xaxes(categoryorder="total ascending")

fig_35.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.6.3.min.js"></script>                <div id="76d5a9be-712e-4559-9a74-e1f22e1b6027" class="plotly-graph-div" style="height:500px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("76d5a9be-712e-4559-9a74-e1f22e1b6027")) {                    Plotly.newPlot(                        "76d5a9be-712e-4559-9a74-e1f22e1b6027",                        [{"alignmentgroup":"True","hovertemplate":"Industry Name=%{x}<br>Growth in Industry across the world(in %)=%{y}<extra></extra>","legendgroup":"Venture Capital & Private Equity","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Venture Capital & Private Equity","offsetgroup":"Venture Capital & Private Equity","orientation":"v","showlegend":true,"textposition":"auto","x":["Venture Capital & Private Equity"],"xaxis":"x","y":[3.5127126253636365],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Industry Name=%{x}<br>Growth in Industry across the world(in %)=%{y}<extra></extra>","legendgroup":"Railroad Manufacture","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Railroad Manufacture","offsetgroup":"Railroad Manufacture","orientation":"v","showlegend":true,"textposition":"auto","x":["Railroad Manufacture"],"xaxis":"x","y":[2.593456491794873],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Industry Name=%{x}<br>Growth in Industry across the world(in %)=%{y}<extra></extra>","legendgroup":"Renewables & Environment","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Renewables & Environment","offsetgroup":"Renewables & Environment","orientation":"v","showlegend":true,"textposition":"auto","x":["Renewables & Environment"],"xaxis":"x","y":[2.1810178424144135],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Industry Name=%{x}<br>Growth in Industry across the world(in %)=%{y}<extra></extra>","legendgroup":"Alternative Dispute Resolution","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Alternative Dispute Resolution","offsetgroup":"Alternative Dispute Resolution","orientation":"v","showlegend":true,"textposition":"auto","x":["Alternative Dispute Resolution"],"xaxis":"x","y":[2.0349095533333337],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Industry Name=%{x}<br>Growth in Industry across the world(in %)=%{y}<extra></extra>","legendgroup":"Animation","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Animation","offsetgroup":"Animation","orientation":"v","showlegend":true,"textposition":"auto","x":["Animation"],"xaxis":"x","y":[1.9513783131538458],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Industry Name=%{x}<br>Growth in Industry across the world(in %)=%{y}<extra></extra>","legendgroup":"Aviation & Aerospace","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Aviation & Aerospace","offsetgroup":"Aviation & Aerospace","orientation":"v","showlegend":true,"textposition":"auto","x":["Aviation & Aerospace"],"xaxis":"x","y":[1.6919935518526317],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Industry Name=%{x}<br>Growth in Industry across the world(in %)=%{y}<extra></extra>","legendgroup":"Computer & Network Security","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Computer & Network Security","offsetgroup":"Computer & Network Security","orientation":"v","showlegend":true,"textposition":"auto","x":["Computer & Network Security"],"xaxis":"x","y":[1.6784903070109887],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Industry Name=%{x}<br>Growth in Industry across the world(in %)=%{y}<extra></extra>","legendgroup":"Information Services","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Information Services","offsetgroup":"Information Services","orientation":"v","showlegend":true,"textposition":" ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.6.3.min.js"></script>                <div id="38fd682b-fa3c-43fc-b942-77dd452561a1" class="plotly-graph-div" style="height:500px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("38fd682b-fa3c-43fc-b942-77dd452561a1")) {                    Plotly.newPlot(                        "38fd682b-fa3c-43fc-b942-77dd452561a1",                        [{"alignmentgroup":"True","hovertemplate":"Industry Name=%{x}<br>Average migration per 10k=%{y}<extra></extra>","legendgroup":"Venture Capital & Private Equity","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Venture Capital & Private Equity","offsetgroup":"Venture Capital & Private Equity","orientation":"v","showlegend":true,"textposition":"auto","x":["Venture Capital & Private Equity"],"xaxis":"x","y":[281.4273684210525],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Industry Name=%{x}<br>Average migration per 10k=%{y}<extra></extra>","legendgroup":"Capital Markets","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Capital Markets","offsetgroup":"Capital Markets","orientation":"v","showlegend":true,"textposition":"auto","x":["Capital Markets"],"xaxis":"x","y":[221.4381818181818],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Industry Name=%{x}<br>Average migration per 10k=%{y}<extra></extra>","legendgroup":"E-Learning","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"E-Learning","offsetgroup":"E-Learning","orientation":"v","showlegend":true,"textposition":"auto","x":["E-Learning"],"xaxis":"x","y":[211.47583333333338],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Industry Name=%{x}<br>Average migration per 10k=%{y}<extra></extra>","legendgroup":"Think Tanks","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Think Tanks","offsetgroup":"Think Tanks","orientation":"v","showlegend":true,"textposition":"auto","x":["Think Tanks"],"xaxis":"x","y":[187.0076923076923],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Industry Name=%{x}<br>Average migration per 10k=%{y}<extra></extra>","legendgroup":"Outsourcing/Offshoring","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Outsourcing/Offshoring","offsetgroup":"Outsourcing/Offshoring","orientation":"v","showlegend":true,"textposition":"auto","x":["Outsourcing/Offshoring"],"xaxis":"x","y":[157.33825],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Industry Name=%{x}<br>Average migration per 10k=%{y}<extra></extra>","legendgroup":"Computer & Network Security","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Computer & Network Security","offsetgroup":"Computer & Network Security","orientation":"v","showlegend":true,"textposition":"auto","x":["Computer & Network Security"],"xaxis":"x","y":[153.611875],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Industry Name=%{x}<br>Average migration per 10k=%{y}<extra></extra>","legendgroup":"Information Services","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Information Services","offsetgroup":"Information Services","orientation":"v","showlegend":true,"textposition":"auto","x":["Information Services"],"xaxis":"x","y":[152.23423076923083],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Industry Name=%{x}<br>Average migration per 10k=%{y}<extra></extra>","legendgroup":"Gambling & Casinos","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Gambling & Casinos","offsetgroup":"Gambling & Casinos","orientation":"v","showlegend":true,"textposition":"auto","x":["Gambling & Casinos"],"xaxis":"x","y":[141.13733333333332],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Industry Name=%{x}<br>Average migration per 10k=%{y}<extra></extra>","legendgroup":"Philanthropy","marker":{"color" ...

# %% [markdown]
# ### Inference from the graphs
#
# - By comparing these two graphs of Average Growth in Industry Vs Average Industry Migration for the year 2018, we can conclude that there is some correlation between the two and Industry Nigration does affect Growth of an Industry, but that is the case in some industires and not all. Hence, our Hypothesis is partially true and not completely true

# %% [markdown]
# ### 4. Now we'll check the same for the year 2019
# - i.e :  we'll compare industry migration for each year with the growth of industries in that year and we'll try to see if the industry which had the most incoming migrants showed the most growth.

# %%
# Arranging the data in descending order and filter out only the data for the year 2019

df_9_2019_1=df_9_tidy.sort_values(by='value',ascending=False).query('Year=="2019"')
df_9_2019_1.head(3)
# Out:
#       country_code country_name  ...  Year      value
# 36139           ua      Ukraine  ...  2019  34.515366
# 33343           lk    Sri Lanka  ...  2019  32.044199
# 34536           pe         Peru  ...  2019  28.030303
#
# [3 rows x 10 columns]

# %%
# Grouping the data by industry name

df_9_2019_grouped = df_9_2019_1.groupby(by=["industry_name"]).mean()[["value"]].reset_index()
df_9_2019_grouped.head()
# Out:
#                     industry_name     value
# 0                      Accounting -1.188033
# 1  Alternative Dispute Resolution  0.242088
# 2                       Animation  2.281182
# 3         Architecture & Planning -0.452658
# 4                   Arts & Crafts  0.064045

# %%
# Arranging the data in descending order and filter out only the data for the year 2019

df_2_2019_1=df_2_tidy.sort_values(by='value',ascending=False).query('Year=="2019"')
df_2_2019_1.head(3)
# Out:
#       country_code country_name  ...  Year    value
# 24354           lu   Luxembourg  ...  2019  1820.99
# 24339           lu   Luxembourg  ...  2019  1561.98
# 23297           ge      Georgia  ...  2019  1321.56
#
# [3 rows x 10 columns]

# %%
df_2_2019_grouped = df_2_2019_1.groupby(by=["industry_name"]).mean()[["value"]].reset_index()
df_2_2019_grouped.head()
# Out:
#              industry_name       value
# 0               Accounting   16.459855
# 1        Airlines/Aviation   -7.639559
# 2                Animation  124.025455
# 3        Apparel & Fashion   16.883556
# 4  Architecture & Planning  -30.953208

# %%
# Plotting the average growth in each industry across the world for the year 2019

fig_36 = px.bar(df_9_2019_grouped.sort_values(by='value',ascending=False).head(20), 
                x="industry_name", 
                y="value",
                title="Growth in industry vs Industry name - 2019",
                labels={"industry_name":"Industry Name","value":"Growth in Industry across the world(in %)"},
                color="industry_name",
                #hover_data=['Year','country_name'],
                height=500
                ).update_xaxes(categoryorder="total ascending")

fig_36.show()

#Plotting the average industry migration vs industry for the year 2018

fig_37 = px.bar(df_2_2019_grouped.sort_values(by='value',ascending=False).head(20), 
                x="industry_name", 
                y="value",
                title="Plotting average industry migration per 10k vs industry (country wise) - 2019",
                labels={"industry_name":"Industry Name","value":"Average migration per 10k"},
                color="industry_name",
                #hover_data=['Year','country_name'],
                height=500
                ).update_xaxes(categoryorder="total ascending")

fig_37.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.6.3.min.js"></script>                <div id="23c4878a-d1a3-4cf4-bf76-2aef6ebbbff9" class="plotly-graph-div" style="height:500px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("23c4878a-d1a3-4cf4-bf76-2aef6ebbbff9")) {                    Plotly.newPlot(                        "23c4878a-d1a3-4cf4-bf76-2aef6ebbbff9",                        [{"alignmentgroup":"True","hovertemplate":"Industry Name=%{x}<br>Growth in Industry across the world(in %)=%{y}<extra></extra>","legendgroup":"Venture Capital & Private Equity","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Venture Capital & Private Equity","offsetgroup":"Venture Capital & Private Equity","orientation":"v","showlegend":true,"textposition":"auto","x":["Venture Capital & Private Equity"],"xaxis":"x","y":[3.1991435781212125],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Industry Name=%{x}<br>Growth in Industry across the world(in %)=%{y}<extra></extra>","legendgroup":"Animation","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Animation","offsetgroup":"Animation","orientation":"v","showlegend":true,"textposition":"auto","x":["Animation"],"xaxis":"x","y":[2.2811824727384624],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Industry Name=%{x}<br>Growth in Industry across the world(in %)=%{y}<extra></extra>","legendgroup":"Computer & Network Security","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Computer & Network Security","offsetgroup":"Computer & Network Security","orientation":"v","showlegend":true,"textposition":"auto","x":["Computer & Network Security"],"xaxis":"x","y":[1.9920815916373633],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Industry Name=%{x}<br>Growth in Industry across the world(in %)=%{y}<extra></extra>","legendgroup":"Renewables & Environment","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Renewables & Environment","offsetgroup":"Renewables & Environment","orientation":"v","showlegend":true,"textposition":"auto","x":["Renewables & Environment"],"xaxis":"x","y":[1.4945874637117103],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Industry Name=%{x}<br>Growth in Industry across the world(in %)=%{y}<extra></extra>","legendgroup":"Railroad Manufacture","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Railroad Manufacture","offsetgroup":"Railroad Manufacture","orientation":"v","showlegend":true,"textposition":"auto","x":["Railroad Manufacture"],"xaxis":"x","y":[1.372485819487179],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Industry Name=%{x}<br>Growth in Industry across the world(in %)=%{y}<extra></extra>","legendgroup":"Internet","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Internet","offsetgroup":"Internet","orientation":"v","showlegend":true,"textposition":"auto","x":["Internet"],"xaxis":"x","y":[1.2292426360236213],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Industry Name=%{x}<br>Growth in Industry across the world(in %)=%{y}<extra></extra>","legendgroup":"Investment Management","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Investment Management","offsetgroup":"Investment Management","orientation":"v","showlegend":true,"textposition":"auto","x":["Investment Management"],"xaxis":"x","y":[0.9590916697876092],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Industry Name=%{x}<br>Growth in Industry across the world(in %)=%{y}<extra></extra>","legendgroup":"Aviation & Aerospace","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Aviation & Aerospace","offsetgroup":"Aviation & Aerospace","orientation":"v","showlegend":true,"textposition":"auto","x":["Aviation & Aerospace"],"xaxis":"x","y":[0.868219926768421],"yaxis":"y"," ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.6.3.min.js"></script>                <div id="e7795dfd-4858-49ab-a785-27a8a9ea05c7" class="plotly-graph-div" style="height:500px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e7795dfd-4858-49ab-a785-27a8a9ea05c7")) {                    Plotly.newPlot(                        "e7795dfd-4858-49ab-a785-27a8a9ea05c7",                        [{"alignmentgroup":"True","hovertemplate":"Industry Name=%{x}<br>Average migration per 10k=%{y}<extra></extra>","legendgroup":"Capital Markets","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Capital Markets","offsetgroup":"Capital Markets","orientation":"v","showlegend":true,"textposition":"auto","x":["Capital Markets"],"xaxis":"x","y":[153.13636363636365],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Industry Name=%{x}<br>Average migration per 10k=%{y}<extra></extra>","legendgroup":"Computer & Network Security","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Computer & Network Security","offsetgroup":"Computer & Network Security","orientation":"v","showlegend":true,"textposition":"auto","x":["Computer & Network Security"],"xaxis":"x","y":[129.37625],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Industry Name=%{x}<br>Average migration per 10k=%{y}<extra></extra>","legendgroup":"Outsourcing/Offshoring","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Outsourcing/Offshoring","offsetgroup":"Outsourcing/Offshoring","orientation":"v","showlegend":true,"textposition":"auto","x":["Outsourcing/Offshoring"],"xaxis":"x","y":[124.71574999999999],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Industry Name=%{x}<br>Average migration per 10k=%{y}<extra></extra>","legendgroup":"Animation","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Animation","offsetgroup":"Animation","orientation":"v","showlegend":true,"textposition":"auto","x":["Animation"],"xaxis":"x","y":[124.02545454545456],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Industry Name=%{x}<br>Average migration per 10k=%{y}<extra></extra>","legendgroup":"Venture Capital & Private Equity","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Venture Capital & Private Equity","offsetgroup":"Venture Capital & Private Equity","orientation":"v","showlegend":true,"textposition":"auto","x":["Venture Capital & Private Equity"],"xaxis":"x","y":[123.58842105263157],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Industry Name=%{x}<br>Average migration per 10k=%{y}<extra></extra>","legendgroup":"E-Learning","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"E-Learning","offsetgroup":"E-Learning","orientation":"v","showlegend":true,"textposition":"auto","x":["E-Learning"],"xaxis":"x","y":[110.52624999999995],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Industry Name=%{x}<br>Average migration per 10k=%{y}<extra></extra>","legendgroup":"Information Services","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Information Services","offsetgroup":"Information Services","orientation":"v","showlegend":true,"textposition":"auto","x":["Information Services"],"xaxis":"x","y":[95.20230769230767],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Industry Name=%{x}<br>Average migration per 10k=%{y}<extra></extra>","legendgroup":"Market Research","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Market Research","offsetgroup":"Market Research","orientation":"v","showlegend":true,"textposition":"auto","x":["Market Research"],"xaxis":"x","y":[89.06130434782608],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Industry Name=%{x}<br>Average migration per 10k=%{y}<extra></extra>","legendgroup":"Shipbuilding","marker":{"color":"#FF97FF", ...

# %% [markdown]
# ### Inference from the graphs
#
# - By comparing these two graphs of Average Growth in Industry Vs Average Industry Migration for the year 2019, we can conclude that there is some correlation between the two and Industry Nigration does affect Growth of an Industry, but that is the case in some industires and not all. Hence, our Hypothesis is partially true and not completely true
